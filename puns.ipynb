# %%
# functionality import
import re
import pandas as pd

# data import
def _open(path):
    with open(path, 'r') as f:
        return tuple(f.read().split('\n'))

SYMBOLS = _open('./data/cmu-pronouncing-dictionary/cmudict.symbols')
ALL_PRONOUNCED_WORDS = _open('./data/cmu-pronouncing-dictionary/cmudict.dict')
phones = pd.read_csv('./data/cmu-pronouncing-dictionary/cmudict.phones', sep='\t', header=None)
# not pictured: pronunciation of punctuation in cmudict.vp
print(f'number of pronunciations: {len(ALL_PRONOUNCED_WORDS)}')
# Out:
# number of pronunciations: 135011

# %%
pd.np.log10(135011 ** 2)
# Out:
# 10.260738308022356

# %%
# record all the identicalled spelled and identically pronounced words
alt_identifier = re.compile(r'\(\d+\)$')

spelling_to_pronunciation = {}
pronunciation_to_spelling = {}

for entry in ALL_PRONOUNCED_WORDS:
    split = entry.split(' ')
    if len(split) >= 2:
        word, *the_rest = split
        phonetic_tuple = tuple(the_rest)
        if alt_identifier.search(word):
            # this word spelling is an alternate pronunciation
            word = re.sub(alt_identifier, '', word)
            spelling_to_pronunciation[word].append(phonetic_tuple)
        else:
            spelling_to_pronunciation[word] = [phonetic_tuple]
        if phonetic_tuple in pronunciation_to_spelling:
            pronunciation_to_spelling[phonetic_tuple].append(word)
        else:
            pronunciation_to_spelling[phonetic_tuple] = [word]

# %%
homographic = {
    word:pronunciations
    for word, pronunciations in spelling_to_pronunciation.items()
    if len(pronunciations) > 1
}
homophonic = {
    pronunciation:words
    for pronunciation, words in pronunciation_to_spelling.items()
    if len(words) > 1
}

# %%
# quick interlude: counts of items in each set
for c in ('homographic', 'homophonic'):
    print(f'{c}:\t{len(eval(c))}')
# Out:
# homographic:	8417
# homophonic:	13091

# %%
homophonic # most from plural/posessive confusion
# Out:
# {('B', 'AW1', 'T'): ["'bout", 'bout'],
#  ('K', 'AO1', 'R', 'S'): ["'course", 'coarse', 'corse', 'course'],
#  ('K', 'Y', 'UW1', 'Z'): ["'cuse",
#   'cues',
#   'kuse',
#   'kuze',
#   "q's",
#   "q.'s",
#   'q.s',
#   'ques',
#   'queues'],
#  ('AH0', 'M'): ["'em", "'m", "i'm"],
#  ('K', 'EY1'): ["'kay",
#   'cay',
#   'k',
#   'k.',
#   'kay',
#   'kaye',
#   'khe',
#   'quai',
#   'quay',
#   'quaye'],
#  ('AH0', 'N'): ["'n", 'an'],
#  ('R', 'AW1', 'N', 'D'): ["'round", 'round'],
#  ('EH1', 'S'): ["'s", 'es', 'ess', 'esse', 's', 's.'],
#  ('T', 'IH1', 'L'): ["'til", 'til', 'till'],
#  ('T', 'IH1', 'Z'): ["'tis", 'tis'],
#  ('T', 'W', 'AH1', 'Z'): ["'twas", 'twas'],
#  ('EY1',): ['a', 'a.', 'ae', 'ay'],
#  ('EY1', 'Z'): ["a's", "a.'s", 'a.s'],
#  ('AA1', 'K', 'ER0'): ['aaker', 'ocker'],
#  ('AA1', 'N', 'K', 'AO2', 'R'): ['aancor', 'encore', 'oncor'],
#  ('AA1', 'R', 'G'): ['aargh', 'argh'],
#  ('EH1', 'R', 'AH0', 'N'): ['aaron', 'aran', 'aron', 'ehren'],
#  ('EH1', 'R', 'AH0', 'N', 'Z'): ["aaron's", 'aarons', 'arens'],
#  ('EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'): ['aaronson', 'aronson'],
#  ('AA1', 'S'): ['aase', 'os'],
#  ('AA1', 'S', 'AH0', 'N'): ['aasen', 'osten'],
#  ('AH0', 'B', 'AE1', 'D', 'IY0'): ['abadi', 'abadie'],
#  ('AE1', 'B', 'IY0'): ['abbe', 'abbey', 'abbie', 'abby', 'abie'],
#  ('AH0', 'B', 'EH1', 'T'): ['abbett', 'abet'],
#  ('AE1', 'B', 'AH0', 'T'): ['abbot', 'abbott'],
#  ('AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N'): ['abbotstown', 'abbottstown'],
#  ('AH0', 'B', 'UW1', 'D'): ['abboud', 'abood'],
#  ('AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1', 'Z', 'IY0'): ['abbruzzese',
#   'abruzzese'],
#  ('AE1', 'B', 'Z'): ['abbs', 'abs'],
#  ('EY1', 'B', 'IY2', 'S', 'IY2', 'Z'): ["abc's", 'abcs'],
#  ('AE2', 'B', 'D', 'AE1', 'L', 'AH0'): ['abdalla', 'abdallah'],
#  ('EY1', 'B', 'AH0', 'L'): ['abel', 'abell', 'able'],
#  ('EY1', 'B', 'AH0', 'L', 'Z'): ['abels', 'ables'],
#  ('EY1', 'B', 'ER0'): ['aber', 'aybar'],
#  ('EY1', 'B', 'R', 'AH0', 'M', 'Z'): ["abram's", 'abrams'],
#  ('AH0', 'B', 'R', 'AE1', 'K', 'S', 'AH0', 'Z'): ["abraxa's", 'abraxas'],
#  ('AE1', 'B', 'S', 'AH0', 'L', 'AH0', 'M'): ['absalom', 'absolom'],
#  ('AH0', 'K', 'AE1', 'D', 'AH0', 'M', 'IY0', 'Z'): ['academies', "academy's"],
#  ('AE1', 'K', 'S', 'AH0', 'D', 'AH0', 'N', 'T', 'S'): ["accident's",
#   'accidents'],
#  ('AH0', 'K', 'L', 'EY1', 'M', 'Z'): ["acclaim's", 'acclaims'],
#  ('AE2', 'K', 'L', 'AH0', 'M', 'EY1', 'SH', 'AH0', 'N'): ['acclamation',
#   'acclimation'],
#  ('AE1', 'K', 'ER0', 'Z'): ["accor's", "acker's"],
#  ('AH0', 'K', 'AO1', 'R', 'D'): ['accord', 'acord'],
#  ('AH0', 'K', 'AO1', 'R', 'D', 'Z'): ["accord's", 'accords'],
#  ('AH0', 'K', 'AW1', 'N', 'T', 'S'): ["account's", 'accounts'],
#  ('AH0', 'K', 'AW1', 'N', 'T', 'AH0', 'N', 'T', 'S'): ["accountant's",
#   'accountants',
#   "accountants'"],
#  ('AH0', 'K', 'UW1', 'T', 'ER0', 'M', 'AH0', 'N', 'T'): ['accouterment',
#   'accoutrement'],
#  ('AH0', 'K', 'UW1', 'T', 'ER0', 'M', 'AH0', 'N', 'T', 'S'): ['accouterments',
#   'accoutrements'],
#  ('EY1', 'S', 'T'): ['aced', 'aist'],
#  ('AH0', 'S', 'EH1', 'T', 'IH0', 'K'): ['acetic', 'ascetic'],
#  ('EY1', 'K'): ['ache', 'ake'],
#  ('EY1', 'K', 'S'): ['aches', 'aix'],
#  ('AE1', 'CH', 'AH0', 'S', 'AH0', 'N', 'Z'): ["acheson's", 'achesons'],
#  ('AH0', 'K', 'IH1', 'L', 'IY0', 'Z'): ['achilles', "achilles'"],
#  ('EY1', 'K', 'ER0'): ['achor', 'acre', 'aker'],
#  ('EY1', 'K', 'IY0'): ['achy', 'aikey'],
#  ('AE1', 'K'): ['ack', 'akc'],
#  ('AE1', 'K', 'ER0'): ['acker', 'aker', 'akre'],
#  ('AE1', 'K', 'ER0', 'L', 'IY0'): ['ackerley', 'ackerly'],
#  ('AE1', 'K', 'ER0', 'M', 'AH0', 'N'): ['ackerman',
#   'ackermann',
#   'akerman',
#   'akkerman'],
#  ('AE1', 'K', 'ER0', 'S', 'AH0', 'N'): ['ackerson', 'akerson'],
#  ('AE0',
#   'K',
#   'N',
#   'AA1',
#   'L',
#   'IH0',
#   'JH',
#   'M',
#   'AH0',
#   'N',
#   'T'): ['acknowledgement', 'acknowledgment'],
#  ('AE0',
#   'K',
#   'N',
#   'AA1',
#   'L',
#   'IH0',
#   'JH',
#   'M',
#   'AH0',
#   'N',
#   'T',
#   'S'): ['acknowledgements', 'acknowledgments'],
#  ('EY1', 'K', 'AO0', 'R', 'N', 'Z'): ["acorn's", 'acorns'],
#  ('AH0', 'K', 'W', 'AY1', 'ER0', 'ER0', 'Z'): ["acquirer's", 'acquirers'],
#  ('AE2', 'K', 'W', 'AH0', 'Z', 'IH1', 'SH', 'AH0', 'N', 'Z'): ["acquisition's",
#   'acquisitions'],
#  ('EY1', 'K', 'ER0', 'Z'): ['acres', 'akers'],
#  ('AE1', 'K', 'T', 'S'): ["act's", 'acts'],
#  ('AE2', 'K', 'T', 'AA1', 'V', 'AH0', 'Z'): ["actava's", 'actavas'],
#  ('AE1', 'K', 'T', 'AH0', 'N'): ['actin', 'acton'],
#  ('AE1', 'K', 'SH', 'AH0', 'N', 'Z'): ["action's", 'actions'],
#  ('AE1', 'K', 'T', 'IH0', 'V', 'Z'): ["active's", 'actives'],
#  ('AE1', 'K', 'T', 'IH0', 'V', 'IH0', 'S', 'T', 'S'): ['activists',
#   "activists'"],
#  ('AE1', 'K', 'T', 'ER0'): ['actor', 'akhtar'],
#  ('AE1', 'K', 'T', 'ER0', 'Z'): ["actor's", 'actors', "actors'"],
#  ('AE1', 'K', 'T', 'R', 'AH0', 'S', 'IH0', 'Z'): ["actress's", 'actresses'],
#  ('AE1', 'K', 'S'): ['acts', 'ax', 'axe', 'x.'],
#  ('AE1', 'K', 'Y', 'ER0', 'AH0', 'Z'): ["acura's", 'acuras'],
#  ('AE1', 'D'): ['ad', 'add'],
#  ('AE1', 'D', 'Z'): ["ad's", 'adds', 'ads', "ads'", 'adz'],
#  ('EY1', 'D', 'AH0', 'Z'): ["ada's", 'adas'],
#  ('AH0', 'D', 'EH1', 'R'): ['adair', 'addair'],
#  ('AE1', 'D', 'AH0', 'M', 'Z'): ["adam's", 'adams', "adams'", 'addams'],
#  ('AA1', 'D', 'AH0', 'M', 'CH', 'IH0', 'K'): ['adamcik', 'adamczyk'],
#  ('AA0', 'D', 'AA1', 'M', 'IY0'): ['adame', 'adami'],
#  ('AH0', 'D', 'AA1', 'M', 'IH0', 'K'): ['adamec', 'adamik'],
#  ('EY1', 'D', 'AH0', 'N'): ['adan', 'aden'],
#  ('AH0', 'D', 'AE1', 'P', 'T', 'ER0'): ['adapter', 'adaptor'],
#  ('AH0', 'D', 'AE1', 'P', 'T', 'ER0', 'Z'): ['adapters', 'adaptors'],
#  ('AH0', 'D', 'IY1', 'D', 'AH0', 'S'): ['addidas', "addidas'", 'adidas'],
#  ('AH0', 'D', 'IY1', 'D', 'AH0', 'S', 'IH0', 'Z'): ["addidas's",
#   'addidases',
#   "adidas's"],
#  ('AE1', 'D', 'IY0'): ['addie', 'addy'],
#  ('AH0', 'D', 'IH1', 'SH', 'AH0', 'N'): ['addition', 'edition'],
#  ('AE1', 'D', 'AH0', 'L', 'M', 'AH0', 'N'): ['addleman',
#   'adelman',
#   'adelmann'],
#  ('EY1', 'D'): ['ade', 'aid', 'aide', 'eyde'],
#  ('AH0', 'D', 'EH1', 'L'): ['adel', 'adele', 'adell', 'adelle', 'udelle'],
#  ('AH0', 'D', 'EH1', 'L', 'Z'): ["adele's", "adell's"],
#  ('EH1', 'D', 'AH0', 'L', 'M', 'AH0', 'N'): ['adelman',
#   'eddleman',
#   'edelman',
#   'edelmann',
#   'edleman'],
#  ('EY1', 'D', 'Z'): ['ades', "aid's", "aide's", 'aides', "aides'", 'aids'],
#  ('EY1', 'D', 'IY0'): ['adey', 'ady', 'eydie'],
#  ('AA1', 'D', 'IY0', 'AH0'): ['adia', 'odea'],
#  ('AH0', 'D', 'UW1'): ['adieu', 'ado'],
#  ('AE1', 'D', 'K', 'IH0', 'S', 'AH0', 'N'): ['adkison', 'adkisson'],
#  ('AE1', 'D', 'L', 'ER0', 'Z'): ["adler's", 'adlers'],
#  ('AE1', 'D', 'M', 'AH0', 'N'): ['adman', 'admen'],
#  ('AE0',
#   'D',
#   'M',
#   'IH2',
#   'N',
#   'IH0',
#   'S',
#   'T',
#   'R',
#   'EY1',
#   'SH',
#   'AH0',
#   'N',
#   'Z'): ["administration's", 'administrations', "administrations'"],
#  ('AE0',
#   'D',
#   'M',
#   'IH1',
#   'N',
#   'IH0',
#   'S',
#   'T',
#   'R',
#   'EY2',
#   'T',
#   'ER0',
#   'Z'): ["administrator's", 'administrators'],
#  ('AE1', 'D', 'M', 'ER0', 'AH0', 'L', 'Z'): ["admiral's", 'admirals'],
#  ('AA1', 'D', 'R', 'IY0', 'AH0'): ['adrea', 'adria'],
#  ('AH0', 'D', 'AH1', 'L', 'T', 'S'): ['adults', "adults'"],
#  ('AE1', 'D', 'AH0', 'L', 'T', 'S'): ['adults', "adults'"],
#  ('AH0', 'D', 'V', 'AE1', 'N', 'S', 'AH0', 'Z'): ["advance's", 'advances'],
#  ('AH0', 'D', 'V', 'AE1', 'N', 'S', 'IH0', 'Z'): ["advance's", 'advances'],
#  ('AE1', 'D', 'V', 'ER0', 'T', 'AY2', 'Z', 'ER0', 'Z'): ["advertiser's",
#   'advertisers'],
#  ('AE0', 'D', 'V', 'AY1', 'Z', 'ER0'): ['adviser', 'advisor'],
#  ('AE0', 'D', 'V', 'AY1', 'Z', 'ER0', 'Z'): ['advisers', 'advisors'],
#  ('AE1', 'D', 'V', 'AH0', 'K', 'AH0', 'T', 'S'): ["advocate's", 'advocates'],
#  ('AE1', 'L', 'T', 'AH0', 'S'): ['aeltus', 'altus'],
#  ('EH1', 'R'): ['aer', 'air', 'ayre', 'ere', 'err', 'eyre', 'heir'],
#  ('EH1', 'R', 'IY0', 'AH0', 'L'): ['aerial', 'ariel'],
#  ('EH1', 'R', 'IY0'): ['aerie', 'airey', 'airy', 'arie', 'ary', 'eyrie'],
#  ('EH1', 'R', 'OW0'): ['aero', 'arrow', 'eroh'],
#  ('EH1', 'R', 'OW0', 'S', 'M', 'IH2', 'TH'): ['aerosmith', 'arrowsmith'],
#  ('EH1', 'R', 'OW0', 'S', 'M', 'IH2', 'TH', 'S'): ["aerosmith's",
#   "arrowsmith's"],
#  ('EH1', 'R', 'OW0', 'S', 'T', 'AA2', 'R', 'Z'): ["aerostar's", 'aerostars'],
#  ('EH1', 'R', 'OW0', 'S', 'T', 'AE2', 'T', 'S'): ["aerostat's", 'aerostats'],
#  ('EH1', 'S', 'TH', 'IY0', 'T', 'S'): ["aesthete's", 'aesthetes'],
#  ('EH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K'): ['aesthetic', 'esthetic'],
#  ('EH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K', 'L', 'IY0'): ['aesthetically',
#   'esthetically'],
#  ('EH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K', 'S'): ['aesthetics', 'esthetics'],
#  ('EH1', 'T', 'N', 'AH0'): ['aetna', 'etna'],
#  ('AH0', 'F', 'EH1', 'R', 'Z'): ["affair's", 'affairs'],
#  ('AH0', 'F', 'EH1', 'K', 'T'): ['affect', 'effect'],
#  ('AH0', 'F', 'IH1', 'L', 'IY0', 'EY2', 'T', 'S'): ["affiliate's",
#   'affiliates'],
#  ('AE0', 'F', 'G', 'AE1', 'N', 'IY0', 'Z'): ["afghani's", 'afghanis'],
#  ('AE0',
#   'F',
#   'G',
#   'AE1',
#   'N',
#   'AH0',
#   'S',
#   'T',
#   'AE2',
#   'N',
#   'Z'): ["afghanistan's", 'afghanistans'],
#  ('AE1',
#   'F',
#   'R',
#   'IH0',
#   'K',
#   'AA0',
#   'N',
#   'IH0',
#   'S',
#   'T',
#   'S'): ["africanist's", 'africanists'],
#  ('AE2', 'F', 'T', 'ER0', 'N', 'UW1', 'N', 'Z'): ["afternoon's", 'afternoons'],
#  ('AE1', 'G', 'AE0', 'CH', 'AH0', 'Z'): ["agache's", 'agaches'],
#  ('EY1', 'G', 'AH0', 'N'): ['agan', 'aygen'],
#  ('EY1', 'JH', 'IH0', 'Z'): ["age's", 'ages'],
#  ('EY1', 'JH', 'AH0', 'N', 'S', 'IY0', 'Z'): ['agencies',
#   "agencies'",
#   "agency's"],
#  ('EY1', 'JH', 'AH0', 'N', 'T', 'S'): ["agent's", 'agents', "agents'"],
#  ('EY1', 'JH', 'ER0', 'Z'): ['agers', "agers'"],
#  ('AE1', 'G', 'IY0'): ['aggie', 'aggy', 'agie'],
#  ('AH0', 'G', 'L', 'OW1'): ['aglo', 'aglow'],
#  ('AE1', 'G', 'N', 'EH2', 'L', 'IY0', 'Z'): ["agnelli's", 'agnellis'],
#  ('AE1', 'G', 'N', 'ER0'): ['agner', 'agnor'],
#  ('AH0', 'G', 'R', 'IY1', 'M', 'AH0', 'N', 'T', 'S'): ["agreement's",
#   'agreements'],
#  ('AE1', 'G', 'AH0', 'L', 'AA0', 'R'): ['aguilar', 'aguillar'],
#  ('AA1',): ['ah', 'ahh', 'awe'],
#  ('AH0', 'HH', 'ER1', 'N'): ['ahearn', 'ahern', 'aherne'],
#  ('AH0', 'L', 'EY1', 'N'): ['ahlen',
#   'alain',
#   'alaine',
#   'alane',
#   'alayne',
#   'allain',
#   'elaine'],
#  ('AA1', 'L', 'AH0', 'N'): ['ahlen', 'olen'],
#  ('AA1', 'L', 'M', 'AH0', 'N'): ['ahlman', 'almon'],
#  ('AA1', 'L', 'K', 'W', 'IH2', 'S', 'T', 'S'): ["ahlquist's", 'ahlquists'],
#  ('AA1', 'M', 'AH0', 'N'): ['ahmann', 'aman', 'ommen'],
#  ('AA1', 'M', 'AH0', 'N', 'S', 'AH0', 'N', 'Z'): ["ahmanson's", 'ahmansons'],
#  ('AE1', 'N'): ['ahn', 'an', 'ane', 'ann', 'anne'],
#  ('AA1', 'N', 'ER0'): ['ahner', 'honor', 'honore', 'honour'],
#  ('AH0', 'HH', 'OW1', 'L', 'D', 'Z'): ["ahold's", 'aholds'],
#  ('AA1', 'R'): ['ahr', 'ar', 'are', 'our', 'r', 'r.'],
#  ('AA1', 'R', 'AH0', 'N'): ['ahren', 'aren'],
#  ('AA1', 'Z'): ['ahs', 'oz'],
#  ('AY1',): ['ai', 'ay', 'aye', 'eye', 'i', 'i.'],
#  ('AY1', 'K', 'AH0', 'L'): ['aichele', 'eichel'],
#  ('AY1', 'K', 'ER0'): ['aicher', 'eicher'],
#  ('EY1', 'K', 'IH0', 'N'): ['aickin', 'aiken', 'aikin', 'akin'],
#  ('AY0', 'IY1', 'D', 'AH0'): ['aida', 'uyeda'],
#  ('EY2', 'D', 'EH1', 'N'): ['aiden', 'aidenn'],
#  ('AY1', 'SH', 'AH0'): ['aiesha', 'aisha'],
#  ('EY1', 'K', 'IH0', 'N', 'Z'): ['aikens', 'akins'],
#  ('EY1', 'L'): ['ail', 'ale'],
#  ('AY0', 'L', 'IY1', 'N'): ['aileen', 'ailene', 'eileen'],
#  ('AY1', 'L', 'Z'): ['ailes', 'aisles', 'iles', 'illes', 'isles'],
#  ('EY1', 'L', 'Z'): ['ailes', 'ails', 'ales', 'alles', 'ayles'],
#  ('EY1', 'L', 'IY0'): ['ailey', 'aley', 'aly'],
#  ('EY1', 'L', 'IH0', 'NG'): ['ailing', 'ayling'],
#  ('EY1', 'L', 'ER0'): ['ailor', 'ayler', 'aylor', 'eyler'],
#  ('EY1', 'M'): ['aim', 'aime', 'ame'],
#  ('EY1', 'M', 'Z'): ["aim's", 'aims', 'ames', "ames'"],
#  ('AY1', 'M', 'AH0', 'N'): ['aiman', 'iman'],
#  ('EY1', 'N'): ['aine', 'ane', 'ayn'],
#  ('EY1', 'N', 'JH'): ['ainge', 'ange'],
#  ('EH1', 'R', 'Z'): ["air's", 'airs', "ayer's", 'ayres', 'errs', 'heirs'],
#  ('EH1',
#   'R',
#   'K',
#   'AH0',
#   'N',
#   'D',
#   'IH2',
#   'SH',
#   'AH0',
#   'N',
#   'IH0',
#   'NG'): ['air-conditioning', 'airconditioning'],
#  ('EH1', 'R', 'F', 'AO0', 'R', 'S'): ['air-force', 'airforce'],
#  ('EH1', 'R', 'K', 'R', 'AE2', 'F', 'T', 'S'): ["aircraft's", 'aircrafts'],
#  ('EH1', 'R', 'K', 'R', 'AE2', 'F', 'S'): ["aircraft's", 'aircrafts'],
#  ('EH1', 'R', 'D'): ['aird', 'aired', 'erred'],
#  ('EH1', 'R', 'IY0', 'Z'): ['aires', 'aries'],
#  ('EH1', 'R', 'HH', 'AA0', 'R', 'T'): ['airhart',
#   'earhart',
#   'ehrhardt',
#   'ehrhart'],
#  ('EH1', 'R', 'IH0', 'NG'): ['airing', 'erring'],
#  ('EH1', 'R', 'IH0', 'NG', 'T', 'AH0', 'N'): ['airington',
#   'arrington',
#   'errington'],
#  ('EH1', 'R', 'L', 'AY2', 'N', 'Z'): ["airline's", 'airlines', "airlines'"],
#  ('EH1', 'R', 'L', 'AY2', 'N', 'ER0', 'Z'): ["airliner's", 'airliners'],
#  ('EH1', 'R', 'M', 'AH0', 'N'): ['airman', 'ehrman', 'ehrmann'],
#  ('EH1', 'R', 'P', 'L', 'EY0', 'N', 'Z'): ["airplane's", 'airplanes'],
#  ('EH1', 'R', 'P', 'AO2', 'R', 'T', 'S'): ["airport's", 'airports'],
#  ('EH1', 'R', 'W', 'EY2', 'Z'): ["airway's", 'airways', "airways'"],
#  ('AY1', 'Z'): ['ais',
#   'ayes',
#   'eis',
#   "eye's",
#   'eyes',
#   "eyes'",
#   "i's",
#   "i.'s",
#   'i.s',
#   'ise'],
#  ('AY1', 'L'): ['aisle', "i'll", 'isle'],
#  ('EH1', 'K', 'S'): ['aix', 'eckes', 'ex', 'x', 'x.'],
#  ('AE1', 'K', 'S', 'T'): ['akst', 'axed', 'axt'],
#  ('AE1', 'K', 'Z', 'OW0', 'Z'): ["akzo's", 'akzos'],
#  ('AE1', 'L'): ['al', 'al.'],
#  ('AE1', 'L', 'Z'): ["al's", 'als'],
#  ('AE1', 'L', 'AH0', 'M', 'EY2', 'N'): ['al-amein', 'alamein'],
#  ('AE2', 'L', 'AH0', 'B', 'AE1', 'M', 'AH0'): ['al.', 'alabama'],
#  ('AH0', 'L', 'AY1'): ['alai', 'ally'],
#  ('AE1', 'L', 'AH0', 'N'): ['alan', 'allan', 'allen'],
#  ('AE1', 'L', 'AH0', 'N', 'Z'): ["alan's", "allen's", 'allens'],
#  ('AH0', 'L', 'AA1', 'R', 'M', 'Z'): ["alarm's", 'alarms'],
#  ('AE1', 'L', 'B', 'AA0', 'K'): ['albach', 'allebach'],
#  ('AH0', 'L', 'B', 'AO1'): ['albaugh', 'allbaugh'],
#  ('AE1', 'L', 'B', 'ER0', 'T', 'S'): ["albert's", 'alberts'],
#  ('AE1', 'L', 'B', 'ER0', 'T', 'S', 'AH0', 'N'): ['albertsen', 'albertson'],
#  ('AO1', 'L', 'B', 'R', 'AY2', 'T'): ['albright', 'allbright'],
#  ('AE1', 'L', 'B', 'R', 'IH0', 'T', 'AA0', 'N'): ['albritton', 'allbritton'],
#  ('AE1', 'L', 'B', 'AH0', 'M', 'Z'): ["album's", 'albums'],
#  ('AA1', 'L', 'D', 'IH0', 'S'): ['aldis', 'aldus'],
#  ('AO1', 'L', 'D', 'W', 'IH0', 'N'): ['aldwin', 'aldwyn'],
#  ('AE1', 'L', 'IH0', 'K'): ['alec', 'allick'],
#  ('AH0', 'L', 'IY1', 'N'): ['aleen', 'alene'],
#  ('AE2', 'L', 'AH0', 'K', 'S', 'AE1', 'N', 'D', 'ER0'): ['aleksander',
#   'aleksandr'],
#  ('EY1', 'L', 'M', 'AH0', 'N'): ['aleman', 'alleman'],
#  ('AE1', 'L', 'AH0', 'K', 'S'): ['alex', 'alexs'],
#  ('AE2', 'L', 'IH0', 'G', 'Z', 'AE1', 'N', 'D', 'ER0', 'Z'): ["alexander's",
#   'alexanders'],
#  ('AH0', 'L', 'EH1', 'K', 'S', 'IY0'): ['alexi', 'alexy', 'oleksy'],
#  ('AE1', 'L', 'F', 'AH0'): ['alfa', 'alpha'],
#  ('AE1', 'L', 'F', 'AH0', 'Z'): ["alfa's", "alpha's"],
#  ('AE1', 'L', 'F', 'IH0', 'N'): ['alfin', 'alphin'],
#  ('AE1', 'L', 'F', 'R', 'IH0', 'D', 'S', 'AH0', 'N'): ['alfredson',
#   'alfredsson'],
#  ('AE1', 'L', 'JH', 'IY0'): ['algae', 'algy'],
#  ('AA1', 'L', 'IY0'): ['ali', 'olley', 'ollie', 'olly'],
#  ('AA1', 'L', 'IY0', 'Z'): ["ali's", "ollie's"],
#  ('EY1', 'L', 'IY0', 'AH0', 'S'): ['alias', 'allais'],
#  ('AE1', 'L', 'IH0', 'S'): ['alice', 'allis', 'alyce'],
#  ('AE1', 'L', 'AH0', 'S', 'AH0', 'Z'): ["alice's", 'alices'],
#  ('AH0', 'L', 'IH1', 'S', 'IY0', 'AH0'): ['alicea', 'alysia'],
#  ('AE1', 'L', 'IY0'): ['alie', 'alley', 'alli', 'allie'],
#  ('AH0', 'L', 'AY1', 'N'): ['align', 'aline'],
#  ('AH0', 'L', 'AY1', 'N', 'Z'): ['aligns', 'alines'],
#  ('AE2', 'L', 'AH0', 'K', 'W', 'IH1', 'P', 'AH0', 'Z'): ["aliquippa's",
#   'aliquippas'],
#  ('AH0', 'L', 'IY1', 'S', 'AH0'): ['alisa', 'elisa'],
#  ('AE1', 'L', 'IH0', 'S', 'AH0', 'N'): ['alison', 'allison', 'allyson'],
#  ('AH0', 'L', 'IH1', 'S', 'AH0'): ['alissa', 'alyssa'],
#  ('AE1', 'L', 'IH0', 'S', 'T', 'ER0'): ['alister', 'allister'],
#  ('AO1', 'L'): ['all', 'aul', 'aull'],
#  ('AO1', 'L', 'Z'): ["all's", 'alls'],
#  ('AA1', 'L', 'AH0'): ['alla', 'allah'],
#  ('AH0', 'L', 'EY1'): ['allais', 'allay'],
#  ('AE1', 'L', 'ER0', 'T'): ['allardt', 'allert'],
#  ('AE2', 'L', 'AH0', 'G', 'EY1', 'N', 'IY0', 'Z'): ['alleghenies',
#   "allegheny's"],
#  ('AE1', 'L', 'AH0', 'G', 'EH2', 'N', 'IY0', 'Z'): ['alleghenies',
#   "allegheny's"],
#  ('AE2', 'L', 'EY1', 'JH', 'IH0', 'S'): ['allegis', "allegis'"],
#  ('AE2', 'L', 'EH0', 'L', 'UW1', 'Y', 'AA0'): ['alleluia', 'alleluja'],
#  ('AO1', 'L', 'ER0'): ['aller', 'allor'],
#  ('AE1', 'L', 'ER0', 'JH', 'AH0', 'N'): ['allergan', 'allergen'],
#  ('AE1', 'L', 'ER0', 'JH', 'AH0', 'S', 'T', 'S'): ["allergist's",
#   'allergists'],
#  ('AE1', 'L', 'IY0', 'Z'): ["alley's", 'alleys', 'alys'],
#  ('AE1', 'L', 'G', 'AY0', 'ER0'): ['allgaier', 'allgeier'],
#  ('AH0', 'L', 'AY1', 'AH0', 'N', 'S', 'IH0', 'Z'): ["alliance's", 'alliances'],
#  ('AE1', 'L', 'AY0', 'Z'): ['allies', "allies'", 'allys'],
#  ('AH0', 'L', 'AY1', 'Z'): ['allies', "ally's"],
#  ('AO1', 'L', 'M', 'AH0', 'N'): ['allman', 'allmon'],
#  ('AH0', 'L', 'AA1', 'T'): ['allot', 'alot'],
#  ('AH0', 'L', 'AA1', 'T', 'IH0', 'D'): ['alloted', 'allotted'],
#  ('AH0', 'L', 'AW1', 'D'): ['allowed', 'aloud'],
#  ('AO1', 'L', 'S', 'AA2', 'P'): ['allsop', 'allsopp'],
#  ('AO1', 'L', 'S', 'T', 'AH0', 'N'): ['allston', 'alston'],
#  ('AE1', 'L', 'S', 'AH0', 'P'): ['allsup', 'alsup'],
#  ('AO1', 'L', 'T', 'AH0', 'N'): ['allton', 'alton'],
#  ('AE1', 'L', 'AH0', 'M'): ['allum', 'alum'],
#  ('AE1', 'L', 'AH0', 'M', 'Z'): ['allums', 'alums'],
#  ('AA0', 'L', 'OY1', 'S', 'IY0', 'AH0'): ['aloisia', 'aloysia'],
#  ('AE1', 'L', 'Z', 'B', 'R', 'UH0', 'K', 'S'): ["alsbrook's",
#   'alsbrooks',
#   "alsbrooks'"],
#  ('AO1', 'L', 'T', 'ER0'): ['altar', 'alter'],
#  ('AO1', 'L', 'T', 'ER0', 'Z'): ['altars', 'alters'],
#  ('AO1', 'L', 'T', 'M', 'AH0', 'N'): ['altman', 'altmann', 'aultman'],
#  ('AE1', 'L', 'CH', 'Y', 'UW0', 'L', 'ER0'): ['altschuler', 'altshuler'],
#  ('AE1', 'L', 'CH', 'UW0', 'L', 'ER0'): ['altschuler', 'altshuler'],
#  ('AA1', 'L', 'T', 'S', 'HH', 'AY2', 'M', 'ER0'): ['altzheimer', 'alzheimer'],
#  ('AE1', 'L', 'W', 'IH0', 'N'): ['alwin', 'alwyn'],
#  ('AE1', 'M', 'Z'): ["am's", 'ambs', 'ams'],
#  ('AE1', 'M', 'AH0', 'K', 'ER0'): ['amacher', 'amacker'],
#  ('AH0', 'M', 'AA1', 'L', 'Y', 'AH0'): ['amalia', 'amalya'],
#  ('AH0', 'M', 'AE1', 'N', 'D', 'AH0', 'Z'): ["amanda's", 'amandas'],
#  ('AE1', 'M', 'AH0', 'N'): ['amann', 'amman', 'ammann', 'ammon'],
#  ('AE2', 'M', 'ER0', 'IH1', 'L', 'OW0', 'Z'): ["amarillo's", 'amarillos'],
#  ('AE1', 'M', 'AH0', 'Z', 'AA2', 'N', 'Z'): ["amazon's", 'amazons'],
#  ('AE0', 'M', 'B', 'AE1', 'S', 'AH0', 'D', 'ER0', 'Z'): ["ambassador's",
#   'ambassadors'],
#  ('AE1', 'M', 'B', 'ER0', 'Z'): ["amber's", 'ambers'],
#  ('AE1', 'M', 'B', 'IY0', 'AH0', 'N', 'S'): ['ambiance', 'ambience'],
#  ('AA0', 'M', 'B', 'R', 'OW0', 'S', 'IY1', 'N', 'IY0'): ['ambrosine',
#   'ambrosini'],
#  ('AE1', 'M', 'K', 'AO2', 'R'): ['amcor', 'amcore'],
#  ('AH0', 'M', 'IY1', 'N'): ['ameen', 'ammeen'],
#  ('AH0', 'M', 'IY1', 'L', 'IY0', 'OW0'): ['amelio', 'emilio'],
#  ('AH0', 'M', 'EH1', 'N', 'D', 'M', 'AH0', 'N', 'T', 'S'): ["amendment's",
#   'amendments'],
#  ('AH0', 'M', 'EH1', 'R', 'IY0'): ['ameri', 'omary'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AH0'): ['america', 'amerika'],
#  ('AH0', 'M', 'EH1', 'R', 'AH0', 'K', 'AH0', 'Z'): ["america's", 'americas'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AH0', 'Z'): ["america's", 'americas'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AH0', 'N', 'Z'): ["american's",
#   'americans',
#   "americans'"],
#  ('AH0', 'M', 'EH2', 'R', 'AH0', 'K', 'AE1', 'N', 'AH0', 'Z'): ["americana's",
#   'americanas'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AO2', 'R'): ['americorp', 'americorps'],
#  ('AE1', 'M', 'ER0', 'M', 'AH0', 'N'): ['amerman', 'ammerman'],
#  ('EY1', 'M', 'IY0'): ['amey', 'amy', 'eighmey'],
#  ('AH0', 'M', 'AH1', 'K'): ['amok', 'amuck'],
#  ('AE1', 'M', 'P', 'AH0', 'L'): ['ampal', 'ample'],
#  ('AE1', 'M', 'F', 'AH0', 'TH', 'IY0', 'EY1', 'T', 'ER0'): ['amphitheater',
#   'amphitheatre'],
#  ('AH0', 'M', 'Y', 'UW1', 'Z', 'M', 'AH0', 'N', 'T', 'S'): ['amusements',
#   "amusements'"],
#  ('AE1', 'N', 'AH0'): ['ana', 'anna'],
#  ('AE2',
#   'N',
#   'AH0',
#   'S',
#   'TH',
#   'IY0',
#   'Z',
#   'IY0',
#   'AA1',
#   'L',
#   'AH0',
#   'JH',
#   'IY0'): ['anaesthesiology', 'anesthesiology'],
#  ('AE2', 'N', 'AH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K'): ['anaesthetic',
#   'anesthetic'],
#  ('AE2', 'N', 'AH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K', 'S'): ['anaesthetics',
#   'anesthetics'],
#  ('AE1', 'N', 'AH0', 'L', 'AO2', 'G'): ['analog', 'analogue'],
#  ('AE1', 'N', 'AH0', 'L', 'IH0', 'S', 'T', 'S'): ["analyst's",
#   'analysts',
#   "analysts'"],
#  ('AE1', 'N', 'AH0', 'N', 'D', 'EY2', 'L'): ['anandale', 'annandale'],
#  ('AE1', 'N', 'AH0', 'S'): ['anas', 'anise'],
#  ('AE2', 'N', 'AH0', 'T', 'OW1', 'L', 'IY0'): ['anatoli', 'anatoly'],
#  ('AH0', 'N', 'S', 'EH1', 'L'): ['ancel', 'ansel', 'unsell'],
#  ('AE1', 'N', 'S', 'EH2', 'S', 'T', 'ER0', 'Z'): ["ancestor's",
#   'ancestors',
#   "ancestors'"],
#  ('AE1', 'NG', 'K', 'ER0'): ['anchor', 'anker'],
#  ('AE1', 'NG', 'K', 'ER0', 'Z'): ["anchor's", 'anchors'],
#  ('AE1', 'N', 'D', 'AH0', 'L'): ['andal', 'andel'],
#  ('AE1', 'N', 'D', 'ER0', 'S', 'AH0', 'N'): ['andersen',
#   'anderson',
#   'andersson'],
#  ('AE1', 'N', 'D', 'ER0', 'S', 'AH0', 'N', 'Z'): ["andersen's",
#   "anderson's",
#   'andersons'],
#  ('AE1', 'N', 'D', 'IY0', 'Z'): ['andes', "andy's"],
#  ('AE1', 'N', 'D', 'IY0'): ['andi', 'andie', 'andy'],
#  ('AA1', 'N', 'D', 'R', 'EY2'): ['andre', 'andrzej'],
#  ('AE2', 'N', 'D', 'R', 'IY1', 'S', 'AH0', 'N'): ['andreason', 'andriessen'],
#  ('AE1', 'N', 'D', 'R', 'UW0'): ['andreu', 'andrew'],
#  ('AE1', 'N', 'D', 'R', 'UW2', 'Z'): ["andrew's", 'andrews', "andrews'"],
#  ('AE1', 'N', 'D', 'R', 'IY0'): ['andrey', 'andry'],
#  ('AE1', 'N', 'D', 'R', 'IH0', 'K'): ['andric', 'andrich', 'andrick'],
#  ('AH0', 'N', 'EH1', 'T'): ['anette', 'annett', 'annette'],
#  ('AE1', 'N', 'Y', 'UH0', 'R', 'IH2', 'Z', 'AH0', 'M'): ['aneurism',
#   'aneurysm'],
#  ('AE1', 'N', 'Y', 'UH0', 'R', 'IH2', 'Z', 'M'): ['aneurism', 'aneurysm'],
#  ('EY1', 'N', 'JH', 'AH0', 'L'): ['angel', 'angell'],
#  ('EY1', 'N', 'JH', 'AH0', 'L', 'Z'): ["angel's", 'angels', "angels'"],
#  ('AE2', 'N', 'JH', 'AH0', 'L', 'IY1', 'N', 'OW0'): ['angeleno', 'angelino'],
#  ('AE2', 'N', 'JH', 'AH0', 'L', 'IY1', 'N', 'OW0', 'Z'): ['angelenos',
#   "angelino's",
#   'angelinos'],
#  ('AE1', 'N', 'JH', 'AH0', 'L', 'OW2', 'Z'): ["angelo's",
#   'angelos',
#   'angeloz'],
#  ('AA0', 'NG', 'G', 'EH0', 'L', 'OW1', 'N', 'IY0'): ['angelone', 'angeloni'],
#  ('AE1', 'N', 'JH', 'IY0'): ['angi', 'angie', 'angy'],
#  ('AE1', 'N', 'AH0', 'M', 'AH0', 'L', 'Z'): ["animal's",
#   'animals',
#   "animals'"],
#  ('AE1', 'N', 'IH0', 'M', 'AH0', 'S'): ['animous', 'animus'],
#  ('AE0', 'N', 'IY1', 'S', 'AH0'): ['anisa', 'annissa'],
#  ('AE1', 'N', 'AH0', 'S', 'T', 'AH0', 'N'): ['aniston', 'anniston'],
#  ('AE1', 'NG', 'K', 'R', 'AH0', 'M'): ['ankrom', 'ankrum'],
#  ('AE1', 'N', 'Z'): ["ann's", "anne's"],
#  ('AE1', 'N', 'AH0', 'Z'): ["anna's", 'annas'],
#  ('AE1', 'N', 'AH0', 'B', 'AH0', 'L'): ['annabelle', 'annable'],
#  ('AE1', 'N', 'AH0', 'L'): ['annal', 'annul'],
#  ('AE1', 'N', 'AH0', 'N'): ['annan', 'annen'],
#  ('AE1', 'N', 'IY0'): ['annie', 'anny'],
#  ('AE1', 'N', 'OW0'): ['anno', 'ano'],
#  ('AH0', 'N', 'AW1', 'N', 'S', 'M', 'AH0', 'N', 'T'): ['announcement',
#   'announcment'],
#  ('AH0', 'N', 'S', 'K', 'AA1', 'M'): ['anscom', 'anscomb'],
#  ('AE1', 'N', 'S', 'AH0', 'N'): ['ansohn', 'anson'],
#  ('AE1', 'N', 'S', 'ER0', 'Z'): ["answer's", 'answers'],
#  ('AE1', 'N', 'T'): ['ant', 'aunt'],
#  ('AE1', 'N', 'T', 'AH0', 'L'): ['antal', 'antle'],
#  ('AE1', 'N', 'T', 'IY0'): ['ante', 'auntie'],
#  ('AE0', 'N', 'T', 'EH1', 'N', 'AH0', 'Z'): ["antenna's", 'antennas'],
#  ('AE2', 'N', 'T', 'IY0', 'W', 'AO1', 'R'): ['anti-war', 'antiwar'],
#  ('AE0', 'N', 'T', 'IH1', 'G', 'AH0', 'N', 'IY2', 'Z'): ["antigone's",
#   'antigones'],
#  ('AA0', 'N', 'T', 'OW1', 'N', 'IY0'): ['antone', 'antoni'],
#  ('AE0', 'N', 'T', 'OW1', 'N', 'IY2', 'OW2', 'Z'): ["antonio's", 'antonios'],
#  ('AE1', 'N', 'T', 'S'): ['ants', "aunt's", 'aunts', "aunts'"],
#  ('AH0', 'N', 'W', 'EH1', 'L'): ['anwell', 'unwell'],
#  ('AE1', 'N', 'W', 'IH0', 'L'): ['anwyl', 'anwyll'],
#  ('AW1', 'AH0', 'N'): ['aoun', 'auen'],
#  ('AH0', 'P', 'AE1', 'CH', 'IY0', 'Z'): ["apache's", 'apaches'],
#  ('AH0', 'P', 'AA1', 'R', 'T', 'M', 'AH0', 'N', 'T', 'S'): ["apartment's",
#   'apartments'],
#  ('AE1', 'P', 'AH0', 'T', 'AY2', 'T'): ['apatite', 'appetite'],
#  ('AE1', 'P', 'AH0', 'T', 'AY2', 'T', 'S'): ['apatites', 'appetites'],
#  ('EY1', 'P', 'EH2', 'K', 'S'): ["apec's", 'apex'],
#  ('AE2', 'F', 'R', 'AH0', 'D', 'AY1', 'T', 'IY0', 'Z'): ["aphrodite's",
#   'aphrodites'],
#  ('AE1', 'P', 'L', 'IH0', 'N'): ['aplin', 'applin'],
#  ('AH0', 'P', 'AA1', 'L', 'AH0', 'JH', 'AY2', 'Z'): ['apologise', 'apologize'],
#  ('AH0', 'P', 'AA1', 'L', 'AH0', 'JH', 'AY2', 'Z', 'D'): ['apologised',
#   'apologized'],
#  ('AH0', 'P', 'AA1', 'L', 'AH0', 'JH', 'AY2', 'Z', 'IH0', 'Z'): ['apologises',
#   'apologizes'],
#  ('AH0',
#   'P',
#   'AA1',
#   'L',
#   'AH0',
#   'JH',
#   'AY2',
#   'Z',
#   'IH0',
#   'NG'): ['apologising', 'apologizing'],
#  ('AE2', 'P', 'AH0', 'L', 'EY1', 'SH', 'AH0', 'N'): ['appalachian',
#   'appellation'],
#  ('AE2', 'P', 'AH0', 'L', 'EY1', 'SH', 'AH0', 'N', 'Z'): ['appalachians',
#   'appellations'],
#  ('AE1', 'P', 'AH0', 'L'): ['appel', 'appell', 'apple'],
#  ('AE1', 'P', 'AH0', 'L', 'B', 'AW2', 'M'): ['appelbaum', 'applebaum'],
#  ('AE1', 'P', 'AH0', 'L', 'M', 'AH0', 'N'): ['appelman', 'appleman'],
#  ('AE1', 'P', 'AH0', 'L', 'Z'): ["apple's", 'apples'],
#  ('AE1', 'P', 'AH0', 'L', 'B', 'IY2'): ['applebee', 'appleby'],
#  ('AE1', 'P', 'L', 'IH0', 'K', 'AH0', 'N', 'T', 'S'): ["applicant's",
#   'applicants'],
#  ('AE1', 'R', 'AH0', 'B', 'Z'): ['arabs', "arabs'"],
#  ('AA1', 'R', 'AH0', 'N', 'T'): ['arant', "aren't", 'arent'],
#  ('ER0', 'AE1', 'P', 'AH0', 'HH', 'OW2'): ['arapaho', 'arapahoe'],
#  ('AA1', 'R', 'B', 'IH0', 'T', 'R', 'AA2', 'ZH', 'ER0'): ['arbitrager',
#   'arbitrageur'],
#  ('AA1', 'R', 'B', 'IH0', 'T', 'R', 'AA2', 'ZH', 'ER0', 'Z'): ['arbitragers',
#   "arbitragers'"],
#  ('AA1', 'R', 'B', 'AH0', 'T', 'R', 'EY2', 'T', 'ER0', 'Z'): ["arbitrator's",
#   "arbitrators'"],
#  ('AA1', 'R', 'B', 'ER0'): ['arbor', 'arbour'],
#  ('AA1', 'R', 'K'): ['arc', 'ark'],
#  ('AA1', 'R', 'S'): ['arce', 'arse'],
#  ('AA1', 'R', 'S', 'IH0', 'N', 'OW0'): ['arceneaux',
#   'arsenault',
#   'arseneau',
#   'arseneault'],
#  ('AA2',
#   'R',
#   'K',
#   'IY0',
#   'AH0',
#   'L',
#   'AA1',
#   'JH',
#   'IH0',
#   'K',
#   'AH0',
#   'L'): ['archaeological', 'archeological'],
#  ('AA2', 'R', 'K', 'IY0', 'AA1', 'L', 'AH0', 'JH', 'IY0'): ['archaeology',
#   'archeology'],
#  ('AA1', 'R', 'SH', 'AH0', 'M', 'B', 'OW0'): ['archambault', 'archambeault'],
#  ('AA1', 'R', 'CH', 'ER0', 'Z'): ["archer's", 'archers'],
#  ('AA1', 'R', 'K', 'AH0', 'T', 'EH2', 'K', 'T', 'S'): ["architect's",
#   'architects'],
#  ('AA1',
#   'R',
#   'K',
#   'AH0',
#   'T',
#   'EH2',
#   'K',
#   'CH',
#   'ER0',
#   'Z'): ["architecture's", 'architectures'],
#  ('AA0', 'R', 'K', 'UW0', 'L', 'EH1', 'T', 'AH0'): ['archuleta', 'archuletta'],
#  ('AA1', 'R', 'K', 'OW0'): ['arco', 'arko'],
#  ('AA1', 'R', 'K', 'OW0', 'Z'): ["arco's", 'arcos'],
#  ('AA1', 'R', 'K', 'S'): ['arcs', 'arx'],
#  ('ER0',): ['are', 'er', 'or'],
#  ('EH1', 'R', 'IY0', 'AH0'): ['area', 'erria'],
#  ('EH1', 'R', 'IY0', 'AH0', 'Z'): ["area's", 'areas'],
#  ('AA1', 'R', 'N', 'T'): ["aren't", 'arndt'],
#  ('ER0', 'IY1', 'N', 'AH0'): ['arena', 'erina'],
#  ('ER0', 'IY1', 'N', 'AH0', 'Z'): ["arena's", 'arenas'],
#  ('AA1', 'R', 'Z'): ['ares', 'ours', "r's", "r.'s", 'r.s'],
#  ('AA0', 'R', 'EH1', 'T', 'AH0'): ['areta', 'aretta'],
#  ('AA2', 'R', 'JH', 'AH0', 'N', 'T', 'IY1', 'N', 'AH0', 'Z'): ["argentina's",
#   'argentinas'],
#  ('AA1', 'R', 'G', 'AA2', 'N'): ['argon', 'argonne'],
#  ('AA1', 'R', 'G', 'AH0', 'N', 'AO2', 'T', 'S'): ["argonaut's", 'argonauts'],
#  ('AA1', 'R', 'G', 'Y', 'AH0', 'M', 'AH0', 'N', 'T', 'S'): ["argument's",
#   'arguments'],
#  ('AA0', 'R', 'IY0', 'AE1', 'N', 'AH0'): ['ariana', 'arianna'],
#  ('AE1', 'R', 'IH0', 'K'): ['aric', 'arrick'],
#  ('AA0', 'R', 'IY0', 'EH1', 'L', 'AH0'): ['ariela', 'ariella'],
#  ('AA2', 'R', 'IH0', 'S', 'T', 'IY1', 'D'): ['aristede', 'aristide'],
#  ('AA2', 'R', 'IH0', 'S', 'T', 'IY1', 'D', 'Z'): ["aristede's", "aristide's"],
#  ('AA1', 'R', 'K', 'AH0', 'N', 'S', 'AA2', 'Z'): ["arkansas'", "arkansas's"],
#  ('AA1', 'R', 'L', 'IY0'): ['arley', 'arlie'],
#  ('AA1', 'R', 'L', 'AY2', 'N'): ['arline', 'arlyne'],
#  ('AA1', 'R', 'M', 'Z'): ["arm's", 'armes', 'arms'],
#  ('AA1', 'R', 'M', 'AH0', 'N'): ['arman', 'armen', 'armin', 'armon'],
#  ('AA1', 'R', 'M', 'AH0', 'N', 'D'): ['armand', 'armond'],
#  ('AA1', 'R', 'M', 'AH0', 'N', 'T', 'R', 'AW2', 'T'): ['armantrout',
#   'armentrout'],
#  ('AA1', 'R', 'M', 'ER0'): ['armer', 'armor', 'armour'],
#  ('AA1', 'R', 'M', 'IH0', 'S', 'T', 'EH2', 'D'): ['armested', 'armistead'],
#  ('AA1', 'R', 'M', 'IY0'): ['armey', 'army'],
#  ('AA1', 'R', 'M', 'IY0', 'Z'): ["armey's", 'armies', "army's"],
#  ('AA1', 'R', 'M', 'T', 'EH2', 'K'): ['armtec', 'armtek'],
#  ('AA1', 'R', 'N'): ['arn', 'arne', 'arnn'],
#  ('AA1', 'R', 'N', 'AH0', 'L'): ['arnal', 'arnall', 'arnell'],
#  ('AA0', 'R', 'N', 'EH1', 'T'): ['arnett', 'arnette'],
#  ('AA1', 'R', 'N', 'IY0'): ['arney', 'arnie'],
#  ('AA1', 'R', 'N', 'OW0'): ['arno', 'arnow'],
#  ('AA1', 'R', 'N', 'AH0', 'L', 'D', 'Z'): ["arnold's", 'arnolds'],
#  ('AE1', 'R', 'OW0', 'Z'): ["arrow's", 'arrows'],
#  ('EH1', 'R', 'OW0', 'Z'): ["arrow's", 'arrows'],
#  ('AA1', 'R', 'T', 'S'): ["art's", 'arts', 'artz'],
#  ('AA1', 'R', 'T', 'IY0', 'Z'): ['artes', "arty's"],
#  ('AA1', 'R', 'TH', 'ER0', 'Z'): ["arthur's", 'arthurs'],
#  ('AA1', 'R', 'T', 'IH0', 'K', 'AH0', 'L', 'Z'): ["article's", 'articles'],
#  ('AA1', 'R', 'T', 'IY0'): ['artie', 'arty'],
#  ('AA1', 'R', 'T', 'IH0', 'S', 'T', 'S'): ["artist's", 'artists', "artists'"],
#  ('AA1', 'S', 'AH0'): ['asa', 'ossa'],
#  ('AH0', 'S', 'EH1', 'N', 'D', 'AH0', 'N', 'S', 'IY0'): ['ascendancy',
#   'ascendency'],
#  ('AH0', 'S', 'EH1', 'N', 'T'): ['ascent', 'assent'],
#  ('AE1', 'SH'): ['asch', 'asche', 'ash', 'ashe'],
#  ('AE1', 'SH', 'ER0'): ['ascher', 'asher', 'ashur'],
#  ('AE1', 'SH', 'AH0', 'Z'): ["ashe's", 'ashes'],
#  ('AE1', 'SH', 'V', 'IH2', 'L'): ['asheville', 'ashville'],
#  ('AE1', 'SH', 'IY0'): ['ashey', 'ashy'],
#  ('AE1', 'S', 'T'): ['asked', 'assed', 'ast'],
#  ('AE1', 'S', 'K', 'ER0', 'Z'): ["asker's", 'askers', "askers'"],
#  ('AE1', 'S', 'P', 'AH0', 'N', 'Z'): ["aspen's", 'aspens'],
#  ('AH0', 'S', 'EY1', 'L', 'AH0', 'N', 'T', 'S'): ["assailant's", 'assailants'],
#  ('AH0', 'S', 'AE1', 'S', 'AH0', 'N', 'Z'): ["assassin's", 'assassins'],
#  ('AH0', 'S', 'EH1', 'M', 'B', 'L', 'IY0', 'Z'): ['assemblies', "assembly's"],
#  ('AH0', 'S', 'AY1', 'N', 'M', 'AH0', 'N', 'T', 'S'): ["assignment's",
#   'assignments'],
#  ('AH0', 'S', 'OW1', 'S', 'IY0', 'AH0', 'T', 'S'): ["associate's",
#   'associates',
#   "associates'"],
#  ('AH0', 'S', 'OW1', 'SH', 'IY0', 'AH0', 'T', 'S'): ["associate's",
#   'associates',
#   "associates'"],
#  ('AH0',
#   'S',
#   'OW2',
#   'SH',
#   'IY0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N',
#   'Z'): ["association's", 'associations'],
#  ('AA1', 'S', 'T', 'AH0'): ['asta', 'hasta'],
#  ('AE1', 'S', 'T', 'ER0'): ['aster', 'astor'],
#  ('AE1', 'S', 'T', 'ER0', 'OY2', 'D', 'Z'): ["asteroid's", 'asteroids'],
#  ('AE1', 'S', 'T', 'ER0', 'Z'): ['asters', "astor's"],
#  ('AE1', 'S', 'T', 'R', 'AH0', 'N', 'AO2', 'T', 'S'): ['astronauts',
#   "astronauts'"],
#  ('AE1', 'CH', 'IH0', 'S', 'AH0', 'N'): ['atcheson', 'atchison'],
#  ('EY1', 'T'): ['ate', 'aydt', 'eight'],
#  ('EY1', 'T', 'AH0', 'N'): ['aten', 'eyton'],
#  ('EY1', 'T', 'S'): ['ates', 'aytes', "eight's", 'eights'],
#  ('AE1', 'TH', 'AH0', 'N', 'Z'): ['athans', 'athens'],
#  ('AE1', 'TH', 'L', 'IY2', 'T', 'S'): ["athlete's", 'athletes', "athletes'"],
#  ('AE1', 'T', 'K', 'IH0', 'S', 'AH0', 'N'): ['atkison',
#   'atkisson',
#   'attkisson'],
#  ('AE0', 'T', 'L', 'AE1', 'N', 'T', 'IH0', 'S'): ['atlantis', "atlantis'"],
#  ('AE0', 'T', 'L', 'AE1', 'N', 'T', 'IH0', 'S', 'IH0', 'Z'): ["atlantis'",
#   "atlantis's"],
#  ('AE1', 'T', 'L', 'AH0', 'S', 'IH0', 'Z'): ["atlas's", 'atlases'],
#  ('AE1', 'T', 'L', 'IY0'): ['atley', 'attlee'],
#  ('AE1', 'T', 'B', 'EH0', 'R', 'IY0'): ['atteberry', 'attebury'],
#  ('AH0', 'T', 'EH1', 'N', 'D', 'AH0', 'N', 'T', 'S'): ["attendant's",
#   'attendants',
#   "attendants'"],
#  ('AH0', 'T', 'ER1', 'N', 'IY0', 'Z'): ["attorney's",
#   'attorneys',
#   "attorneys'"],
#  ('AE1', 'T', 'W', 'UH2', 'D'): ['attwood', 'atwood'],
#  ('OW1',): ['au',
#   'aux',
#   'eau',
#   'eaux',
#   'o',
#   "o'",
#   'o.',
#   'oh',
#   'ohh',
#   'ow',
#   'owe'],
#  ('AO1', 'B', 'R', 'IY0'): ['aubrey', 'aubry', 'awbrey'],
#  ('AO1', 'K', 'SH', 'AH0', 'N', 'Z'): ["auction's", 'auctions'],
#  ('AO1', 'D'): ['aud', 'awed'],
#  ('OW0', 'D', 'EH1', 'T'): ['audet', 'audette'],
#  ('AW1', 'D', 'IY0', 'Z'): ["audi's", 'audis'],
#  ('AA1', 'D', 'IY0', 'AH0', 'N', 'S', 'AH0', 'Z'): ["audience's", 'audiences'],
#  ('AO1', 'D', 'IY0', 'AH0', 'N', 'S', 'AH0', 'Z'): ["audience's", 'audiences'],
#  ('AO1', 'D', 'IH0', 'T', 'ER0', 'Z'): ["auditor's", "auditors'"],
#  ('AO1', 'D', 'R', 'IY0'): ['audrey', 'audry'],
#  ('AW1',): ['aue', 'ow'],
#  ('AW1', 'ER0'): ['auer', 'hour', 'our'],
#  ('AO1', 'G', 'AH0', 'S', 'T'): ['aug', 'august', 'auguste'],
#  ('AO1', 'G', 'ER0'): ['auger', 'augur'],
#  ('AO1', 'G', 'ER0', 'Z'): ['augers', 'augurs'],
#  ('AO1', 'T'): ['aught', 'ot', 'ought'],
#  ('AO1', 'M', 'AH0', 'N'): ['auman', 'aumann'],
#  ('AO1', 'N'): ['aune', 'on'],
#  ('AO1', 'NG'): ['aung', 'ong'],
#  ('AO1', 'N', 'T', 'S'): ["aunt's", 'aunts', "aunts'"],
#  ('AO1', 'R', 'AH0'): ['aura', 'ora'],
#  ('AO1', 'R', 'AH0', 'L'): ['aural', 'oral', 'orel'],
#  ('AO1', 'R', 'AH0', 'N', 'D'): ['aurand', 'orand'],
#  ('AO1', 'R', 'AH0', 'M'): ['aurum', 'oram', 'orum'],
#  ('AW1', 'S', 'T', 'AH0', 'L'): ['austell', 'austill'],
#  ('AO1', 'S', 'T', 'AH0', 'N'): ['austin', 'auston'],
#  ('AO0', 'S', 'T', 'R', 'EY1', 'L', 'Y', 'AH0', 'N', 'Z'): ["australian's",
#   'australians'],
#  ('AW1', 'T', 'AH0', 'N'): ['auten', 'outen', 'outten'],
#  ('AO1', 'TH', 'ER0'): ['auther', 'author'],
#  ('AO1', 'TH', 'ER0', 'Z'): ["author's", 'authors', "authors'"],
#  ('AH0', 'TH', 'AO1', 'R', 'IH0', 'T', 'IY0', 'Z'): ["authorities'",
#   "authority's"],
#  ('AO1', 'T', 'OW0', 'Z'): ["auto's", 'autos'],
#  ('AO1', 'T', 'OW0', 'M', 'EY2', 'K', 'ER0', 'Z'): ["automaker's",
#   'automakers',
#   "automakers'"],
#  ('AO1', 'T', 'R', 'IY0'): ['autrey', 'autry', 'awtrey'],
#  ('EY1', 'V', 'AH0'): ['ava', 'eva'],
#  ('AE1', 'V', 'AH0', 'N', 'UW2', 'Z'): ["avenue's", 'avenues'],
#  ('AE1', 'V', 'R', 'IH0', 'JH', 'IH0', 'Z'): ["average's", 'averages'],
#  ('EY1', 'V', 'IY0'): ['avey', 'avi'],
#  ('EY2', 'V', 'IY0', 'EY1', 'SH', 'AH0', 'N'): ['aviacion', 'aviation'],
#  ('AH0', 'V', 'IH1', 'L', 'AH0'): ['avila', 'avilla'],
#  ('AO1',): ['aw', 'awe'],
#  ('AE1', 'K', 'S', 'AH0', 'L'): ['axel', 'axle'],
#  ('EY1', 'ER0', 'Z'): ['ayars', 'ayers'],
#  ('AY1', 'ER0'): ['ayer', 'eyer', 'iyer'],
#  ('AY1', 'ER0', 'Z'): ['ayers', "i'ers"],
#  ('AY1', 'G', 'AH0', 'N'): ['aygen', 'eigen', 'igon'],
#  ('EY1', 'S', 'K', 'Y', 'UW0'): ['ayscue', 'escue'],
#  ('B', 'IY1'): ['b', 'b.', 'be', 'bea', 'bee'],
#  ('B', 'AH0', 'N', 'EY1'): ["b'nai", 'benet'],
#  ('B', 'IY1', 'Z'): ["b's",
#   "b.'s",
#   'b.s',
#   "be's",
#   'beas',
#   "bee's",
#   'bees',
#   'beese',
#   'bes'],
#  ('B', 'IY2', 'S', 'IY1'): ['b.c.', 'bc'],
#  ('B', 'AA1'): ['ba', 'bah'],
#  ('B', 'AA1', 'B'): ['baab', 'bob', 'bobb'],
#  ('B', 'AA1', 'K'): ['baack', 'bach', 'boch', 'bock', 'bohlke', 'bok'],
#  ('B', 'AA1', 'L', 'B', 'EH0', 'K'): ['baalbek', 'baalbeq'],
#  ('B', 'AA1', 'R'): ['baar', 'bahr', 'bahre', 'bar', 'barr', 'barre'],
#  ('B', 'AA1', 'R', 'Z'): ['baars',
#   "bar's",
#   "barr's",
#   'barres',
#   'barrs',
#   'bars',
#   'barz'],
#  ('B', 'AA1', 'SH'): ['baasch', 'bosh'],
#  ('B', 'AA1', 'T', 'S'): ['baatz', 'botts', 'botz'],
#  ('B', 'AE1', 'B'): ['bab', 'babb'],
#  ('B', 'AH1', 'B', 'AH0'): ['baba', 'bubba'],
#  ('B', 'AE1', 'B', 'IH0', 'T'): ['babbit', 'babbitt'],
#  ('B', 'AE1', 'B', 'AH0', 'T', 'S'): ["babbitt's", 'babbitts'],
#  ('B', 'AE1', 'B', 'AH0', 'L'): ['babble', 'babel'],
#  ('B', 'AE1', 'B', 'Z'): ['babbs', 'babs'],
#  ('B', 'AA1', 'B', 'IH0', 'K'): ['babic', 'babik', 'bobick'],
#  ('B', 'EY1', 'B', 'IY0', 'Z'): ['babies', "babies'", "baby's"],
#  ('B', 'AE1', 'B', 'IH0', 'N', 'OW2'): ['babineau', 'babineaux'],
#  ('B', 'AH0', 'B', 'IH1', 'N', 'S', 'K', 'IY0'): ['babinski', 'bobinski'],
#  ('B', 'AE0', 'B', 'UW1', 'N', 'Z'): ["baboon's", 'baboons'],
#  ('B', 'AH0', 'B', 'UW1', 'N', 'Z'): ["baboon's", 'baboons'],
#  ('B', 'EY1', 'B', 'IY0', 'S', 'IH2', 'T', 'ER0'): ['baby-sitter',
#   'babysitter'],
#  ('B', 'EY1', 'B', 'IY0', 'S', 'IH2', 'T', 'ER0', 'Z'): ['baby-sitters',
#   'babysitters'],
#  ('B', 'AE1', 'K', 'IH0', 'S'): ['bacchus', 'bacus'],
#  ('B', 'AE1', 'K', 'AH0', 'S'): ['baccus', 'backus', 'baucus'],
#  ('B', 'AA1', 'K', 'ER0'): ['bachar', 'bacher'],
#  ('B', 'AE1', 'CH'): ['bache', 'batch'],
#  ('B', 'AE1', 'CH', 'IH0', 'Z'): ["bache's", 'batches'],
#  ('B', 'AE1', 'CH', 'AH0', 'L', 'ER0'): ['bachelor',
#   'batcheller',
#   'batchelor'],
#  ('B', 'AE1', 'CH', 'L', 'ER0', 'Z'): ["bachelor's", 'bachelors'],
#  ('B', 'AA1', 'K', 'M', 'AH0', 'N'): ['bachman', 'bachmann', 'bockman'],
#  ('B', 'AA1', 'K', 'N', 'ER0'): ['bachner', 'bochner'],
#  ('B', 'AE1', 'K', 'T', 'AH0', 'L'): ['bachtel', 'bachtell'],
#  ('B', 'AE1', 'K'): ['back', 'backe', 'bak', 'bakke'],
#  ('B', 'AE1', 'K', 'S'): ["back's", 'backes', 'backs', 'bax'],
#  ('B', 'AE1', 'K', 'AH2', 'P'): ['back-up', 'backup'],
#  ('B', 'AE1', 'K', 'ER0'): ['backer', 'bakker'],
#  ('B', 'AE1', 'K', 'ER0', 'Z'): ["backer's", 'backers', "bakker's", 'bakkers'],
#  ('B', 'AE1', 'D', 'AE2', 'S'): ['bad-ass', 'badass'],
#  ('B', 'EY1', 'D'): ['bade', 'bayed'],
#  ('B', 'AH0', 'D', 'OW1'): ['badeau', 'badeaux'],
#  ('B', 'AE1', 'JH', 'ER0', 'Z'): ["badger's", 'badgers'],
#  ('B', 'AE1', 'D', 'L', 'IY0'): ['badley', 'badly'],
#  ('B', 'AY1'): ['bae', 'bi', 'buy', 'by', 'bye'],
#  ('B', 'EH1', 'K', 'ER0'): ['baecker', 'becher', 'becker', 'beker', 'bekker'],
#  ('B', 'IY1', 'R'): ['baehr', 'bier'],
#  ('B', 'EH1', 'R'): ['baehr', 'baer', 'bahr', 'bair', 'bare', 'bear', 'behr'],
#  ('B', 'IY1', 'K'): ['baek', 'beak', 'beeck', 'beek'],
#  ('B', 'EH1', 'K'): ['baek', 'bec', 'beck'],
#  ('B', 'EH1', 'T', 'AH0', 'N'): ['baeten', 'betten', 'betton'],
#  ('B', 'IY1', 'T', 'S'): ['baetz', 'beats', 'beets', 'beitz', 'bietz'],
#  ('B', 'AE1', 'G'): ['bag', 'bagg', 'bagge'],
#  ('B', 'EY1', 'G', 'AH0', 'N'): ['bagan', 'begun'],
#  ('B', 'AE1', 'G', 'D', 'AE0', 'D'): ['bagdad', 'baghdad'],
#  ('B', 'EY1', 'G', 'AH0', 'L'): ['bagel', 'begel'],
#  ('B', 'AE1', 'G', 'IY0'): ['baggie', 'baggy'],
#  ('B', 'AE1', 'G', 'Z'): ['baggs', 'bags'],
#  ('B', 'AE1', 'G', 'L', 'IY0'): ['baghli', 'bagley'],
#  ('B', 'AE1', 'G', 'N', 'AH0', 'L'): ['bagnall', 'bagnell'],
#  ('B', 'AA1', 'L'): ['bahl', 'bol', 'bolle'],
#  ('B', 'AA1', 'L', 'ER0'): ['bahler', 'boller'],
#  ('B', 'AE1', 'M'): ['bahm', 'bam'],
#  ('B', 'AE1', 'N'): ['bahn', 'ban', 'banh', 'bann'],
#  ('B', 'AA1', 'N', 'ER0'): ['bahner', 'bonnor'],
#  ('B', 'AA1', 'T'): ['baht', 'bhatt', 'bott', 'bought'],
#  ('B', 'AY2', 'D', 'OW1', 'AH0', 'Z'): ["baidoa's", 'baidoas'],
#  ('B', 'AY2', 'D', 'OW1', 'AH0', 'N', 'Z'): ["baidoan's", 'baidoans'],
#  ('B', 'EY1', 'ER0'): ['baier', 'bayar', 'bayer', 'beyer'],
#  ('B', 'EY1', 'G'): ['baig', 'begue'],
#  ('B', 'EY1', 'L'): ['bail', 'baile', 'bale', 'balle', 'bayle', 'beyl'],
#  ('B', 'EY1', 'L', 'ER0'): ['bailer', 'bailor', 'baler', 'baylor'],
#  ('B', 'EY1', 'L', 'Z'): ['bailes', 'bails', 'bales', 'balles', 'bayles'],
#  ('B', 'EY1', 'L', 'IY0'): ['bailey',
#   'bailie',
#   'baillie',
#   'bailly',
#   'baily',
#   'baley',
#   'bally',
#   'baylee',
#   'bayley',
#   'bayly'],
#  ('B', 'EY1', 'L', 'IY0', 'Z'): ["bailey's", 'baileys', "bally's"],
#  ('B', 'EY1', 'L', 'IH0', 'F'): ['bailiff', 'bayliff'],
#  ('B', 'EY1', 'L', 'IH0', 'N'): ['bailin', 'bailyn', 'beilin'],
#  ('B', 'EY1', 'L', 'IH0', 'NG'): ['bailing', 'baling'],
#  ('B', 'EY1', 'L', 'AH0', 'N'): ['bailon', 'balan', 'baylen'],
#  ('B', 'EY1', 'M'): ['baim', 'bame', 'boehm', 'boehme'],
#  ('B', 'EY1', 'N'): ['bain', 'baine', 'bane', 'bayne'],
#  ('B', 'EY1', 'N', 'Z'): ["bain's", 'baines', 'bains', 'banes', 'baynes'],
#  ('B', 'EY1', 'N', 'ER0', 'D'): ['bainerd', 'baynard'],
#  ('B', 'EH1', 'R', 'D'): ['baird', 'bared'],
#  ('B', 'EY1', 'Z'): ['baise',
#   'baize',
#   "bay's",
#   'bayes',
#   'bays',
#   'bayse',
#   'baze'],
#  ('B', 'EY1', 'T'): ['bait', 'bate', 'beit'],
#  ('B', 'EY1', 'T', 'IH0', 'D'): ['baited', 'bated'],
#  ('B', 'EY1', 'T', 'S'): ['baits', 'bates', "bates'"],
#  ('B', 'EY1', 'T', 'IY0'): ['baity', 'batey', 'batie', 'baty', 'beatty'],
#  ('B', 'EY1', 'K', 'ER0'): ['baker', 'bakker'],
#  ('B', 'EY1', 'K', 'ER0', 'Z'): ["baker's", 'bakers', "bakker's", 'bakkers'],
#  ('B', 'AE1', 'K', 'S', 'T'): ['bakst', 'baxt'],
#  ('B', 'AA1', 'L', 'AH0'): ['bala', 'bolla'],
#  ('B', 'AE1', 'L', 'AH0', 'S'): ['balas', 'ballasts'],
#  ('B', 'EY1', 'L', 'S', 'ER0'): ['balcer', 'balser'],
#  ('B', 'AE1', 'L', 'K', 'AH0', 'M'): ['balcom', 'balkcom'],
#  ('B', 'AO1', 'L', 'D'): ['bald', 'balled', 'bawled'],
#  ('B', 'AA0', 'L', 'D', 'AA0', 'S', 'AA1', 'R', 'IY0'): ['baldassare',
#   'baldassari'],
#  ('B', 'AO1', 'L', 'D', 'ER0'): ['balder', 'baldor'],
#  ('B', 'AA0', 'L', 'EH0', 'N', 'T', 'IY1', 'N', 'IY0'): ['balentine',
#   'ballentine'],
#  ('B', 'AA1', 'L', 'IH0', 'K'): ['balik', 'bolich', 'bolick'],
#  ('B', 'AE1', 'L', 'IH0', 'N'): ['balin', 'ballin'],
#  ('B', 'AO1', 'L'): ['ball', 'bawl'],
#  ('B', 'AO1', 'L', 'Z'): ["ball's", 'balls', 'balz', 'bawls'],
#  ('B', 'AO1', 'L', 'ER0'): ['baller', 'ballor'],
#  ('B', 'AE0', 'L', 'EY1', 'Z'): ["ballet's", 'ballets'],
#  ('B', 'AE1', 'L', 'IY0'): ['balli', 'bally'],
#  ('B', 'AE1', 'L', 'OW0'): ['ballo', 'ballow', 'balogh', 'balow'],
#  ('B', 'AA1', 'M'): ['balm', 'bohm', 'bom', 'bomb'],
#  ('B', 'AA1', 'M', 'ER0'): ['balmer', 'bomber', 'bommer'],
#  ('B', 'AA1', 'M', 'Z'): ['balms', "bomb's", 'bombs'],
#  ('B', 'AH0', 'L', 'OW1', 'N', 'IY0'): ['baloney', 'bologna'],
#  ('B', 'AE1', 'L', 'TH', 'AH0', 'S', 'ER0'): ['balthasar', 'balthaser'],
#  ('B', 'AE1', 'M', 'B', 'ER0', 'G'): ['bamberg', 'bamburg'],
#  ('B', 'AE1', 'N', 'Z'): ["ban's", 'bans', 'benz'],
#  ('B', 'AE1', 'NG', 'K'): ['banc', 'bank', 'banke', 'banque'],
#  ('B', 'AE1', 'NG', 'K', 'OW0'): ['banco', 'banko'],
#  ('B', 'AE1', 'N', 'D'): ['band', 'banned'],
#  ('B', 'AE1', 'N', 'D', 'Z'): ["band's", 'bands'],
#  ('B', 'AE1', 'NG', 'G', 'AH0', 'L', 'AO2', 'R'): ['bangalor', 'bangalore'],
#  ('B',
#   'AE1',
#   'NG',
#   'L',
#   'AH0',
#   'D',
#   'EH2',
#   'SH',
#   'IY0',
#   'Z'): ["bangladeshi's", 'bangladeshis'],
#  ('B', 'AE1', 'N', 'IH0', 'K'): ['banick', 'banik', 'bannick'],
#  ('B', 'AE1', 'N', 'IH0', 'S', 'T', 'ER0'): ['banister', 'bannister'],
#  ('B', 'AA1', 'N', 'Y', 'AH0'): ['banja', 'banya'],
#  ('B', 'AE1', 'NG', 'K', 'S'): ["bank's", 'bankes', 'banks', "banks'"],
#  ('B', 'AE1', 'NG', 'K', 'ER0', 'Z'): ["banker's", 'bankers', "bankers'"],
#  ('B', 'AH0', 'NG', 'K', 'AO1', 'F', 'S', 'K', 'IY0'): ['bankowski',
#   'bonkowski'],
#  ('B', 'AE1', 'NG', 'K', 'R', 'AH0', 'P', 'T', 'S', 'IY0'): ['bankrupcty',
#   'bankruptcy'],
#  ('B', 'AE1', 'N', 'AH0', 'N'): ['bannan', 'bannon'],
#  ('B', 'AE1', 'N', 'ER0', 'Z'): ["banner's", 'banners'],
#  ('B', 'AE1', 'N', 'T', 'AH0', 'M', 'Z'): ["bantam's", 'bantams'],
#  ('B', 'AW1'): ['bao', 'bough', 'bow'],
#  ('B', 'AA1', 'R', 'AH0'): ['bara', 'barra'],
#  ('B', 'AA1', 'R', 'AH0', 'K'): ['barack', 'barak'],
#  ('B', 'AE1', 'R', 'AH0', 'SH'): ['barasch', 'barash'],
#  ('B', 'AA1', 'R', 'B'): ['barb', 'barbe'],
#  ('B', 'AA1', 'R', 'B', 'Z'): ["barb's", 'barbs'],
#  ('B', 'AA1', 'R', 'B', 'R', 'AH0'): ['barbara', 'barbra'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2'): ['barbecue',
#   'barbeque',
#   'bbq'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2', 'Z'): ["barbecue's",
#   'barbecues',
#   'barbeques'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2', 'D'): ['barbecued',
#   'barbequed'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2', 'IH0', 'NG'): ['barbecueing',
#   'barbecuing',
#   'barbequeing'],
#  ('B', 'AA1', 'R', 'B', 'EH2', 'L'): ['barbel', 'barbell'],
#  ('B', 'AA1', 'R', 'B', 'ER0'): ['barber', 'barbour', 'barbre'],
#  ('B', 'AA1', 'R', 'B', 'ER0', 'Z'): ["barber's", 'barbers', "barbour's"],
#  ('B', 'AA1', 'R', 'B', 'IY0'): ['barbie', 'barby'],
#  ('B', 'AA1', 'R', 'B', 'IY0', 'Z'): ["barbie's", 'barbies'],
#  ('B', 'AA1', 'R', 'K'): ['barch', 'bark', 'barke'],
#  ('B', 'AA1', 'R', 'K', 'L', 'IY0', 'Z'): ["barclay's",
#   'barclays',
#   "barclays'"],
#  ('B', 'AA1', 'R', 'K', 'L', 'EY0', 'Z'): ["barclay's",
#   'barclays',
#   "barclays'"],
#  ('B', 'AA1', 'R', 'K', 'OW0'): ['barco', 'barko', 'barkow'],
#  ('B', 'AA1', 'R', 'K', 'AH0', 'S'): ['barcus', 'barkus'],
#  ('B', 'AA1', 'R', 'D'): ['bard', 'barred'],
#  ('B', 'AA1', 'R', 'D', 'AH0', 'L', 'F'): ['bardulf', 'bardulph'],
#  ('B', 'EH1', 'R', 'AH0', 'N', 'Z'): ['barens',
#   "baron's",
#   'barons',
#   'behrens'],
#  ('B', 'EH1', 'R', 'Z'): ['bares',
#   "bear's",
#   'bears',
#   "bears'",
#   'berres',
#   'bures'],
#  ('B', 'EH1', 'R', 'IY0'): ['barey',
#   'barre',
#   'barrie',
#   'barry',
#   'berrey',
#   'berri',
#   'berrie',
#   'berry',
#   'buerry',
#   'bury'],
#  ('B', 'AA1', 'R', 'G', 'M', 'AH0', 'N'): ['bargman', 'bargmann'],
#  ('B', 'AA1', 'R', 'IY0', 'Z'): ["bari's", 'baris'],
#  ('B', 'AE1', 'R', 'IH0', 'K'): ['barich', 'barrick'],
#  ('B', 'EH1', 'R', 'AH0', 'L'): ['baril',
#   'barrel',
#   'behrle',
#   'berrill',
#   'beryl',
#   'burel',
#   'burell'],
#  ('B', 'EH1', 'R', 'IH0', 'NG'): ['baring', 'bearing', 'behring', 'bering'],
#  ('B', 'EH1', 'R', 'IH0', 'NG', 'Z'): ["baring's",
#   'barings',
#   "barings'",
#   'bearings'],
#  ('B', 'EH1', 'R', 'IH0', 'NG', 'ER0'): ['baringer',
#   'behringer',
#   'beringer',
#   'berringer'],
#  ('B', 'EH1', 'R', 'IH0', 'SH'): ['barish', 'bearish', 'buresh'],
#  ('B', 'AA1', 'R', 'K', 'D', 'AH0', 'L'): ['barkdoll', 'barkdull'],
#  ('B', 'AA1', 'R', 'K', 'L', 'IY0'): ['barkeley', 'barkley'],
#  ('B', 'AA1', 'R', 'K', 'S'): ['barkes', 'barks'],
#  ('B', 'AA1', 'R', 'L', 'OW2'): ['barlow', 'barlowe'],
#  ('B', 'AA1', 'R', 'N', 'Z'): ['barnes', 'barns'],
#  ('B', 'AA1', 'R', 'N', 'IY0'): ['barney', 'barny'],
#  ('B', 'AA1', 'R', 'N', 'IY0', 'Z'): ["barney's", 'barneys'],
#  ('B', 'AA1', 'R', 'N', 'HH', 'AA2', 'R', 'T'): ['barnhardt', 'barnhart'],
#  ('B', 'AA1', 'R', 'OW0'): ['baro', 'barro'],
#  ('B', 'AE1', 'R', 'AH0', 'N'): ['baron', 'barren', 'barron'],
#  ('B', 'EH1', 'R', 'AH0', 'N'): ['baron', 'barren', 'beran', 'beron'],
#  ('B', 'AE1', 'R', 'AH0', 'N', 'Z'): ["baron's",
#   'barons',
#   'barrens',
#   "barron's"],
#  ('B', 'ER0', 'OW1', 'N'): ['barone', 'barrone'],
#  ('B', 'AA1', 'R', 'OW0', 'Z'): ['baros', 'barros', 'borrows'],
#  ('B', 'AE1', 'R', 'IH0', 'T'): ['barret', 'barrett'],
#  ('B', 'AA0', 'R', 'EH1', 'T', 'OW0'): ['barreto', 'barretto'],
#  ('B', 'EH1', 'R', 'IH0', 'T'): ['barrett', 'berrett'],
#  ('B', 'EH1', 'R', 'IH0', 'K'): ['barrick', 'burek', 'burich'],
#  ('B', 'AE1', 'R', 'IY0'): ['barrie', 'barry'],
#  ('B', 'EH1', 'R', 'IY0', 'ER0'): ['barrier', 'berrier'],
#  ('B', 'EH0', 'R', 'IY1', 'OW0', 'Z'): ['barrios', 'berrios'],
#  ('B', 'EH1', 'R', 'OW0'): ['barrow', 'bero'],
#  ('B', 'EH1', 'R', 'IY0', 'Z'): ["barry's",
#   'berries',
#   'berris',
#   "berry's",
#   'buries',
#   "bury's"],
#  ('B', 'AA1', 'R', 'SH'): ['barsch', 'barsh'],
#  ('B', 'AA1', 'R', 'T', 'S'): ["bart's", 'barts', 'bartz'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'K'): ['bartak', 'bartok'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'L'): ['bartel', 'bartl', 'bartle', 'bartol'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'L', 'Z'): ['bartels', 'bartles'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'N'): ['barten', 'barton'],
#  ('B', 'AA1', 'R', 'T', 'N', 'IH0', 'K'): ['bartnick', 'bartnik'],
#  ('B', 'AE1', 'SH'): ['basch', 'bash'],
#  ('B', 'EY1', 'S'): ['base', 'bass'],
#  ('B', 'EY1', 'S', 'AH0', 'Z'): ["base's", 'bases'],
#  ('B', 'EY1', 'S', 'B', 'AO1', 'L', 'Z'): ["baseball's", 'baseballs'],
#  ('B', 'EY1', 'S', 'T'): ['based', 'baste'],
#  ('B', 'EY1', 'S', 'IH0', 'Z'): ['bases', "bass's", 'basses'],
#  ('B', 'EY1', 'S', 'IY0'): ['basey', 'basi'],
#  ('B', 'AE1', 'S', 'F', 'ER0', 'D'): ['basford', 'bassford'],
#  ('B', 'AA1', 'SH', 'AH0'): ['basha', 'bhatia'],
#  ('B', 'AE1', 'SH', 'AH0', 'M'): ['basham', 'bassham'],
#  ('B', 'AE1', 'SH', 'ER0'): ['basher', 'bashor', 'bashore'],
#  ('B', 'EY1', 'S', 'IH0', 'K', 'S'): ["basic's", 'basics', 'basix'],
#  ('B', 'AE1', 'Z', 'AH0', 'L'): ['basil', 'bazzell', 'bazzle'],
#  ('B', 'AE1', 'S', 'K'): ['bask', 'basque'],
#  ('B', 'AE1', 'S', 'K', 'AH0', 'T', 'B', 'AO2', 'L', 'Z'): ["basketball's",
#   'basketballs'],
#  ('B', 'AE1', 'S', 'K', 'S'): ['basks', 'basques'],
#  ('B', 'AE1', 'S'): ['bass', 'basse'],
#  ('B', 'AE1', 'S', 'IH0', 'Z'): ["bass's", 'basses'],
#  ('B', 'AE1', 'S', 'IH0', 'T'): ['basset', 'bassett'],
#  ('B', 'AE1', 'S', 'T', 'ER0', 'D', 'Z'): ["bastard's", 'bastards'],
#  ('B', 'AE1', 'S', 'T', 'AH0', 'N'): ['bastien', 'baston'],
#  ('B', 'AE1', 'T'): ['bat', 'batt', 'batte', 'bhatt'],
#  ('B', 'AH0', 'T', 'AA1', 'N'): ['bataan', 'baton', 'bhutan'],
#  ('B', 'AE1', 'T', 'IH0', 'S', 'AH0', 'N'): ['bateson', 'battison'],
#  ('B', 'AE1', 'T', 'S', 'AH0', 'N'): ['bateson', 'batson'],
#  ('B', 'AE1', 'T', 'AH0', 'N'): ['baton', 'batten', 'batton'],
#  ('B', 'AE1', 'T', 'S'): ['bats', 'batts', 'batz'],
#  ('B', 'AE1', 'T', 'IY0'): ['battey', 'batty'],
#  ('B', 'AA0', 'T', 'IY1', 'S', 'T', 'IY0'): ['battiste', 'battisti'],
#  ('B', 'AE1', 'T', 'AH0', 'L', 'Z'): ["battle's", 'battles'],
#  ('B', 'AO1', 'B', 'AH0', 'L'): ['bauble', 'bobble'],
#  ('B', 'AO1', 'B', 'AH0', 'L', 'Z'): ['baubles', 'bobbles'],
#  ('B', 'AA1', 'K', 'AH0', 'S'): ['baucus', 'bockus'],
#  ('B', 'AO1', 'D'): ['baud', 'bawd'],
#  ('B', 'AW1', 'ER0'): ['bauer', 'baur', 'bougher', 'bower'],
#  ('B', 'AW1', 'ER0', 'Z'): ['bauers', 'bowers'],
#  ('B', 'AO1', 'ER0'): ['baugher', 'bawer'],
#  ('B', 'AO1', 'N'): ['baughn', 'baun'],
#  ('B', 'AO1', 'M'): ['baum', 'bomb'],
#  ('B', 'AW1', 'M', 'AH0', 'N'): ['bauman', 'baumann', 'boughman', 'bouwman'],
#  ('B', 'AA1', 'M', 'B', 'ER0', 'G', 'ER0'): ['baumberger', 'bomberger'],
#  ('B', 'AA1', 'M', 'G', 'AA2', 'R', 'D', 'N', 'ER0'): ['baumgardner',
#   'bomgardner'],
#  ('B', 'AW1', 'M', 'G', 'AA2', 'R', 'T'): ['baumgardt', 'baumgart'],
#  ('B', 'AA1', 'M', 'G', 'AA2', 'R', 'T'): ['baumgardt', 'baumgart'],
#  ('B', 'AO1', 'R'): ['baur', 'boar', 'boer', 'bohr', 'bore', 'borre'],
#  ('B', 'AW1', 'CH'): ['bautch', 'bouch', 'bouche'],
#  ('B', 'AO1', 'T', 'S'): ['bautz', 'bots'],
#  ('B', 'EY1'): ['bay', 'baye', 'bayh', 'bey'],
#  ('B', 'EY1', 'B', 'AE2', 'NG', 'K', 'S'): ["baybank's", 'baybanks'],
#  ('B', 'EY1', 'ER0', 'Z'): ["bayer's", 'bayers', 'beyers'],
#  ('B', 'EY1', 'L', 'IH0', 'S'): ['bayless', 'baylis', 'bayliss'],
#  ('B', 'AH0', 'Z', 'AA1', 'R'): ['bazaar', 'bazar', 'bizarre'],
#  ('B', 'IY1', 'B', 'ER0'): ['beaber', 'beber', 'bieber'],
#  ('B', 'IY1', 'CH'): ['beach', 'beech'],
#  ('B', 'IY1', 'CH', 'AH0', 'Z'): ["beach's", 'beaches'],
#  ('B', 'IY1', 'CH', 'AH0', 'M'): ['beacham', 'beachum', 'beecham'],
#  ('B', 'IY1', 'CH', 'ER0'): ['beacher', 'beecher'],
#  ('B', 'IY1', 'CH', 'L', 'ER0'): ['beachler', 'beechler'],
#  ('B', 'IY1', 'CH', 'IY0'): ['beachy', 'beechy'],
#  ('B', 'IY1', 'D'): ['bead', 'bede', 'beede'],
#  ('B', 'IY1', 'D', 'AH0', 'L'): ['beadle', 'beedle'],
#  ('B', 'IY1', 'D', 'IY0'): ['beady', 'beedie', 'beedy'],
#  ('B', 'IY1', 'G', 'AH0', 'L'): ['beagle', 'beegle', 'biegel'],
#  ('B', 'IY1', 'G', 'AH0', 'L', 'Z'): ["beagle's", 'beagles'],
#  ('B', 'IY1', 'G', 'L', 'IY0'): ['beagley', 'beeghly'],
#  ('B', 'IY1', 'M'): ['beahm', 'beam', 'beem'],
#  ('B', 'IH1', 'R', 'D'): ['beaird', 'beard'],
#  ('B', 'IY1', 'K', 'ER0'): ['beaker', 'beeker', 'bieker'],
#  ('B', 'IY1', 'K', 'M', 'AH0', 'N'): ['beakman', 'beekman'],
#  ('B', 'IY1', 'L'): ['beal',
#   'beale',
#   'beall',
#   'beel',
#   'beil',
#   'biehl',
#   'biel'],
#  ('B', 'IY1', 'L', 'ER0'): ['bealer',
#   'beehler',
#   'beeler',
#   'biehler',
#   'bieler'],
#  ('B', 'IY1', 'L', 'Z'): ['beales', 'beals'],
#  ('B', 'IY1', 'M', 'Z'): ["beam's", 'beams'],
#  ('B', 'IY1', 'M', 'AH0', 'N'): ['beaman', 'beamon', 'beeman', 'beman'],
#  ('B', 'IY1', 'M', 'ER0'): ['beamer', 'beemer'],
#  ('B', 'IY1', 'N'): ['bean',
#   'beane',
#   'beene',
#   'bein',
#   'beine',
#   'biehn',
#   'bien'],
#  ('B', 'IY1', 'N', 'Z'): ["bean's", 'beans'],
#  ('B', 'EH1', 'R', 'AH0'): ['beara', 'bera', 'berra'],
#  ('B', 'ER1', 'S'): ['bearce', 'bearse', 'bearss', 'burse'],
#  ('B', 'IH1', 'R', 'D', 'Z', 'L', 'IY0'): ['beardslee', 'beardsley'],
#  ('B', 'IH1', 'R'): ['beare', 'beer', 'bere'],
#  ('B', 'ER1', 'F', 'IY0', 'L', 'D'): ['bearfield', 'burfield'],
#  ('B', 'EH1', 'R', 'M', 'AH0', 'N'): ['bearman', 'behrman', 'behrmann'],
#  ('B', 'IH1', 'R', 'IY0'): ['beary', 'beery', 'bieri', 'biery'],
#  ('B', 'IY1', 'Z', 'L', 'IY0'): ['beasley', 'beesley', 'beezley'],
#  ('B', 'IY1', 'Z', 'AH0', 'N'): ['beason', 'beeson'],
#  ('B', 'IY1', 'T'): ['beat', 'beet'],
#  ('B', 'IY1', 'T', 'AH0', 'N'): ['beaten', 'beaton', 'beeton'],
#  ('B', 'IY1', 'T', 'IY0'): ['beatie', 'beattie', 'beatty', 'beaty'],
#  ('B', 'IY1', 'T', 'AH0', 'L'): ['beatle', 'beetle'],
#  ('B', 'IY1', 'T', 'AH0', 'L', 'Z'): ['beatles', "beatles'", 'beetles'],
#  ('B', 'OW1'): ['beau', 'beaux', 'bo', 'boe', 'boeh', 'bow', 'bowe'],
#  ('B', 'OW1', 'S'): ['beauce', 'boese', 'bowse'],
#  ('B', 'OW2', 'SH', 'EY1', 'N'): ['beauchaine', 'beauchene'],
#  ('B', 'OW0', 'D', 'OY1', 'N'): ['beaudoin', 'bowdoin'],
#  ('B', 'EH1', 'V', 'AH0', 'N'): ['beavan', 'bevan', 'beven'],
#  ('B', 'IY1', 'V', 'ER0'): ['beaver', 'beever', 'biever'],
#  ('B', 'IY1', 'V', 'ER0', 'Z'): ['beavers', 'beevers'],
#  ('B', 'IY1', 'B', 'IY0'): ['bebe', 'beeby'],
#  ('B', 'IH0', 'B', 'OW1'): ['bebeau', 'bibeau', 'bibeault'],
#  ('B', 'EH1', 'K', 'L', 'ER0'): ['bechler', 'beckler'],
#  ('B', 'EH1', 'K', 'S'): ["beck's", 'becks'],
#  ('B', 'EH1', 'K', 'ER0', 'Z'): ["becker's", 'beckers', "beker's"],
#  ('B', 'EH1', 'K', 'IY0'): ['becki', 'beckie', 'becky', 'bekki'],
#  ('B', 'EH1', 'K', 'M', 'AH0', 'N'): ['beckman', 'beckmann'],
#  ('B', 'IY1', 'K', 'OW0'): ['beco', 'biko'],
#  ('B', 'EH1', 'D', 'IH0', 'NG', 'F', 'IY2', 'L', 'D'): ['beddingfield',
#   'bedingfield'],
#  ('B', 'EH1', 'D', 'OW0'): ['beddoe', 'beddow'],
#  ('B', 'EH1', 'D', 'N', 'ER0'): ['bednar', 'bedner'],
#  ('B', 'IY1', 'B', 'IY2', 'Z'): ["beebe's", 'beebes'],
#  ('B', 'IH1', 'N'): ['been', 'bihn', 'bin', 'binn'],
#  ('B', 'IH1', 'N', 'Z'): ['beens', 'binns', 'bins', 'binz'],
#  ('B', 'IY1', 'R', 'Z'): ["beer's", 'beres', 'biers'],
#  ('B', 'IH1', 'R', 'M', 'AH0', 'N'): ['beerman', 'bierman', 'biermann'],
#  ('B', 'IH1', 'R', 'Z'): ['beers', "beers'"],
#  ('B', 'EH1', 'G'): ['beg', 'begg'],
#  ('B', 'EH1', 'G', 'ER0'): ['beger', 'beggar'],
#  ('B', 'EH1', 'G', 'Z'): ['beggs', 'begs'],
#  ('B', 'IH0', 'G', 'IH1', 'N', 'Z'): ["begin's", 'begins'],
#  ('B', 'IH0', 'G', 'IH1', 'N', 'ER0', 'Z'): ["beginner's", 'beginners'],
#  ('B', 'IH0', 'HH', 'EY1', 'V', 'Y', 'ER0'): ['behavior', 'behaviour'],
#  ('B', 'IH0', 'HH', 'EY1', 'V', 'Y', 'ER0', 'Z'): ['behaviors', 'behaviours'],
#  ('B', 'EH1', 'L'): ['behl', 'bel', 'bell', 'belle'],
#  ('B', 'EH1', 'L', 'ER0'): ['behler', 'bellar', 'beller'],
#  ('B', 'EH1', 'L', 'IH0', 'NG'): ['behling', 'belling'],
#  ('B', 'EH1', 'L', 'K'): ['behlke', "bel'c", 'belk', 'belke'],
#  ('B', 'EH1', 'M'): ['behm', 'bem'],
#  ('B', 'EH1', 'N'): ['behn', 'behne', 'ben', 'benn', 'benne'],
#  ('B', 'EH1', 'N', 'ER0'): ['behner', 'benner'],
#  ('B', 'EH1', 'N', 'IY0'): ['behney', 'beni', 'benney', 'bennie', 'benny'],
#  ('B', 'EH1', 'N', 'IH0', 'NG'): ['behning', 'bening', 'benning'],
#  ('B', 'EH1', 'NG', 'K'): ['behnke', 'benke'],
#  ('B', 'IY1', 'HH', 'AA0', 'F'): ['behof', 'behoff'],
#  ('B', 'EH1', 'R', 'EH0', 'N', 'D'): ['behrend', 'berend'],
#  ('B', 'EH1', 'R', 'EH0', 'N', 'D', 'Z'): ['behrends', 'berends'],
#  ('B', 'EH1', 'R', 'IH0', 'N', 'T'): ['behrendt', 'berendt'],
#  ('B', 'AY1', 'ER0'): ['beier', 'buyer', 'byer'],
#  ('B', 'EY1', 'ZH', 'AH0', 'Z'): ["beige's", 'beiges'],
#  ('B', 'AY1', 'L', 'ER0'): ['beiler', 'byler'],
#  ('B', 'EH1', 'L', 'IH0', 'N'): ['beilin', 'belin', 'bellin'],
#  ('B', 'IY1', 'L', 'K'): ['beilke', 'bielke'],
#  ('B', 'IY1', 'IH0', 'NG', 'Z'): ["being's", 'beings'],
#  ('B', 'IH1', 'R', 'N'): ['beirne', 'byrn'],
#  ('B', 'AY1', 'S', 'AH0', 'L'): ['beisel', 'beissel'],
#  ('B', 'AY1', 'T'): ['beit', 'bight', 'bite', 'byte'],
#  ('B', 'AY1', 'T', 'ER0'): ['beiter', 'biter'],
#  ('B', 'AY1', 'T', 'AH0', 'L', 'ER0'): ['beitler', 'bitler'],
#  ('B', 'AY1', 'T', 'L', 'ER0'): ['beitler', 'bitler'],
#  ('B', 'EH1', 'L', 'AH0'): ['bela', 'bella', 'bellah'],
#  ('B', 'IH0', 'L', 'EY1', 'B', 'ER0', 'Z'): ['belabores', 'belabors'],
#  ('B', 'EH1', 'L', 'AH0', 'N', 'D'): ['beland', 'belland'],
#  ('B', 'EH1', 'L', 'D', 'AH0', 'N'): ['belden', 'beldon'],
#  ('B', 'EH1', 'L', 'AH0', 'N'): ['belen', 'bellon'],
#  ('B', 'EH1', 'L', 'F', 'L', 'AW2', 'ER0'): ['belflower', 'bellflower'],
#  ('B', 'EH1', 'L', 'IY0'): ['beli', 'belli', 'belly'],
#  ('B', 'AH0', 'L', 'IH1', 'JH', 'ER0', 'AH0', 'N', 'S'): ['beligerence',
#   'belligerence'],
#  ('B', 'AH0', 'L', 'IH1', 'JH', 'ER0', 'AH0', 'N', 'T'): ['beligerent',
#   'belligerent'],
#  ('B', 'IH0', 'L', 'IH1', 'N', 'S', 'K', 'IY0'): ['belinsky',
#   'bielinski',
#   'bilinski'],
#  ('B', 'EH1', 'L', 'IH0', 'V', 'OW2'): ['beliveau', 'belliveau'],
#  ('B', 'EH1', 'L', 'Z'): ["bell's",
#   'belles',
#   'bells',
#   "bells'",
#   'bels',
#   'belz'],
#  ('B', 'EH1', 'L', 'AH0', 'M', 'IY0'): ['bellamy', 'bellomy'],
#  ('B', 'IH0', 'L', 'AA1', 'R', 'D'): ['bellard', 'billard'],
#  ('B', 'IH0', 'L', 'OW1'): ['belleau', 'below'],
#  ('B', 'EH1', 'L', 'M', 'AH0', 'N'): ['bellman', 'bellmon', 'belman'],
#  ('B', 'EH1', 'L', 'M', 'AO0', 'R'): ['bellmore', 'belmore'],
#  ('B', 'EH1', 'L', 'OW0'): ['bello', 'bellow', 'belo'],
#  ('B', 'EH0', 'L', 'OW1', 'T', 'IY0'): ['bellotti', 'belote'],
#  ('B', 'EH1', 'L', 'OW0', 'Z'): ["bellow's", 'bellows'],
#  ('B', 'EH1', 'L', 'V', 'IH2', 'L'): ['bellville', 'belville'],
#  ('B', 'EH1', 'L', 'T', 'S'): ["belt's", 'belts', 'beltz'],
#  ('B', 'EH1', 'N', 'Z'): ["ben's", 'bens', 'benz'],
#  ('B', 'EH1', 'N', 'AH0'): ['bena', 'bene'],
#  ('B', 'EH1', 'N', 'AH0', 'K'): ['benak', 'benecke', 'beneke'],
#  ('B', 'EH1', 'N', 'CH', 'M', 'AA2', 'R', 'K', 'S'): ["benchmark's",
#   'benchmarks'],
#  ('B', 'EH1', 'N', 'D', 'AH0', 'L'): ['bendall', 'bendel', 'bendele'],
#  ('B', 'EH1', 'N', 'D', 'ER0', 'Z'): ["bender's", 'benders'],
#  ('B', 'EH1', 'N', 'T'): ['bendt', 'bent', 'bente'],
#  ('B', 'EH1', 'N', 'AH0', 'D', 'IH0', 'K'): ['benedek', 'benedick'],
#  ('B',
#   'EH2',
#   'N',
#   'AH0',
#   'D',
#   'IH1',
#   'K',
#   'T',
#   'IY0',
#   'N',
#   'Z'): ["benedictine's", 'benedictines'],
#  ('B', 'EH1', 'N', 'AH0', 'F', 'AE2', 'K', 'T', 'ER0', 'Z'): ["benefactor's",
#   'benefactors'],
#  ('B',
#   'EH2',
#   'N',
#   'AH0',
#   'F',
#   'IH1',
#   'SH',
#   'IY0',
#   'EH2',
#   'R',
#   'IY0',
#   'Z'): ['beneficiaries', "beneficiary's"],
#  ('B', 'EH1', 'N', 'AH0', 'F', 'IH0', 'T', 'IH0', 'NG'): ['benefiting',
#   'benefitting'],
#  ('B', 'EH1', 'N', 'AH0', 'SH'): ['benesch', 'benesh'],
#  ('B', 'EH1', 'N', 'AH0', 'T'): ['benet', 'bennett'],
#  ('B', 'EH1', 'N', 'AH0', 'T', 'S'): ["benet's", "bennett's"],
#  ('B', 'EH1', 'NG', 'G', 'AH0', 'L'): ['bengal', 'bengel'],
#  ('B', 'AH0', 'N', 'IY1', 'T', 'OW0'): ['benito', 'bonito'],
#  ('B', 'EH1', 'N', 'IH0', 'T'): ['bennet', 'bennett', 'bennitt'],
#  ('B', 'IH0', 'N', 'EH1', 'T'): ['bennette', 'binette'],
#  ('B', 'EH1', 'N', 'S', 'AH0', 'N'): ['bensen', 'benson'],
#  ('B', 'EH1', 'T', 'IH0', 'N'): ['benten', 'bettin'],
#  ('B', 'EH1', 'N', 'T', 'L', 'IY0'): ['bentley', 'bently'],
#  ('B', 'EH1', 'N', 'T', 'S', 'AH0', 'N'): ['bentsen', 'bentson'],
#  ('B', 'EH1', 'N', 'Z', 'IH0', 'Z'): ["benz's", 'benzes'],
#  ('B', 'EH1', 'N', 'Z', 'IY0', 'N'): ['benzene', 'benzine'],
#  ('B', 'ER0', 'AA1', 'R', 'D'): ['berard', 'berrard'],
#  ('B', 'ER1', 'K'): ['berch',
#   'berk',
#   'berke',
#   'birk',
#   'bourke',
#   'burck',
#   'burk',
#   'burke'],
#  ('B', 'ER1', 'D', 'AH0', 'N'): ['berdan', 'birden', 'burden', 'burdon'],
#  ('B', 'ER1', 'G'): ['berg', 'bergh', 'burg', 'burge'],
#  ('B', 'ER1', 'G', 'Z'): ["berg's", 'bergs', 'burges'],
#  ('B', 'ER1', 'G', 'AH0', 'N'): ['bergan', 'bergen'],
#  ('B', 'ER1', 'JH'): ['berge', 'birge', 'burdge'],
#  ('B', 'ER1', 'G', 'M', 'AH0', 'N'): ['bergeman',
#   'bergemann',
#   'bergman',
#   'bergmann',
#   'burgman'],
#  ('B', 'ER1', 'G', 'ER0'): ['berger', 'burger', 'burgher'],
#  ('B', 'ER1', 'G', 'ER0', 'Z'): ["berger's", "burger's", 'burgers'],
#  ('B', 'ER1', 'G', 'IH0', 'S', 'AH0', 'N'): ['bergeson', 'burgeson'],
#  ('B', 'ER1', 'G', 'EH0', 'T'): ['berget', 'burget'],
#  ('B', 'ER1', 'JH', 'IY0'): ['bergey', 'burgy'],
#  ('B', 'ER1', 'G', 'R', 'EH0', 'N'): ['berggren', 'bergren'],
#  ('B', 'ER1', 'G', 'HH', 'AO0', 'F'): ['berghof', 'berghoff'],
#  ('B', 'ER1', 'G', 'L', 'IH0', 'NG'): ['bergling', 'burgling'],
#  ('B', 'ER1', 'G', 'N', 'ER0'): ['bergner', 'burgner'],
#  ('B', 'ER1', 'K', 'AH0', 'L'): ['berkel',
#   'birchall',
#   'birkel',
#   'burchell',
#   'burkel',
#   'burkle'],
#  ('B', 'ER1', 'K', 'L', 'IY0'): ['berkeley', 'berklee', 'berkley', 'burkley'],
#  ('B', 'ER1', 'K', 'S'): ['berkes',
#   'birkes',
#   'birks',
#   "burke's",
#   'burkes',
#   'burks'],
#  ('B', 'ER1', 'K', 'IY0'): ['berkey', 'birkey', 'birky', 'burkey'],
#  ('B', 'ER1', 'K', 'L', 'AH0', 'N', 'D'): ['berkland',
#   'birkeland',
#   'birkland',
#   'burkland',
#   'burklund'],
#  ('B', 'ER1', 'K', 'M', 'AH0', 'N'): ['berkman', 'burkman'],
#  ('B', 'ER1', 'K', 'AO0', 'F'): ['berkoff', 'birkhoff'],
#  ('B', 'ER1', 'L', 'AH0', 'N', 'D'): ['berland', 'burland'],
#  ('B', 'ER1', 'L'): ['berle', 'birle', 'burl'],
#  ('B', 'ER1', 'L', 'Z'): ["berle's", 'berles', "berles'", 'berls'],
#  ('B', 'ER0', 'L', 'IH1', 'N', 'ER0', 'Z'): ["berliner's", 'berliners'],
#  ('B', 'ER0', 'L', 'AY1', 'N', 'ER0', 'Z'): ["berliner's", 'berliners'],
#  ('B', 'ER1', 'L', 'IH0', 'NG'): ['berling', 'burling'],
#  ('B', 'ER1', 'M', 'AH0', 'N'): ['berman', 'birman', 'burman'],
#  ('B', 'ER1', 'M', 'AH0', 'N', 'Z'): ["berman's", 'bermans', 'burmans'],
#  ('B', 'ER1', 'N'): ['bern', 'berne', 'burn', 'burne', 'byrne'],
#  ('B', 'ER1', 'N', 'AH0', 'L'): ['bernal', 'burnell'],
#  ('B', 'ER0', 'N', 'AA1', 'R', 'D'): ['bernard', 'burnard'],
#  ('B', 'ER0', 'N', 'AA1', 'R', 'D', 'Z'): ["bernard's", 'bernards'],
#  ('B', 'ER0', 'N', 'AA1', 'R', 'D', 'IY0'): ['bernardi', 'bernardy'],
#  ('B', 'ER1', 'N', 'T'): ['bernd', 'berndt', 'bernt', 'burnt'],
#  ('B', 'ER1', 'N', 'ER0'): ['berner', 'burner'],
#  ('B', 'ER0', 'N', 'EH1', 'T'): ['bernet', 'burnett'],
#  ('B', 'ER1', 'N', 'IH0', 'T'): ['bernett', 'burnet'],
#  ('B', 'ER1', 'N', 'IY0'): ['berney',
#   'bernie',
#   'berny',
#   'birney',
#   'birnie',
#   'burney'],
#  ('B', 'ER1', 'N', 'HH', 'AA0', 'R', 'T'): ['bernhardt', 'bernhart'],
#  ('B', 'ER1', 'N', 'IH0', 'NG'): ['berning', 'burning'],
#  ('B', 'ER1', 'N', 'Z'): ['berns',
#   'burnes',
#   'burns',
#   "burns'",
#   "byrne's",
#   'byrnes'],
#  ('B', 'ER1', 'N', 'S', 'AH0', 'N'): ['bernsen', 'bernson'],
#  ('B', 'ER1', 'N', 'T', 'S', 'AH0', 'N'): ['berntsen', 'berntson'],
#  ('B', 'EH1', 'R', 'IY0', 'AH0', 'N'): ['berrian', 'berrien'],
#  ('B', 'ER1', 'SH'): ['bersch', 'bursch'],
#  ('B', 'ER1', 'S', 'AH0', 'N'): ['berson', 'burson'],
#  ('B', 'ER1', 'S', 'T'): ['berst', 'burst'],
#  ('B', 'ER1', 'S', 'T', 'IY0', 'N'): ['berstein', 'burstein'],
#  ('B', 'ER1', 'S', 'T', 'AY0', 'N'): ['berstein', 'burstein'],
#  ('B', 'ER1', 'T'): ['bert', 'berte', 'birt', 'burt', 'burtt'],
#  ('B', 'ER1', 'CH'): ['bertch',
#   'bertsch',
#   'bertsche',
#   'birch',
#   'burch',
#   'burtch'],
#  ('B', 'ER1', 'T', 'IH0', 'L', 'S', 'AH0', 'N'): ['bertelsen', 'bertelson'],
#  ('B', 'ER1', 'TH'): ['berth', 'birth'],
#  ('B', 'ER1', 'TH', 'S'): ['berths', 'births'],
#  ('B', 'ER1', 'T', 'IY0'): ['bertie', 'berty'],
#  ('B', 'ER1', 'T', 'AH0', 'N'): ['berton', 'burton'],
#  ('B', 'ER0', 'T', 'OW1', 'N', 'IY0'): ['bertone', 'bertoni'],
#  ('B', 'ER1', 'T', 'S'): ['bertz', 'burts'],
#  ('B', 'ER1', 'W', 'IH0', 'K'): ['berwick', 'burwick'],
#  ('B', 'EH1', 'SH', 'L', 'AO2', 'S'): ['beschloss', "beschloss'"],
#  ('B', 'IH0', 'S', 'IY1', 'JH', 'D'): ['beseiged', 'besieged'],
#  ('B', 'IH0', 'S', 'EH1', 'T'): ['beset', 'bessette', 'bissette'],
#  ('B', 'EH1', 'S', 'L', 'ER0'): ['besler', 'bessler'],
#  ...}

# %%
not_plural_or_posessive_homophones = {
    k:v for k,v in homophonic.items()
    if not  all(re.search(r"'?s'?$", m) for m in v)
}
not_plural_or_posessive_homophones
# Out:
# {('B', 'AW1', 'T'): ["'bout", 'bout'],
#  ('K', 'AO1', 'R', 'S'): ["'course", 'coarse', 'corse', 'course'],
#  ('K', 'Y', 'UW1', 'Z'): ["'cuse",
#   'cues',
#   'kuse',
#   'kuze',
#   "q's",
#   "q.'s",
#   'q.s',
#   'ques',
#   'queues'],
#  ('AH0', 'M'): ["'em", "'m", "i'm"],
#  ('K', 'EY1'): ["'kay",
#   'cay',
#   'k',
#   'k.',
#   'kay',
#   'kaye',
#   'khe',
#   'quai',
#   'quay',
#   'quaye'],
#  ('AH0', 'N'): ["'n", 'an'],
#  ('R', 'AW1', 'N', 'D'): ["'round", 'round'],
#  ('EH1', 'S'): ["'s", 'es', 'ess', 'esse', 's', 's.'],
#  ('T', 'IH1', 'L'): ["'til", 'til', 'till'],
#  ('EY1',): ['a', 'a.', 'ae', 'ay'],
#  ('AA1', 'K', 'ER0'): ['aaker', 'ocker'],
#  ('AA1', 'N', 'K', 'AO2', 'R'): ['aancor', 'encore', 'oncor'],
#  ('AA1', 'R', 'G'): ['aargh', 'argh'],
#  ('EH1', 'R', 'AH0', 'N'): ['aaron', 'aran', 'aron', 'ehren'],
#  ('EH1', 'R', 'AH0', 'N', 'S', 'AH0', 'N'): ['aaronson', 'aronson'],
#  ('AA1', 'S'): ['aase', 'os'],
#  ('AA1', 'S', 'AH0', 'N'): ['aasen', 'osten'],
#  ('AH0', 'B', 'AE1', 'D', 'IY0'): ['abadi', 'abadie'],
#  ('AE1', 'B', 'IY0'): ['abbe', 'abbey', 'abbie', 'abby', 'abie'],
#  ('AH0', 'B', 'EH1', 'T'): ['abbett', 'abet'],
#  ('AE1', 'B', 'AH0', 'T'): ['abbot', 'abbott'],
#  ('AE1', 'B', 'AH0', 'T', 'S', 'T', 'AW1', 'N'): ['abbotstown', 'abbottstown'],
#  ('AH0', 'B', 'UW1', 'D'): ['abboud', 'abood'],
#  ('AA0', 'B', 'R', 'UW0', 'T', 'S', 'EY1', 'Z', 'IY0'): ['abbruzzese',
#   'abruzzese'],
#  ('AE2', 'B', 'D', 'AE1', 'L', 'AH0'): ['abdalla', 'abdallah'],
#  ('EY1', 'B', 'AH0', 'L'): ['abel', 'abell', 'able'],
#  ('EY1', 'B', 'ER0'): ['aber', 'aybar'],
#  ('AE1', 'B', 'S', 'AH0', 'L', 'AH0', 'M'): ['absalom', 'absolom'],
#  ('AE2', 'K', 'L', 'AH0', 'M', 'EY1', 'SH', 'AH0', 'N'): ['acclamation',
#   'acclimation'],
#  ('AH0', 'K', 'AO1', 'R', 'D'): ['accord', 'acord'],
#  ('AH0', 'K', 'UW1', 'T', 'ER0', 'M', 'AH0', 'N', 'T'): ['accouterment',
#   'accoutrement'],
#  ('EY1', 'S', 'T'): ['aced', 'aist'],
#  ('AH0', 'S', 'EH1', 'T', 'IH0', 'K'): ['acetic', 'ascetic'],
#  ('EY1', 'K'): ['ache', 'ake'],
#  ('EY1', 'K', 'S'): ['aches', 'aix'],
#  ('EY1', 'K', 'ER0'): ['achor', 'acre', 'aker'],
#  ('EY1', 'K', 'IY0'): ['achy', 'aikey'],
#  ('AE1', 'K'): ['ack', 'akc'],
#  ('AE1', 'K', 'ER0'): ['acker', 'aker', 'akre'],
#  ('AE1', 'K', 'ER0', 'L', 'IY0'): ['ackerley', 'ackerly'],
#  ('AE1', 'K', 'ER0', 'M', 'AH0', 'N'): ['ackerman',
#   'ackermann',
#   'akerman',
#   'akkerman'],
#  ('AE1', 'K', 'ER0', 'S', 'AH0', 'N'): ['ackerson', 'akerson'],
#  ('AE0',
#   'K',
#   'N',
#   'AA1',
#   'L',
#   'IH0',
#   'JH',
#   'M',
#   'AH0',
#   'N',
#   'T'): ['acknowledgement', 'acknowledgment'],
#  ('AE1', 'K', 'T', 'AH0', 'N'): ['actin', 'acton'],
#  ('AE1', 'K', 'T', 'ER0'): ['actor', 'akhtar'],
#  ('AE1', 'K', 'S'): ['acts', 'ax', 'axe', 'x.'],
#  ('AE1', 'D'): ['ad', 'add'],
#  ('AE1', 'D', 'Z'): ["ad's", 'adds', 'ads', "ads'", 'adz'],
#  ('AH0', 'D', 'EH1', 'R'): ['adair', 'addair'],
#  ('AA1', 'D', 'AH0', 'M', 'CH', 'IH0', 'K'): ['adamcik', 'adamczyk'],
#  ('AA0', 'D', 'AA1', 'M', 'IY0'): ['adame', 'adami'],
#  ('AH0', 'D', 'AA1', 'M', 'IH0', 'K'): ['adamec', 'adamik'],
#  ('EY1', 'D', 'AH0', 'N'): ['adan', 'aden'],
#  ('AH0', 'D', 'AE1', 'P', 'T', 'ER0'): ['adapter', 'adaptor'],
#  ('AE1', 'D', 'IY0'): ['addie', 'addy'],
#  ('AH0', 'D', 'IH1', 'SH', 'AH0', 'N'): ['addition', 'edition'],
#  ('AE1', 'D', 'AH0', 'L', 'M', 'AH0', 'N'): ['addleman',
#   'adelman',
#   'adelmann'],
#  ('EY1', 'D'): ['ade', 'aid', 'aide', 'eyde'],
#  ('AH0', 'D', 'EH1', 'L'): ['adel', 'adele', 'adell', 'adelle', 'udelle'],
#  ('EH1', 'D', 'AH0', 'L', 'M', 'AH0', 'N'): ['adelman',
#   'eddleman',
#   'edelman',
#   'edelmann',
#   'edleman'],
#  ('EY1', 'D', 'IY0'): ['adey', 'ady', 'eydie'],
#  ('AA1', 'D', 'IY0', 'AH0'): ['adia', 'odea'],
#  ('AH0', 'D', 'UW1'): ['adieu', 'ado'],
#  ('AE1', 'D', 'K', 'IH0', 'S', 'AH0', 'N'): ['adkison', 'adkisson'],
#  ('AE1', 'D', 'M', 'AH0', 'N'): ['adman', 'admen'],
#  ('AA1', 'D', 'R', 'IY0', 'AH0'): ['adrea', 'adria'],
#  ('AE0', 'D', 'V', 'AY1', 'Z', 'ER0'): ['adviser', 'advisor'],
#  ('EH1', 'R'): ['aer', 'air', 'ayre', 'ere', 'err', 'eyre', 'heir'],
#  ('EH1', 'R', 'IY0', 'AH0', 'L'): ['aerial', 'ariel'],
#  ('EH1', 'R', 'IY0'): ['aerie', 'airey', 'airy', 'arie', 'ary', 'eyrie'],
#  ('EH1', 'R', 'OW0'): ['aero', 'arrow', 'eroh'],
#  ('EH1', 'R', 'OW0', 'S', 'M', 'IH2', 'TH'): ['aerosmith', 'arrowsmith'],
#  ('EH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K'): ['aesthetic', 'esthetic'],
#  ('EH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K', 'L', 'IY0'): ['aesthetically',
#   'esthetically'],
#  ('EH1', 'T', 'N', 'AH0'): ['aetna', 'etna'],
#  ('AH0', 'F', 'EH1', 'K', 'T'): ['affect', 'effect'],
#  ('EY1', 'G', 'AH0', 'N'): ['agan', 'aygen'],
#  ('AE1', 'G', 'IY0'): ['aggie', 'aggy', 'agie'],
#  ('AH0', 'G', 'L', 'OW1'): ['aglo', 'aglow'],
#  ('AE1', 'G', 'N', 'ER0'): ['agner', 'agnor'],
#  ('AE1', 'G', 'AH0', 'L', 'AA0', 'R'): ['aguilar', 'aguillar'],
#  ('AA1',): ['ah', 'ahh', 'awe'],
#  ('AH0', 'HH', 'ER1', 'N'): ['ahearn', 'ahern', 'aherne'],
#  ('AH0', 'L', 'EY1', 'N'): ['ahlen',
#   'alain',
#   'alaine',
#   'alane',
#   'alayne',
#   'allain',
#   'elaine'],
#  ('AA1', 'L', 'AH0', 'N'): ['ahlen', 'olen'],
#  ('AA1', 'L', 'M', 'AH0', 'N'): ['ahlman', 'almon'],
#  ('AA1', 'M', 'AH0', 'N'): ['ahmann', 'aman', 'ommen'],
#  ('AE1', 'N'): ['ahn', 'an', 'ane', 'ann', 'anne'],
#  ('AA1', 'N', 'ER0'): ['ahner', 'honor', 'honore', 'honour'],
#  ('AA1', 'R'): ['ahr', 'ar', 'are', 'our', 'r', 'r.'],
#  ('AA1', 'R', 'AH0', 'N'): ['ahren', 'aren'],
#  ('AA1', 'Z'): ['ahs', 'oz'],
#  ('AY1',): ['ai', 'ay', 'aye', 'eye', 'i', 'i.'],
#  ('AY1', 'K', 'AH0', 'L'): ['aichele', 'eichel'],
#  ('AY1', 'K', 'ER0'): ['aicher', 'eicher'],
#  ('EY1', 'K', 'IH0', 'N'): ['aickin', 'aiken', 'aikin', 'akin'],
#  ('AY0', 'IY1', 'D', 'AH0'): ['aida', 'uyeda'],
#  ('EY2', 'D', 'EH1', 'N'): ['aiden', 'aidenn'],
#  ('AY1', 'SH', 'AH0'): ['aiesha', 'aisha'],
#  ('EY1', 'L'): ['ail', 'ale'],
#  ('AY0', 'L', 'IY1', 'N'): ['aileen', 'ailene', 'eileen'],
#  ('EY1', 'L', 'IY0'): ['ailey', 'aley', 'aly'],
#  ('EY1', 'L', 'IH0', 'NG'): ['ailing', 'ayling'],
#  ('EY1', 'L', 'ER0'): ['ailor', 'ayler', 'aylor', 'eyler'],
#  ('EY1', 'M'): ['aim', 'aime', 'ame'],
#  ('AY1', 'M', 'AH0', 'N'): ['aiman', 'iman'],
#  ('EY1', 'N'): ['aine', 'ane', 'ayn'],
#  ('EY1', 'N', 'JH'): ['ainge', 'ange'],
#  ('EH1',
#   'R',
#   'K',
#   'AH0',
#   'N',
#   'D',
#   'IH2',
#   'SH',
#   'AH0',
#   'N',
#   'IH0',
#   'NG'): ['air-conditioning', 'airconditioning'],
#  ('EH1', 'R', 'F', 'AO0', 'R', 'S'): ['air-force', 'airforce'],
#  ('EH1', 'R', 'D'): ['aird', 'aired', 'erred'],
#  ('EH1', 'R', 'HH', 'AA0', 'R', 'T'): ['airhart',
#   'earhart',
#   'ehrhardt',
#   'ehrhart'],
#  ('EH1', 'R', 'IH0', 'NG'): ['airing', 'erring'],
#  ('EH1', 'R', 'IH0', 'NG', 'T', 'AH0', 'N'): ['airington',
#   'arrington',
#   'errington'],
#  ('EH1', 'R', 'M', 'AH0', 'N'): ['airman', 'ehrman', 'ehrmann'],
#  ('AY1', 'Z'): ['ais',
#   'ayes',
#   'eis',
#   "eye's",
#   'eyes',
#   "eyes'",
#   "i's",
#   "i.'s",
#   'i.s',
#   'ise'],
#  ('AY1', 'L'): ['aisle', "i'll", 'isle'],
#  ('EH1', 'K', 'S'): ['aix', 'eckes', 'ex', 'x', 'x.'],
#  ('AE1', 'K', 'S', 'T'): ['akst', 'axed', 'axt'],
#  ('AE1', 'L'): ['al', 'al.'],
#  ('AE1', 'L', 'AH0', 'M', 'EY2', 'N'): ['al-amein', 'alamein'],
#  ('AE2', 'L', 'AH0', 'B', 'AE1', 'M', 'AH0'): ['al.', 'alabama'],
#  ('AH0', 'L', 'AY1'): ['alai', 'ally'],
#  ('AE1', 'L', 'AH0', 'N'): ['alan', 'allan', 'allen'],
#  ('AE1', 'L', 'B', 'AA0', 'K'): ['albach', 'allebach'],
#  ('AH0', 'L', 'B', 'AO1'): ['albaugh', 'allbaugh'],
#  ('AE1', 'L', 'B', 'ER0', 'T', 'S', 'AH0', 'N'): ['albertsen', 'albertson'],
#  ('AO1', 'L', 'B', 'R', 'AY2', 'T'): ['albright', 'allbright'],
#  ('AE1', 'L', 'B', 'R', 'IH0', 'T', 'AA0', 'N'): ['albritton', 'allbritton'],
#  ('AO1', 'L', 'D', 'W', 'IH0', 'N'): ['aldwin', 'aldwyn'],
#  ('AE1', 'L', 'IH0', 'K'): ['alec', 'allick'],
#  ('AH0', 'L', 'IY1', 'N'): ['aleen', 'alene'],
#  ('AE2', 'L', 'AH0', 'K', 'S', 'AE1', 'N', 'D', 'ER0'): ['aleksander',
#   'aleksandr'],
#  ('EY1', 'L', 'M', 'AH0', 'N'): ['aleman', 'alleman'],
#  ('AE1', 'L', 'AH0', 'K', 'S'): ['alex', 'alexs'],
#  ('AH0', 'L', 'EH1', 'K', 'S', 'IY0'): ['alexi', 'alexy', 'oleksy'],
#  ('AE1', 'L', 'F', 'AH0'): ['alfa', 'alpha'],
#  ('AE1', 'L', 'F', 'IH0', 'N'): ['alfin', 'alphin'],
#  ('AE1', 'L', 'F', 'R', 'IH0', 'D', 'S', 'AH0', 'N'): ['alfredson',
#   'alfredsson'],
#  ('AE1', 'L', 'JH', 'IY0'): ['algae', 'algy'],
#  ('AA1', 'L', 'IY0'): ['ali', 'olley', 'ollie', 'olly'],
#  ('AE1', 'L', 'IH0', 'S'): ['alice', 'allis', 'alyce'],
#  ('AH0', 'L', 'IH1', 'S', 'IY0', 'AH0'): ['alicea', 'alysia'],
#  ('AE1', 'L', 'IY0'): ['alie', 'alley', 'alli', 'allie'],
#  ('AH0', 'L', 'AY1', 'N'): ['align', 'aline'],
#  ('AH0', 'L', 'IY1', 'S', 'AH0'): ['alisa', 'elisa'],
#  ('AE1', 'L', 'IH0', 'S', 'AH0', 'N'): ['alison', 'allison', 'allyson'],
#  ('AH0', 'L', 'IH1', 'S', 'AH0'): ['alissa', 'alyssa'],
#  ('AE1', 'L', 'IH0', 'S', 'T', 'ER0'): ['alister', 'allister'],
#  ('AO1', 'L'): ['all', 'aul', 'aull'],
#  ('AA1', 'L', 'AH0'): ['alla', 'allah'],
#  ('AH0', 'L', 'EY1'): ['allais', 'allay'],
#  ('AE1', 'L', 'ER0', 'T'): ['allardt', 'allert'],
#  ('AE2', 'L', 'EH0', 'L', 'UW1', 'Y', 'AA0'): ['alleluia', 'alleluja'],
#  ('AO1', 'L', 'ER0'): ['aller', 'allor'],
#  ('AE1', 'L', 'ER0', 'JH', 'AH0', 'N'): ['allergan', 'allergen'],
#  ('AE1', 'L', 'G', 'AY0', 'ER0'): ['allgaier', 'allgeier'],
#  ('AO1', 'L', 'M', 'AH0', 'N'): ['allman', 'allmon'],
#  ('AH0', 'L', 'AA1', 'T'): ['allot', 'alot'],
#  ('AH0', 'L', 'AA1', 'T', 'IH0', 'D'): ['alloted', 'allotted'],
#  ('AH0', 'L', 'AW1', 'D'): ['allowed', 'aloud'],
#  ('AO1', 'L', 'S', 'AA2', 'P'): ['allsop', 'allsopp'],
#  ('AO1', 'L', 'S', 'T', 'AH0', 'N'): ['allston', 'alston'],
#  ('AE1', 'L', 'S', 'AH0', 'P'): ['allsup', 'alsup'],
#  ('AO1', 'L', 'T', 'AH0', 'N'): ['allton', 'alton'],
#  ('AE1', 'L', 'AH0', 'M'): ['allum', 'alum'],
#  ('AA0', 'L', 'OY1', 'S', 'IY0', 'AH0'): ['aloisia', 'aloysia'],
#  ('AO1', 'L', 'T', 'ER0'): ['altar', 'alter'],
#  ('AO1', 'L', 'T', 'M', 'AH0', 'N'): ['altman', 'altmann', 'aultman'],
#  ('AE1', 'L', 'CH', 'Y', 'UW0', 'L', 'ER0'): ['altschuler', 'altshuler'],
#  ('AE1', 'L', 'CH', 'UW0', 'L', 'ER0'): ['altschuler', 'altshuler'],
#  ('AA1', 'L', 'T', 'S', 'HH', 'AY2', 'M', 'ER0'): ['altzheimer', 'alzheimer'],
#  ('AE1', 'L', 'W', 'IH0', 'N'): ['alwin', 'alwyn'],
#  ('AE1', 'M', 'AH0', 'K', 'ER0'): ['amacher', 'amacker'],
#  ('AH0', 'M', 'AA1', 'L', 'Y', 'AH0'): ['amalia', 'amalya'],
#  ('AE1', 'M', 'AH0', 'N'): ['amann', 'amman', 'ammann', 'ammon'],
#  ('AE1', 'M', 'B', 'IY0', 'AH0', 'N', 'S'): ['ambiance', 'ambience'],
#  ('AA0', 'M', 'B', 'R', 'OW0', 'S', 'IY1', 'N', 'IY0'): ['ambrosine',
#   'ambrosini'],
#  ('AE1', 'M', 'K', 'AO2', 'R'): ['amcor', 'amcore'],
#  ('AH0', 'M', 'IY1', 'N'): ['ameen', 'ammeen'],
#  ('AH0', 'M', 'IY1', 'L', 'IY0', 'OW0'): ['amelio', 'emilio'],
#  ('AH0', 'M', 'EH1', 'R', 'IY0'): ['ameri', 'omary'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AH0'): ['america', 'amerika'],
#  ('AH0', 'M', 'EH1', 'R', 'IH0', 'K', 'AO2', 'R'): ['americorp', 'americorps'],
#  ('AE1', 'M', 'ER0', 'M', 'AH0', 'N'): ['amerman', 'ammerman'],
#  ('EY1', 'M', 'IY0'): ['amey', 'amy', 'eighmey'],
#  ('AH0', 'M', 'AH1', 'K'): ['amok', 'amuck'],
#  ('AE1', 'M', 'P', 'AH0', 'L'): ['ampal', 'ample'],
#  ('AE1', 'M', 'F', 'AH0', 'TH', 'IY0', 'EY1', 'T', 'ER0'): ['amphitheater',
#   'amphitheatre'],
#  ('AE1', 'N', 'AH0'): ['ana', 'anna'],
#  ('AE2',
#   'N',
#   'AH0',
#   'S',
#   'TH',
#   'IY0',
#   'Z',
#   'IY0',
#   'AA1',
#   'L',
#   'AH0',
#   'JH',
#   'IY0'): ['anaesthesiology', 'anesthesiology'],
#  ('AE2', 'N', 'AH0', 'S', 'TH', 'EH1', 'T', 'IH0', 'K'): ['anaesthetic',
#   'anesthetic'],
#  ('AE1', 'N', 'AH0', 'L', 'AO2', 'G'): ['analog', 'analogue'],
#  ('AE1', 'N', 'AH0', 'N', 'D', 'EY2', 'L'): ['anandale', 'annandale'],
#  ('AE1', 'N', 'AH0', 'S'): ['anas', 'anise'],
#  ('AE2', 'N', 'AH0', 'T', 'OW1', 'L', 'IY0'): ['anatoli', 'anatoly'],
#  ('AH0', 'N', 'S', 'EH1', 'L'): ['ancel', 'ansel', 'unsell'],
#  ('AE1', 'NG', 'K', 'ER0'): ['anchor', 'anker'],
#  ('AE1', 'N', 'D', 'AH0', 'L'): ['andal', 'andel'],
#  ('AE1', 'N', 'D', 'ER0', 'S', 'AH0', 'N'): ['andersen',
#   'anderson',
#   'andersson'],
#  ('AE1', 'N', 'D', 'IY0'): ['andi', 'andie', 'andy'],
#  ('AA1', 'N', 'D', 'R', 'EY2'): ['andre', 'andrzej'],
#  ('AE2', 'N', 'D', 'R', 'IY1', 'S', 'AH0', 'N'): ['andreason', 'andriessen'],
#  ('AE1', 'N', 'D', 'R', 'UW0'): ['andreu', 'andrew'],
#  ('AE1', 'N', 'D', 'R', 'IY0'): ['andrey', 'andry'],
#  ('AE1', 'N', 'D', 'R', 'IH0', 'K'): ['andric', 'andrich', 'andrick'],
#  ('AH0', 'N', 'EH1', 'T'): ['anette', 'annett', 'annette'],
#  ('AE1', 'N', 'Y', 'UH0', 'R', 'IH2', 'Z', 'AH0', 'M'): ['aneurism',
#   'aneurysm'],
#  ('AE1', 'N', 'Y', 'UH0', 'R', 'IH2', 'Z', 'M'): ['aneurism', 'aneurysm'],
#  ('EY1', 'N', 'JH', 'AH0', 'L'): ['angel', 'angell'],
#  ('AE2', 'N', 'JH', 'AH0', 'L', 'IY1', 'N', 'OW0'): ['angeleno', 'angelino'],
#  ('AE1', 'N', 'JH', 'AH0', 'L', 'OW2', 'Z'): ["angelo's",
#   'angelos',
#   'angeloz'],
#  ('AA0', 'NG', 'G', 'EH0', 'L', 'OW1', 'N', 'IY0'): ['angelone', 'angeloni'],
#  ('AE1', 'N', 'JH', 'IY0'): ['angi', 'angie', 'angy'],
#  ('AE0', 'N', 'IY1', 'S', 'AH0'): ['anisa', 'annissa'],
#  ('AE1', 'N', 'AH0', 'S', 'T', 'AH0', 'N'): ['aniston', 'anniston'],
#  ('AE1', 'NG', 'K', 'R', 'AH0', 'M'): ['ankrom', 'ankrum'],
#  ('AE1', 'N', 'AH0', 'B', 'AH0', 'L'): ['annabelle', 'annable'],
#  ('AE1', 'N', 'AH0', 'L'): ['annal', 'annul'],
#  ('AE1', 'N', 'AH0', 'N'): ['annan', 'annen'],
#  ('AE1', 'N', 'IY0'): ['annie', 'anny'],
#  ('AE1', 'N', 'OW0'): ['anno', 'ano'],
#  ('AH0', 'N', 'AW1', 'N', 'S', 'M', 'AH0', 'N', 'T'): ['announcement',
#   'announcment'],
#  ('AH0', 'N', 'S', 'K', 'AA1', 'M'): ['anscom', 'anscomb'],
#  ('AE1', 'N', 'S', 'AH0', 'N'): ['ansohn', 'anson'],
#  ('AE1', 'N', 'T'): ['ant', 'aunt'],
#  ('AE1', 'N', 'T', 'AH0', 'L'): ['antal', 'antle'],
#  ('AE1', 'N', 'T', 'IY0'): ['ante', 'auntie'],
#  ('AE2', 'N', 'T', 'IY0', 'W', 'AO1', 'R'): ['anti-war', 'antiwar'],
#  ('AA0', 'N', 'T', 'OW1', 'N', 'IY0'): ['antone', 'antoni'],
#  ('AH0', 'N', 'W', 'EH1', 'L'): ['anwell', 'unwell'],
#  ('AE1', 'N', 'W', 'IH0', 'L'): ['anwyl', 'anwyll'],
#  ('AW1', 'AH0', 'N'): ['aoun', 'auen'],
#  ('AE1', 'P', 'AH0', 'T', 'AY2', 'T'): ['apatite', 'appetite'],
#  ('EY1', 'P', 'EH2', 'K', 'S'): ["apec's", 'apex'],
#  ('AE1', 'P', 'L', 'IH0', 'N'): ['aplin', 'applin'],
#  ('AH0', 'P', 'AA1', 'L', 'AH0', 'JH', 'AY2', 'Z'): ['apologise', 'apologize'],
#  ('AH0', 'P', 'AA1', 'L', 'AH0', 'JH', 'AY2', 'Z', 'D'): ['apologised',
#   'apologized'],
#  ('AH0',
#   'P',
#   'AA1',
#   'L',
#   'AH0',
#   'JH',
#   'AY2',
#   'Z',
#   'IH0',
#   'NG'): ['apologising', 'apologizing'],
#  ('AE2', 'P', 'AH0', 'L', 'EY1', 'SH', 'AH0', 'N'): ['appalachian',
#   'appellation'],
#  ('AE1', 'P', 'AH0', 'L'): ['appel', 'appell', 'apple'],
#  ('AE1', 'P', 'AH0', 'L', 'B', 'AW2', 'M'): ['appelbaum', 'applebaum'],
#  ('AE1', 'P', 'AH0', 'L', 'M', 'AH0', 'N'): ['appelman', 'appleman'],
#  ('AE1', 'P', 'AH0', 'L', 'B', 'IY2'): ['applebee', 'appleby'],
#  ('AA1', 'R', 'AH0', 'N', 'T'): ['arant', "aren't", 'arent'],
#  ('ER0', 'AE1', 'P', 'AH0', 'HH', 'OW2'): ['arapaho', 'arapahoe'],
#  ('AA1', 'R', 'B', 'IH0', 'T', 'R', 'AA2', 'ZH', 'ER0'): ['arbitrager',
#   'arbitrageur'],
#  ('AA1', 'R', 'B', 'ER0'): ['arbor', 'arbour'],
#  ('AA1', 'R', 'K'): ['arc', 'ark'],
#  ('AA1', 'R', 'S'): ['arce', 'arse'],
#  ('AA1', 'R', 'S', 'IH0', 'N', 'OW0'): ['arceneaux',
#   'arsenault',
#   'arseneau',
#   'arseneault'],
#  ('AA2',
#   'R',
#   'K',
#   'IY0',
#   'AH0',
#   'L',
#   'AA1',
#   'JH',
#   'IH0',
#   'K',
#   'AH0',
#   'L'): ['archaeological', 'archeological'],
#  ('AA2', 'R', 'K', 'IY0', 'AA1', 'L', 'AH0', 'JH', 'IY0'): ['archaeology',
#   'archeology'],
#  ('AA1', 'R', 'SH', 'AH0', 'M', 'B', 'OW0'): ['archambault', 'archambeault'],
#  ('AA0', 'R', 'K', 'UW0', 'L', 'EH1', 'T', 'AH0'): ['archuleta', 'archuletta'],
#  ('AA1', 'R', 'K', 'OW0'): ['arco', 'arko'],
#  ('AA1', 'R', 'K', 'S'): ['arcs', 'arx'],
#  ('ER0',): ['are', 'er', 'or'],
#  ('EH1', 'R', 'IY0', 'AH0'): ['area', 'erria'],
#  ('AA1', 'R', 'N', 'T'): ["aren't", 'arndt'],
#  ('ER0', 'IY1', 'N', 'AH0'): ['arena', 'erina'],
#  ('AA0', 'R', 'EH1', 'T', 'AH0'): ['areta', 'aretta'],
#  ('AA1', 'R', 'G', 'AA2', 'N'): ['argon', 'argonne'],
#  ('AA0', 'R', 'IY0', 'AE1', 'N', 'AH0'): ['ariana', 'arianna'],
#  ('AE1', 'R', 'IH0', 'K'): ['aric', 'arrick'],
#  ('AA0', 'R', 'IY0', 'EH1', 'L', 'AH0'): ['ariela', 'ariella'],
#  ('AA2', 'R', 'IH0', 'S', 'T', 'IY1', 'D'): ['aristede', 'aristide'],
#  ('AA1', 'R', 'L', 'IY0'): ['arley', 'arlie'],
#  ('AA1', 'R', 'L', 'AY2', 'N'): ['arline', 'arlyne'],
#  ('AA1', 'R', 'M', 'AH0', 'N'): ['arman', 'armen', 'armin', 'armon'],
#  ('AA1', 'R', 'M', 'AH0', 'N', 'D'): ['armand', 'armond'],
#  ('AA1', 'R', 'M', 'AH0', 'N', 'T', 'R', 'AW2', 'T'): ['armantrout',
#   'armentrout'],
#  ('AA1', 'R', 'M', 'ER0'): ['armer', 'armor', 'armour'],
#  ('AA1', 'R', 'M', 'IH0', 'S', 'T', 'EH2', 'D'): ['armested', 'armistead'],
#  ('AA1', 'R', 'M', 'IY0'): ['armey', 'army'],
#  ('AA1', 'R', 'M', 'T', 'EH2', 'K'): ['armtec', 'armtek'],
#  ('AA1', 'R', 'N'): ['arn', 'arne', 'arnn'],
#  ('AA1', 'R', 'N', 'AH0', 'L'): ['arnal', 'arnall', 'arnell'],
#  ('AA0', 'R', 'N', 'EH1', 'T'): ['arnett', 'arnette'],
#  ('AA1', 'R', 'N', 'IY0'): ['arney', 'arnie'],
#  ('AA1', 'R', 'N', 'OW0'): ['arno', 'arnow'],
#  ('AA1', 'R', 'T', 'S'): ["art's", 'arts', 'artz'],
#  ('AA1', 'R', 'T', 'IY0'): ['artie', 'arty'],
#  ('AA1', 'S', 'AH0'): ['asa', 'ossa'],
#  ('AH0', 'S', 'EH1', 'N', 'D', 'AH0', 'N', 'S', 'IY0'): ['ascendancy',
#   'ascendency'],
#  ('AH0', 'S', 'EH1', 'N', 'T'): ['ascent', 'assent'],
#  ('AE1', 'SH'): ['asch', 'asche', 'ash', 'ashe'],
#  ('AE1', 'SH', 'ER0'): ['ascher', 'asher', 'ashur'],
#  ('AE1', 'SH', 'V', 'IH2', 'L'): ['asheville', 'ashville'],
#  ('AE1', 'SH', 'IY0'): ['ashey', 'ashy'],
#  ('AE1', 'S', 'T'): ['asked', 'assed', 'ast'],
#  ('AA1', 'S', 'T', 'AH0'): ['asta', 'hasta'],
#  ('AE1', 'S', 'T', 'ER0'): ['aster', 'astor'],
#  ('AE1', 'CH', 'IH0', 'S', 'AH0', 'N'): ['atcheson', 'atchison'],
#  ('EY1', 'T'): ['ate', 'aydt', 'eight'],
#  ('EY1', 'T', 'AH0', 'N'): ['aten', 'eyton'],
#  ('AE1', 'T', 'K', 'IH0', 'S', 'AH0', 'N'): ['atkison',
#   'atkisson',
#   'attkisson'],
#  ('AE1', 'T', 'L', 'IY0'): ['atley', 'attlee'],
#  ('AE1', 'T', 'B', 'EH0', 'R', 'IY0'): ['atteberry', 'attebury'],
#  ('AE1', 'T', 'W', 'UH2', 'D'): ['attwood', 'atwood'],
#  ('OW1',): ['au',
#   'aux',
#   'eau',
#   'eaux',
#   'o',
#   "o'",
#   'o.',
#   'oh',
#   'ohh',
#   'ow',
#   'owe'],
#  ('AO1', 'B', 'R', 'IY0'): ['aubrey', 'aubry', 'awbrey'],
#  ('AO1', 'D'): ['aud', 'awed'],
#  ('OW0', 'D', 'EH1', 'T'): ['audet', 'audette'],
#  ('AO1', 'D', 'R', 'IY0'): ['audrey', 'audry'],
#  ('AW1',): ['aue', 'ow'],
#  ('AW1', 'ER0'): ['auer', 'hour', 'our'],
#  ('AO1', 'G', 'AH0', 'S', 'T'): ['aug', 'august', 'auguste'],
#  ('AO1', 'G', 'ER0'): ['auger', 'augur'],
#  ('AO1', 'T'): ['aught', 'ot', 'ought'],
#  ('AO1', 'M', 'AH0', 'N'): ['auman', 'aumann'],
#  ('AO1', 'N'): ['aune', 'on'],
#  ('AO1', 'NG'): ['aung', 'ong'],
#  ('AO1', 'R', 'AH0'): ['aura', 'ora'],
#  ('AO1', 'R', 'AH0', 'L'): ['aural', 'oral', 'orel'],
#  ('AO1', 'R', 'AH0', 'N', 'D'): ['aurand', 'orand'],
#  ('AO1', 'R', 'AH0', 'M'): ['aurum', 'oram', 'orum'],
#  ('AW1', 'S', 'T', 'AH0', 'L'): ['austell', 'austill'],
#  ('AO1', 'S', 'T', 'AH0', 'N'): ['austin', 'auston'],
#  ('AW1', 'T', 'AH0', 'N'): ['auten', 'outen', 'outten'],
#  ('AO1', 'TH', 'ER0'): ['auther', 'author'],
#  ('AO1', 'T', 'R', 'IY0'): ['autrey', 'autry', 'awtrey'],
#  ('EY1', 'V', 'AH0'): ['ava', 'eva'],
#  ('EY1', 'V', 'IY0'): ['avey', 'avi'],
#  ('EY2', 'V', 'IY0', 'EY1', 'SH', 'AH0', 'N'): ['aviacion', 'aviation'],
#  ('AH0', 'V', 'IH1', 'L', 'AH0'): ['avila', 'avilla'],
#  ('AO1',): ['aw', 'awe'],
#  ('AE1', 'K', 'S', 'AH0', 'L'): ['axel', 'axle'],
#  ('AY1', 'ER0'): ['ayer', 'eyer', 'iyer'],
#  ('AY1', 'G', 'AH0', 'N'): ['aygen', 'eigen', 'igon'],
#  ('EY1', 'S', 'K', 'Y', 'UW0'): ['ayscue', 'escue'],
#  ('B', 'IY1'): ['b', 'b.', 'be', 'bea', 'bee'],
#  ('B', 'AH0', 'N', 'EY1'): ["b'nai", 'benet'],
#  ('B', 'IY1', 'Z'): ["b's",
#   "b.'s",
#   'b.s',
#   "be's",
#   'beas',
#   "bee's",
#   'bees',
#   'beese',
#   'bes'],
#  ('B', 'IY2', 'S', 'IY1'): ['b.c.', 'bc'],
#  ('B', 'AA1'): ['ba', 'bah'],
#  ('B', 'AA1', 'B'): ['baab', 'bob', 'bobb'],
#  ('B', 'AA1', 'K'): ['baack', 'bach', 'boch', 'bock', 'bohlke', 'bok'],
#  ('B', 'AA1', 'L', 'B', 'EH0', 'K'): ['baalbek', 'baalbeq'],
#  ('B', 'AA1', 'R'): ['baar', 'bahr', 'bahre', 'bar', 'barr', 'barre'],
#  ('B', 'AA1', 'R', 'Z'): ['baars',
#   "bar's",
#   "barr's",
#   'barres',
#   'barrs',
#   'bars',
#   'barz'],
#  ('B', 'AA1', 'SH'): ['baasch', 'bosh'],
#  ('B', 'AA1', 'T', 'S'): ['baatz', 'botts', 'botz'],
#  ('B', 'AE1', 'B'): ['bab', 'babb'],
#  ('B', 'AH1', 'B', 'AH0'): ['baba', 'bubba'],
#  ('B', 'AE1', 'B', 'IH0', 'T'): ['babbit', 'babbitt'],
#  ('B', 'AE1', 'B', 'AH0', 'L'): ['babble', 'babel'],
#  ('B', 'AA1', 'B', 'IH0', 'K'): ['babic', 'babik', 'bobick'],
#  ('B', 'AE1', 'B', 'IH0', 'N', 'OW2'): ['babineau', 'babineaux'],
#  ('B', 'AH0', 'B', 'IH1', 'N', 'S', 'K', 'IY0'): ['babinski', 'bobinski'],
#  ('B', 'EY1', 'B', 'IY0', 'S', 'IH2', 'T', 'ER0'): ['baby-sitter',
#   'babysitter'],
#  ('B', 'AA1', 'K', 'ER0'): ['bachar', 'bacher'],
#  ('B', 'AE1', 'CH'): ['bache', 'batch'],
#  ('B', 'AE1', 'CH', 'AH0', 'L', 'ER0'): ['bachelor',
#   'batcheller',
#   'batchelor'],
#  ('B', 'AA1', 'K', 'M', 'AH0', 'N'): ['bachman', 'bachmann', 'bockman'],
#  ('B', 'AA1', 'K', 'N', 'ER0'): ['bachner', 'bochner'],
#  ('B', 'AE1', 'K', 'T', 'AH0', 'L'): ['bachtel', 'bachtell'],
#  ('B', 'AE1', 'K'): ['back', 'backe', 'bak', 'bakke'],
#  ('B', 'AE1', 'K', 'S'): ["back's", 'backes', 'backs', 'bax'],
#  ('B', 'AE1', 'K', 'AH2', 'P'): ['back-up', 'backup'],
#  ('B', 'AE1', 'K', 'ER0'): ['backer', 'bakker'],
#  ('B', 'EY1', 'D'): ['bade', 'bayed'],
#  ('B', 'AH0', 'D', 'OW1'): ['badeau', 'badeaux'],
#  ('B', 'AE1', 'D', 'L', 'IY0'): ['badley', 'badly'],
#  ('B', 'AY1'): ['bae', 'bi', 'buy', 'by', 'bye'],
#  ('B', 'EH1', 'K', 'ER0'): ['baecker', 'becher', 'becker', 'beker', 'bekker'],
#  ('B', 'IY1', 'R'): ['baehr', 'bier'],
#  ('B', 'EH1', 'R'): ['baehr', 'baer', 'bahr', 'bair', 'bare', 'bear', 'behr'],
#  ('B', 'IY1', 'K'): ['baek', 'beak', 'beeck', 'beek'],
#  ('B', 'EH1', 'K'): ['baek', 'bec', 'beck'],
#  ('B', 'EH1', 'T', 'AH0', 'N'): ['baeten', 'betten', 'betton'],
#  ('B', 'IY1', 'T', 'S'): ['baetz', 'beats', 'beets', 'beitz', 'bietz'],
#  ('B', 'AE1', 'G'): ['bag', 'bagg', 'bagge'],
#  ('B', 'EY1', 'G', 'AH0', 'N'): ['bagan', 'begun'],
#  ('B', 'AE1', 'G', 'D', 'AE0', 'D'): ['bagdad', 'baghdad'],
#  ('B', 'EY1', 'G', 'AH0', 'L'): ['bagel', 'begel'],
#  ('B', 'AE1', 'G', 'IY0'): ['baggie', 'baggy'],
#  ('B', 'AE1', 'G', 'L', 'IY0'): ['baghli', 'bagley'],
#  ('B', 'AE1', 'G', 'N', 'AH0', 'L'): ['bagnall', 'bagnell'],
#  ('B', 'AA1', 'L'): ['bahl', 'bol', 'bolle'],
#  ('B', 'AA1', 'L', 'ER0'): ['bahler', 'boller'],
#  ('B', 'AE1', 'M'): ['bahm', 'bam'],
#  ('B', 'AE1', 'N'): ['bahn', 'ban', 'banh', 'bann'],
#  ('B', 'AA1', 'N', 'ER0'): ['bahner', 'bonnor'],
#  ('B', 'AA1', 'T'): ['baht', 'bhatt', 'bott', 'bought'],
#  ('B', 'EY1', 'ER0'): ['baier', 'bayar', 'bayer', 'beyer'],
#  ('B', 'EY1', 'G'): ['baig', 'begue'],
#  ('B', 'EY1', 'L'): ['bail', 'baile', 'bale', 'balle', 'bayle', 'beyl'],
#  ('B', 'EY1', 'L', 'ER0'): ['bailer', 'bailor', 'baler', 'baylor'],
#  ('B', 'EY1', 'L', 'IY0'): ['bailey',
#   'bailie',
#   'baillie',
#   'bailly',
#   'baily',
#   'baley',
#   'bally',
#   'baylee',
#   'bayley',
#   'bayly'],
#  ('B', 'EY1', 'L', 'IH0', 'F'): ['bailiff', 'bayliff'],
#  ('B', 'EY1', 'L', 'IH0', 'N'): ['bailin', 'bailyn', 'beilin'],
#  ('B', 'EY1', 'L', 'IH0', 'NG'): ['bailing', 'baling'],
#  ('B', 'EY1', 'L', 'AH0', 'N'): ['bailon', 'balan', 'baylen'],
#  ('B', 'EY1', 'M'): ['baim', 'bame', 'boehm', 'boehme'],
#  ('B', 'EY1', 'N'): ['bain', 'baine', 'bane', 'bayne'],
#  ('B', 'EY1', 'N', 'ER0', 'D'): ['bainerd', 'baynard'],
#  ('B', 'EH1', 'R', 'D'): ['baird', 'bared'],
#  ('B', 'EY1', 'Z'): ['baise',
#   'baize',
#   "bay's",
#   'bayes',
#   'bays',
#   'bayse',
#   'baze'],
#  ('B', 'EY1', 'T'): ['bait', 'bate', 'beit'],
#  ('B', 'EY1', 'T', 'IH0', 'D'): ['baited', 'bated'],
#  ('B', 'EY1', 'T', 'IY0'): ['baity', 'batey', 'batie', 'baty', 'beatty'],
#  ('B', 'EY1', 'K', 'ER0'): ['baker', 'bakker'],
#  ('B', 'AE1', 'K', 'S', 'T'): ['bakst', 'baxt'],
#  ('B', 'AA1', 'L', 'AH0'): ['bala', 'bolla'],
#  ('B', 'EY1', 'L', 'S', 'ER0'): ['balcer', 'balser'],
#  ('B', 'AE1', 'L', 'K', 'AH0', 'M'): ['balcom', 'balkcom'],
#  ('B', 'AO1', 'L', 'D'): ['bald', 'balled', 'bawled'],
#  ('B', 'AA0', 'L', 'D', 'AA0', 'S', 'AA1', 'R', 'IY0'): ['baldassare',
#   'baldassari'],
#  ('B', 'AO1', 'L', 'D', 'ER0'): ['balder', 'baldor'],
#  ('B', 'AA0', 'L', 'EH0', 'N', 'T', 'IY1', 'N', 'IY0'): ['balentine',
#   'ballentine'],
#  ('B', 'AA1', 'L', 'IH0', 'K'): ['balik', 'bolich', 'bolick'],
#  ('B', 'AE1', 'L', 'IH0', 'N'): ['balin', 'ballin'],
#  ('B', 'AO1', 'L'): ['ball', 'bawl'],
#  ('B', 'AO1', 'L', 'Z'): ["ball's", 'balls', 'balz', 'bawls'],
#  ('B', 'AO1', 'L', 'ER0'): ['baller', 'ballor'],
#  ('B', 'AE1', 'L', 'IY0'): ['balli', 'bally'],
#  ('B', 'AE1', 'L', 'OW0'): ['ballo', 'ballow', 'balogh', 'balow'],
#  ('B', 'AA1', 'M'): ['balm', 'bohm', 'bom', 'bomb'],
#  ('B', 'AA1', 'M', 'ER0'): ['balmer', 'bomber', 'bommer'],
#  ('B', 'AH0', 'L', 'OW1', 'N', 'IY0'): ['baloney', 'bologna'],
#  ('B', 'AE1', 'L', 'TH', 'AH0', 'S', 'ER0'): ['balthasar', 'balthaser'],
#  ('B', 'AE1', 'M', 'B', 'ER0', 'G'): ['bamberg', 'bamburg'],
#  ('B', 'AE1', 'N', 'Z'): ["ban's", 'bans', 'benz'],
#  ('B', 'AE1', 'NG', 'K'): ['banc', 'bank', 'banke', 'banque'],
#  ('B', 'AE1', 'NG', 'K', 'OW0'): ['banco', 'banko'],
#  ('B', 'AE1', 'N', 'D'): ['band', 'banned'],
#  ('B', 'AE1', 'NG', 'G', 'AH0', 'L', 'AO2', 'R'): ['bangalor', 'bangalore'],
#  ('B', 'AE1', 'N', 'IH0', 'K'): ['banick', 'banik', 'bannick'],
#  ('B', 'AE1', 'N', 'IH0', 'S', 'T', 'ER0'): ['banister', 'bannister'],
#  ('B', 'AA1', 'N', 'Y', 'AH0'): ['banja', 'banya'],
#  ('B', 'AH0', 'NG', 'K', 'AO1', 'F', 'S', 'K', 'IY0'): ['bankowski',
#   'bonkowski'],
#  ('B', 'AE1', 'NG', 'K', 'R', 'AH0', 'P', 'T', 'S', 'IY0'): ['bankrupcty',
#   'bankruptcy'],
#  ('B', 'AE1', 'N', 'AH0', 'N'): ['bannan', 'bannon'],
#  ('B', 'AW1'): ['bao', 'bough', 'bow'],
#  ('B', 'AA1', 'R', 'AH0'): ['bara', 'barra'],
#  ('B', 'AA1', 'R', 'AH0', 'K'): ['barack', 'barak'],
#  ('B', 'AE1', 'R', 'AH0', 'SH'): ['barasch', 'barash'],
#  ('B', 'AA1', 'R', 'B'): ['barb', 'barbe'],
#  ('B', 'AA1', 'R', 'B', 'R', 'AH0'): ['barbara', 'barbra'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2'): ['barbecue',
#   'barbeque',
#   'bbq'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2', 'D'): ['barbecued',
#   'barbequed'],
#  ('B', 'AA1', 'R', 'B', 'IH0', 'K', 'Y', 'UW2', 'IH0', 'NG'): ['barbecueing',
#   'barbecuing',
#   'barbequeing'],
#  ('B', 'AA1', 'R', 'B', 'EH2', 'L'): ['barbel', 'barbell'],
#  ('B', 'AA1', 'R', 'B', 'ER0'): ['barber', 'barbour', 'barbre'],
#  ('B', 'AA1', 'R', 'B', 'IY0'): ['barbie', 'barby'],
#  ('B', 'AA1', 'R', 'K'): ['barch', 'bark', 'barke'],
#  ('B', 'AA1', 'R', 'K', 'OW0'): ['barco', 'barko', 'barkow'],
#  ('B', 'AA1', 'R', 'D'): ['bard', 'barred'],
#  ('B', 'AA1', 'R', 'D', 'AH0', 'L', 'F'): ['bardulf', 'bardulph'],
#  ('B', 'EH1', 'R', 'IY0'): ['barey',
#   'barre',
#   'barrie',
#   'barry',
#   'berrey',
#   'berri',
#   'berrie',
#   'berry',
#   'buerry',
#   'bury'],
#  ('B', 'AA1', 'R', 'G', 'M', 'AH0', 'N'): ['bargman', 'bargmann'],
#  ('B', 'AE1', 'R', 'IH0', 'K'): ['barich', 'barrick'],
#  ('B', 'EH1', 'R', 'AH0', 'L'): ['baril',
#   'barrel',
#   'behrle',
#   'berrill',
#   'beryl',
#   'burel',
#   'burell'],
#  ('B', 'EH1', 'R', 'IH0', 'NG'): ['baring', 'bearing', 'behring', 'bering'],
#  ('B', 'EH1', 'R', 'IH0', 'NG', 'ER0'): ['baringer',
#   'behringer',
#   'beringer',
#   'berringer'],
#  ('B', 'EH1', 'R', 'IH0', 'SH'): ['barish', 'bearish', 'buresh'],
#  ('B', 'AA1', 'R', 'K', 'D', 'AH0', 'L'): ['barkdoll', 'barkdull'],
#  ('B', 'AA1', 'R', 'K', 'L', 'IY0'): ['barkeley', 'barkley'],
#  ('B', 'AA1', 'R', 'L', 'OW2'): ['barlow', 'barlowe'],
#  ('B', 'AA1', 'R', 'N', 'IY0'): ['barney', 'barny'],
#  ('B', 'AA1', 'R', 'N', 'HH', 'AA2', 'R', 'T'): ['barnhardt', 'barnhart'],
#  ('B', 'AA1', 'R', 'OW0'): ['baro', 'barro'],
#  ('B', 'AE1', 'R', 'AH0', 'N'): ['baron', 'barren', 'barron'],
#  ('B', 'EH1', 'R', 'AH0', 'N'): ['baron', 'barren', 'beran', 'beron'],
#  ('B', 'ER0', 'OW1', 'N'): ['barone', 'barrone'],
#  ('B', 'AE1', 'R', 'IH0', 'T'): ['barret', 'barrett'],
#  ('B', 'AA0', 'R', 'EH1', 'T', 'OW0'): ['barreto', 'barretto'],
#  ('B', 'EH1', 'R', 'IH0', 'T'): ['barrett', 'berrett'],
#  ('B', 'EH1', 'R', 'IH0', 'K'): ['barrick', 'burek', 'burich'],
#  ('B', 'AE1', 'R', 'IY0'): ['barrie', 'barry'],
#  ('B', 'EH1', 'R', 'IY0', 'ER0'): ['barrier', 'berrier'],
#  ('B', 'EH1', 'R', 'OW0'): ['barrow', 'bero'],
#  ('B', 'AA1', 'R', 'SH'): ['barsch', 'barsh'],
#  ('B', 'AA1', 'R', 'T', 'S'): ["bart's", 'barts', 'bartz'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'K'): ['bartak', 'bartok'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'L'): ['bartel', 'bartl', 'bartle', 'bartol'],
#  ('B', 'AA1', 'R', 'T', 'AH0', 'N'): ['barten', 'barton'],
#  ('B', 'AA1', 'R', 'T', 'N', 'IH0', 'K'): ['bartnick', 'bartnik'],
#  ('B', 'AE1', 'SH'): ['basch', 'bash'],
#  ('B', 'EY1', 'S'): ['base', 'bass'],
#  ('B', 'EY1', 'S', 'T'): ['based', 'baste'],
#  ('B', 'EY1', 'S', 'IY0'): ['basey', 'basi'],
#  ('B', 'AE1', 'S', 'F', 'ER0', 'D'): ['basford', 'bassford'],
#  ('B', 'AA1', 'SH', 'AH0'): ['basha', 'bhatia'],
#  ('B', 'AE1', 'SH', 'AH0', 'M'): ['basham', 'bassham'],
#  ('B', 'AE1', 'SH', 'ER0'): ['basher', 'bashor', 'bashore'],
#  ('B', 'EY1', 'S', 'IH0', 'K', 'S'): ["basic's", 'basics', 'basix'],
#  ('B', 'AE1', 'Z', 'AH0', 'L'): ['basil', 'bazzell', 'bazzle'],
#  ('B', 'AE1', 'S', 'K'): ['bask', 'basque'],
#  ('B', 'AE1', 'S'): ['bass', 'basse'],
#  ('B', 'AE1', 'S', 'IH0', 'T'): ['basset', 'bassett'],
#  ('B', 'AE1', 'S', 'T', 'AH0', 'N'): ['bastien', 'baston'],
#  ('B', 'AE1', 'T'): ['bat', 'batt', 'batte', 'bhatt'],
#  ('B', 'AH0', 'T', 'AA1', 'N'): ['bataan', 'baton', 'bhutan'],
#  ('B', 'AE1', 'T', 'IH0', 'S', 'AH0', 'N'): ['bateson', 'battison'],
#  ('B', 'AE1', 'T', 'S', 'AH0', 'N'): ['bateson', 'batson'],
#  ('B', 'AE1', 'T', 'AH0', 'N'): ['baton', 'batten', 'batton'],
#  ('B', 'AE1', 'T', 'S'): ['bats', 'batts', 'batz'],
#  ('B', 'AE1', 'T', 'IY0'): ['battey', 'batty'],
#  ('B', 'AA0', 'T', 'IY1', 'S', 'T', 'IY0'): ['battiste', 'battisti'],
#  ('B', 'AO1', 'B', 'AH0', 'L'): ['bauble', 'bobble'],
#  ('B', 'AO1', 'D'): ['baud', 'bawd'],
#  ('B', 'AW1', 'ER0'): ['bauer', 'baur', 'bougher', 'bower'],
#  ('B', 'AO1', 'ER0'): ['baugher', 'bawer'],
#  ('B', 'AO1', 'N'): ['baughn', 'baun'],
#  ('B', 'AO1', 'M'): ['baum', 'bomb'],
#  ('B', 'AW1', 'M', 'AH0', 'N'): ['bauman', 'baumann', 'boughman', 'bouwman'],
#  ('B', 'AA1', 'M', 'B', 'ER0', 'G', 'ER0'): ['baumberger', 'bomberger'],
#  ('B', 'AA1', 'M', 'G', 'AA2', 'R', 'D', 'N', 'ER0'): ['baumgardner',
#   'bomgardner'],
#  ('B', 'AW1', 'M', 'G', 'AA2', 'R', 'T'): ['baumgardt', 'baumgart'],
#  ('B', 'AA1', 'M', 'G', 'AA2', 'R', 'T'): ['baumgardt', 'baumgart'],
#  ('B', 'AO1', 'R'): ['baur', 'boar', 'boer', 'bohr', 'bore', 'borre'],
#  ('B', 'AW1', 'CH'): ['bautch', 'bouch', 'bouche'],
#  ('B', 'AO1', 'T', 'S'): ['bautz', 'bots'],
#  ('B', 'EY1'): ['bay', 'baye', 'bayh', 'bey'],
#  ('B', 'AH0', 'Z', 'AA1', 'R'): ['bazaar', 'bazar', 'bizarre'],
#  ('B', 'IY1', 'B', 'ER0'): ['beaber', 'beber', 'bieber'],
#  ('B', 'IY1', 'CH'): ['beach', 'beech'],
#  ('B', 'IY1', 'CH', 'AH0', 'M'): ['beacham', 'beachum', 'beecham'],
#  ('B', 'IY1', 'CH', 'ER0'): ['beacher', 'beecher'],
#  ('B', 'IY1', 'CH', 'L', 'ER0'): ['beachler', 'beechler'],
#  ('B', 'IY1', 'CH', 'IY0'): ['beachy', 'beechy'],
#  ('B', 'IY1', 'D'): ['bead', 'bede', 'beede'],
#  ('B', 'IY1', 'D', 'AH0', 'L'): ['beadle', 'beedle'],
#  ('B', 'IY1', 'D', 'IY0'): ['beady', 'beedie', 'beedy'],
#  ('B', 'IY1', 'G', 'AH0', 'L'): ['beagle', 'beegle', 'biegel'],
#  ('B', 'IY1', 'G', 'L', 'IY0'): ['beagley', 'beeghly'],
#  ('B', 'IY1', 'M'): ['beahm', 'beam', 'beem'],
#  ('B', 'IH1', 'R', 'D'): ['beaird', 'beard'],
#  ('B', 'IY1', 'K', 'ER0'): ['beaker', 'beeker', 'bieker'],
#  ('B', 'IY1', 'K', 'M', 'AH0', 'N'): ['beakman', 'beekman'],
#  ('B', 'IY1', 'L'): ['beal',
#   'beale',
#   'beall',
#   'beel',
#   'beil',
#   'biehl',
#   'biel'],
#  ('B', 'IY1', 'L', 'ER0'): ['bealer',
#   'beehler',
#   'beeler',
#   'biehler',
#   'bieler'],
#  ('B', 'IY1', 'M', 'AH0', 'N'): ['beaman', 'beamon', 'beeman', 'beman'],
#  ('B', 'IY1', 'M', 'ER0'): ['beamer', 'beemer'],
#  ('B', 'IY1', 'N'): ['bean',
#   'beane',
#   'beene',
#   'bein',
#   'beine',
#   'biehn',
#   'bien'],
#  ('B', 'EH1', 'R', 'AH0'): ['beara', 'bera', 'berra'],
#  ('B', 'ER1', 'S'): ['bearce', 'bearse', 'bearss', 'burse'],
#  ('B', 'IH1', 'R', 'D', 'Z', 'L', 'IY0'): ['beardslee', 'beardsley'],
#  ('B', 'IH1', 'R'): ['beare', 'beer', 'bere'],
#  ('B', 'ER1', 'F', 'IY0', 'L', 'D'): ['bearfield', 'burfield'],
#  ('B', 'EH1', 'R', 'M', 'AH0', 'N'): ['bearman', 'behrman', 'behrmann'],
#  ('B', 'IH1', 'R', 'IY0'): ['beary', 'beery', 'bieri', 'biery'],
#  ('B', 'IY1', 'Z', 'L', 'IY0'): ['beasley', 'beesley', 'beezley'],
#  ('B', 'IY1', 'Z', 'AH0', 'N'): ['beason', 'beeson'],
#  ('B', 'IY1', 'T'): ['beat', 'beet'],
#  ('B', 'IY1', 'T', 'AH0', 'N'): ['beaten', 'beaton', 'beeton'],
#  ('B', 'IY1', 'T', 'IY0'): ['beatie', 'beattie', 'beatty', 'beaty'],
#  ('B', 'IY1', 'T', 'AH0', 'L'): ['beatle', 'beetle'],
#  ('B', 'OW1'): ['beau', 'beaux', 'bo', 'boe', 'boeh', 'bow', 'bowe'],
#  ('B', 'OW1', 'S'): ['beauce', 'boese', 'bowse'],
#  ('B', 'OW2', 'SH', 'EY1', 'N'): ['beauchaine', 'beauchene'],
#  ('B', 'OW0', 'D', 'OY1', 'N'): ['beaudoin', 'bowdoin'],
#  ('B', 'EH1', 'V', 'AH0', 'N'): ['beavan', 'bevan', 'beven'],
#  ('B', 'IY1', 'V', 'ER0'): ['beaver', 'beever', 'biever'],
#  ('B', 'IY1', 'B', 'IY0'): ['bebe', 'beeby'],
#  ('B', 'IH0', 'B', 'OW1'): ['bebeau', 'bibeau', 'bibeault'],
#  ('B', 'EH1', 'K', 'L', 'ER0'): ['bechler', 'beckler'],
#  ('B', 'EH1', 'K', 'IY0'): ['becki', 'beckie', 'becky', 'bekki'],
#  ('B', 'EH1', 'K', 'M', 'AH0', 'N'): ['beckman', 'beckmann'],
#  ('B', 'IY1', 'K', 'OW0'): ['beco', 'biko'],
#  ('B', 'EH1', 'D', 'IH0', 'NG', 'F', 'IY2', 'L', 'D'): ['beddingfield',
#   'bedingfield'],
#  ('B', 'EH1', 'D', 'OW0'): ['beddoe', 'beddow'],
#  ('B', 'EH1', 'D', 'N', 'ER0'): ['bednar', 'bedner'],
#  ('B', 'IH1', 'N'): ['been', 'bihn', 'bin', 'binn'],
#  ('B', 'IH1', 'N', 'Z'): ['beens', 'binns', 'bins', 'binz'],
#  ('B', 'IH1', 'R', 'M', 'AH0', 'N'): ['beerman', 'bierman', 'biermann'],
#  ('B', 'EH1', 'G'): ['beg', 'begg'],
#  ('B', 'EH1', 'G', 'ER0'): ['beger', 'beggar'],
#  ('B', 'IH0', 'HH', 'EY1', 'V', 'Y', 'ER0'): ['behavior', 'behaviour'],
#  ('B', 'EH1', 'L'): ['behl', 'bel', 'bell', 'belle'],
#  ('B', 'EH1', 'L', 'ER0'): ['behler', 'bellar', 'beller'],
#  ('B', 'EH1', 'L', 'IH0', 'NG'): ['behling', 'belling'],
#  ('B', 'EH1', 'L', 'K'): ['behlke', "bel'c", 'belk', 'belke'],
#  ('B', 'EH1', 'M'): ['behm', 'bem'],
#  ('B', 'EH1', 'N'): ['behn', 'behne', 'ben', 'benn', 'benne'],
#  ('B', 'EH1', 'N', 'ER0'): ['behner', 'benner'],
#  ('B', 'EH1', 'N', 'IY0'): ['behney', 'beni', 'benney', 'bennie', 'benny'],
#  ('B', 'EH1', 'N', 'IH0', 'NG'): ['behning', 'bening', 'benning'],
#  ('B', 'EH1', 'NG', 'K'): ['behnke', 'benke'],
#  ('B', 'IY1', 'HH', 'AA0', 'F'): ['behof', 'behoff'],
#  ('B', 'EH1', 'R', 'EH0', 'N', 'D'): ['behrend', 'berend'],
#  ('B', 'EH1', 'R', 'IH0', 'N', 'T'): ['behrendt', 'berendt'],
#  ('B', 'AY1', 'ER0'): ['beier', 'buyer', 'byer'],
#  ('B', 'AY1', 'L', 'ER0'): ['beiler', 'byler'],
#  ('B', 'EH1', 'L', 'IH0', 'N'): ['beilin', 'belin', 'bellin'],
#  ('B', 'IY1', 'L', 'K'): ['beilke', 'bielke'],
#  ('B', 'IH1', 'R', 'N'): ['beirne', 'byrn'],
#  ('B', 'AY1', 'S', 'AH0', 'L'): ['beisel', 'beissel'],
#  ('B', 'AY1', 'T'): ['beit', 'bight', 'bite', 'byte'],
#  ('B', 'AY1', 'T', 'ER0'): ['beiter', 'biter'],
#  ('B', 'AY1', 'T', 'AH0', 'L', 'ER0'): ['beitler', 'bitler'],
#  ('B', 'AY1', 'T', 'L', 'ER0'): ['beitler', 'bitler'],
#  ('B', 'EH1', 'L', 'AH0'): ['bela', 'bella', 'bellah'],
#  ('B', 'EH1', 'L', 'AH0', 'N', 'D'): ['beland', 'belland'],
#  ('B', 'EH1', 'L', 'D', 'AH0', 'N'): ['belden', 'beldon'],
#  ('B', 'EH1', 'L', 'AH0', 'N'): ['belen', 'bellon'],
#  ('B', 'EH1', 'L', 'F', 'L', 'AW2', 'ER0'): ['belflower', 'bellflower'],
#  ('B', 'EH1', 'L', 'IY0'): ['beli', 'belli', 'belly'],
#  ('B', 'AH0', 'L', 'IH1', 'JH', 'ER0', 'AH0', 'N', 'S'): ['beligerence',
#   'belligerence'],
#  ('B', 'AH0', 'L', 'IH1', 'JH', 'ER0', 'AH0', 'N', 'T'): ['beligerent',
#   'belligerent'],
#  ('B', 'IH0', 'L', 'IH1', 'N', 'S', 'K', 'IY0'): ['belinsky',
#   'bielinski',
#   'bilinski'],
#  ('B', 'EH1', 'L', 'IH0', 'V', 'OW2'): ['beliveau', 'belliveau'],
#  ('B', 'EH1', 'L', 'Z'): ["bell's",
#   'belles',
#   'bells',
#   "bells'",
#   'bels',
#   'belz'],
#  ('B', 'EH1', 'L', 'AH0', 'M', 'IY0'): ['bellamy', 'bellomy'],
#  ('B', 'IH0', 'L', 'AA1', 'R', 'D'): ['bellard', 'billard'],
#  ('B', 'IH0', 'L', 'OW1'): ['belleau', 'below'],
#  ('B', 'EH1', 'L', 'M', 'AH0', 'N'): ['bellman', 'bellmon', 'belman'],
#  ('B', 'EH1', 'L', 'M', 'AO0', 'R'): ['bellmore', 'belmore'],
#  ('B', 'EH1', 'L', 'OW0'): ['bello', 'bellow', 'belo'],
#  ('B', 'EH0', 'L', 'OW1', 'T', 'IY0'): ['bellotti', 'belote'],
#  ('B', 'EH1', 'L', 'V', 'IH2', 'L'): ['bellville', 'belville'],
#  ('B', 'EH1', 'L', 'T', 'S'): ["belt's", 'belts', 'beltz'],
#  ('B', 'EH1', 'N', 'Z'): ["ben's", 'bens', 'benz'],
#  ('B', 'EH1', 'N', 'AH0'): ['bena', 'bene'],
#  ('B', 'EH1', 'N', 'AH0', 'K'): ['benak', 'benecke', 'beneke'],
#  ('B', 'EH1', 'N', 'D', 'AH0', 'L'): ['bendall', 'bendel', 'bendele'],
#  ('B', 'EH1', 'N', 'T'): ['bendt', 'bent', 'bente'],
#  ('B', 'EH1', 'N', 'AH0', 'D', 'IH0', 'K'): ['benedek', 'benedick'],
#  ('B', 'EH1', 'N', 'AH0', 'F', 'IH0', 'T', 'IH0', 'NG'): ['benefiting',
#   'benefitting'],
#  ('B', 'EH1', 'N', 'AH0', 'SH'): ['benesch', 'benesh'],
#  ('B', 'EH1', 'N', 'AH0', 'T'): ['benet', 'bennett'],
#  ('B', 'EH1', 'NG', 'G', 'AH0', 'L'): ['bengal', 'bengel'],
#  ('B', 'AH0', 'N', 'IY1', 'T', 'OW0'): ['benito', 'bonito'],
#  ('B', 'EH1', 'N', 'IH0', 'T'): ['bennet', 'bennett', 'bennitt'],
#  ('B', 'IH0', 'N', 'EH1', 'T'): ['bennette', 'binette'],
#  ('B', 'EH1', 'N', 'S', 'AH0', 'N'): ['bensen', 'benson'],
#  ('B', 'EH1', 'T', 'IH0', 'N'): ['benten', 'bettin'],
#  ('B', 'EH1', 'N', 'T', 'L', 'IY0'): ['bentley', 'bently'],
#  ('B', 'EH1', 'N', 'T', 'S', 'AH0', 'N'): ['bentsen', 'bentson'],
#  ('B', 'EH1', 'N', 'Z', 'IY0', 'N'): ['benzene', 'benzine'],
#  ('B', 'ER0', 'AA1', 'R', 'D'): ['berard', 'berrard'],
#  ('B', 'ER1', 'K'): ['berch',
#   'berk',
#   'berke',
#   'birk',
#   'bourke',
#   'burck',
#   'burk',
#   'burke'],
#  ('B', 'ER1', 'D', 'AH0', 'N'): ['berdan', 'birden', 'burden', 'burdon'],
#  ('B', 'ER1', 'G'): ['berg', 'bergh', 'burg', 'burge'],
#  ('B', 'ER1', 'G', 'AH0', 'N'): ['bergan', 'bergen'],
#  ('B', 'ER1', 'JH'): ['berge', 'birge', 'burdge'],
#  ('B', 'ER1', 'G', 'M', 'AH0', 'N'): ['bergeman',
#   'bergemann',
#   'bergman',
#   'bergmann',
#   'burgman'],
#  ('B', 'ER1', 'G', 'ER0'): ['berger', 'burger', 'burgher'],
#  ('B', 'ER1', 'G', 'IH0', 'S', 'AH0', 'N'): ['bergeson', 'burgeson'],
#  ('B', 'ER1', 'G', 'EH0', 'T'): ['berget', 'burget'],
#  ('B', 'ER1', 'JH', 'IY0'): ['bergey', 'burgy'],
#  ('B', 'ER1', 'G', 'R', 'EH0', 'N'): ['berggren', 'bergren'],
#  ('B', 'ER1', 'G', 'HH', 'AO0', 'F'): ['berghof', 'berghoff'],
#  ('B', 'ER1', 'G', 'L', 'IH0', 'NG'): ['bergling', 'burgling'],
#  ('B', 'ER1', 'G', 'N', 'ER0'): ['bergner', 'burgner'],
#  ('B', 'ER1', 'K', 'AH0', 'L'): ['berkel',
#   'birchall',
#   'birkel',
#   'burchell',
#   'burkel',
#   'burkle'],
#  ('B', 'ER1', 'K', 'L', 'IY0'): ['berkeley', 'berklee', 'berkley', 'burkley'],
#  ('B', 'ER1', 'K', 'IY0'): ['berkey', 'birkey', 'birky', 'burkey'],
#  ('B', 'ER1', 'K', 'L', 'AH0', 'N', 'D'): ['berkland',
#   'birkeland',
#   'birkland',
#   'burkland',
#   'burklund'],
#  ('B', 'ER1', 'K', 'M', 'AH0', 'N'): ['berkman', 'burkman'],
#  ('B', 'ER1', 'K', 'AO0', 'F'): ['berkoff', 'birkhoff'],
#  ('B', 'ER1', 'L', 'AH0', 'N', 'D'): ['berland', 'burland'],
#  ('B', 'ER1', 'L'): ['berle', 'birle', 'burl'],
#  ('B', 'ER1', 'L', 'IH0', 'NG'): ['berling', 'burling'],
#  ('B', 'ER1', 'M', 'AH0', 'N'): ['berman', 'birman', 'burman'],
#  ('B', 'ER1', 'N'): ['bern', 'berne', 'burn', 'burne', 'byrne'],
#  ('B', 'ER1', 'N', 'AH0', 'L'): ['bernal', 'burnell'],
#  ('B', 'ER0', 'N', 'AA1', 'R', 'D'): ['bernard', 'burnard'],
#  ('B', 'ER0', 'N', 'AA1', 'R', 'D', 'IY0'): ['bernardi', 'bernardy'],
#  ('B', 'ER1', 'N', 'T'): ['bernd', 'berndt', 'bernt', 'burnt'],
#  ('B', 'ER1', 'N', 'ER0'): ['berner', 'burner'],
#  ('B', 'ER0', 'N', 'EH1', 'T'): ['bernet', 'burnett'],
#  ('B', 'ER1', 'N', 'IH0', 'T'): ['bernett', 'burnet'],
#  ('B', 'ER1', 'N', 'IY0'): ['berney',
#   'bernie',
#   'berny',
#   'birney',
#   'birnie',
#   'burney'],
#  ('B', 'ER1', 'N', 'HH', 'AA0', 'R', 'T'): ['bernhardt', 'bernhart'],
#  ('B', 'ER1', 'N', 'IH0', 'NG'): ['berning', 'burning'],
#  ('B', 'ER1', 'N', 'S', 'AH0', 'N'): ['bernsen', 'bernson'],
#  ('B', 'ER1', 'N', 'T', 'S', 'AH0', 'N'): ['berntsen', 'berntson'],
#  ('B', 'EH1', 'R', 'IY0', 'AH0', 'N'): ['berrian', 'berrien'],
#  ('B', 'ER1', 'SH'): ['bersch', 'bursch'],
#  ('B', 'ER1', 'S', 'AH0', 'N'): ['berson', 'burson'],
#  ('B', 'ER1', 'S', 'T'): ['berst', 'burst'],
#  ('B', 'ER1', 'S', 'T', 'IY0', 'N'): ['berstein', 'burstein'],
#  ('B', 'ER1', 'S', 'T', 'AY0', 'N'): ['berstein', 'burstein'],
#  ('B', 'ER1', 'T'): ['bert', 'berte', 'birt', 'burt', 'burtt'],
#  ('B', 'ER1', 'CH'): ['bertch',
#   'bertsch',
#   'bertsche',
#   'birch',
#   'burch',
#   'burtch'],
#  ('B', 'ER1', 'T', 'IH0', 'L', 'S', 'AH0', 'N'): ['bertelsen', 'bertelson'],
#  ('B', 'ER1', 'TH'): ['berth', 'birth'],
#  ('B', 'ER1', 'T', 'IY0'): ['bertie', 'berty'],
#  ('B', 'ER1', 'T', 'AH0', 'N'): ['berton', 'burton'],
#  ('B', 'ER0', 'T', 'OW1', 'N', 'IY0'): ['bertone', 'bertoni'],
#  ('B', 'ER1', 'T', 'S'): ['bertz', 'burts'],
#  ('B', 'ER1', 'W', 'IH0', 'K'): ['berwick', 'burwick'],
#  ('B', 'IH0', 'S', 'IY1', 'JH', 'D'): ['beseiged', 'besieged'],
#  ('B', 'IH0', 'S', 'EH1', 'T'): ['beset', 'bessette', 'bissette'],
#  ('B', 'EH1', 'S', 'L', 'ER0'): ['besler', 'bessler'],
#  ('B', 'EH1', 'S'): ['bess', 'besse'],
#  ('B', 'EH1', 'S', 'IY0'): ['bessey', 'bessie', 'bessy'],
#  ('B', 'EH1', 'S', 'T'): ['best', 'beste'],
#  ('B', 'EH1', 'T'): ['bet', 'bett'],
#  ('B', 'EH1', 'T', 'S'): ["bet's", 'bets', 'betts', 'betz'],
#  ('B', 'EH1', 'TH', 'AE2', 'N'): ['bethann', 'bethanne'],
#  ('B', 'EH1', 'TH', 'AH0', 'L'): ['bethel', 'bethell'],
#  ('B', 'EH1', 'T', 'S', 'IY0'): ['betsey', 'betsy'],
#  ('B', 'EH1', 'T', 'IY0'): ['bette', 'betti', 'betty'],
#  ('B', 'EH1', 'T', 'ER0'): ['better', 'bettor'],
#  ('B', 'UW1'): ['beu', 'boo'],
#  ('B', 'Y', 'UW1', 'L', 'AH0'): ['beulah', 'bula'],
#  ('B', 'ER1', 'IY0'): ['beury', 'burry'],
#  ('B', 'EH1', 'V', 'AH0', 'L'): ['bevel', 'bevil', 'bevill'],
#  ('B', 'EH1', 'V', 'ER0', 'IH0', 'JH'): ['beverage', 'beveridge'],
#  ('B', 'EH1', 'V', 'ER0', 'L', 'IY0'): ['beverley', 'beverly'],
#  ('B', 'Y', 'UW1', 'L', 'IY0'): ['bewley', 'buley'],
#  ('B', 'AY1', 'R', 'AH0', 'L'): ['beyerle', 'byrle'],
#  ('B', 'UW1', 'T', 'OW0'): ['bhutto', 'buetow'],
#  ('B', 'AY0', 'P', 'OW1', 'L', 'ER0'): ['bi-polar', 'bipolar'],
#  ('B', 'AY0', 'W', 'IY1', 'K', 'L', 'IY0'): ['bi-weekly', 'biweekly'],
#  ('B', 'IY0', 'AA1', 'S', 'IY0'): ['biasi', 'byassee'],
#  ('B', 'IH1', 'B'): ['bib', 'bibb'],
#  ('B', 'IH0', 'B', 'IY1'): ['bibee', 'bibi'],
#  ('B', 'IH1', 'K'): ['bic', 'bick'],
#  ('B', 'AY1', 'S'): ['bice', 'buysse'],
#  ('B', 'IH1', 'K', 'L', 'ER0'): ['bichler', 'bickler'],
#  ('B', 'IH1', 'K', 'S', 'AH0', 'L'): ['bichsel', 'bixel'],
#  ('B', 'IH1', 'K', 'AH0', 'L'): ['bickel', 'bickell', 'bickle'],
#  ('B', 'IH1', 'K', 'S', 'L', 'ER0'): ['bicksler', 'bixler'],
#  ('B', 'IH1', 'D', 'IY0'): ['biddie', 'biddy'],
#  ('B', 'AY1', 'D', 'ER0', 'M', 'AH0', 'N'): ['biderman', 'biedermann'],
#  ('B', 'IY1', 'L', 'AH0'): ['biela', 'bila'],
#  ('B', 'IH0', 'L', 'IH1', 'T', 'S', 'K', 'IY0'): ['bielicki', 'bilicki'],
#  ('B', 'IH0', 'NG', 'K', 'AO1', 'F', 'S', 'K', 'IY0'): ['bienkowski',
#   'binkowski'],
#  ('B', 'IH1', 'R', 'L', 'IY0'): ['bierley', 'bierly'],
#  ('B', 'AY1', 'Z'): ['bies', 'bise', "buy's", 'buys'],
#  ('B', 'IH1', 'G', 'B', 'IY0'): ['bigbie', 'bigby'],
#  ('B', 'IH1', 'G', 'ER0'): ['biggar', 'bigger'],
#  ('B', 'IH1', 'L'): ['bihl', 'bil', 'bill'],
#  ('B', 'AY1', 'K', 'ER0'): ['biker', 'byker'],
#  ('B', 'IH1', 'L', 'D'): ['bild', 'billed', 'build'],
#  ('B', 'IH1', 'L', 'T'): ['bildt', 'built'],
#  ('B', 'IH1', 'L', 'T', 'S'): ["bildt's", 'biltz'],
#  ('B', 'AY1', 'L'): ['bile', 'bille'],
#  ('B', 'IH1', 'L', 'IH0', 'T'): ['billet', 'billett'],
#  ('B', 'IH1', 'L', 'IY0', 'T', 'ER0'): ['billeter', 'billiter'],
#  ('B', 'IH1', 'L', 'IH0', 'K'): ['billick', 'bilyk'],
#  ('B', 'IH1', 'L', 'IY0'): ['billie', 'billy', 'bily'],
#  ('B', 'IH1', 'L', 'IH0', 'NG', 'Z', 'L', 'IY0'): ['billingslea',
#   'billingsley',
#   'billingsly'],
#  ('B', 'IH1', 'L', 'OW0'): ['billow', 'bilow'],
#  ('B', 'IH1', 'L', 'S', 'K', 'IY0'): ['bilski', 'bilsky'],
#  ('B', 'IH1', 'N', 'D', 'AH0', 'L'): ['bindel', 'bindle'],
#  ('B', 'IH1', 'NG', 'G', 'AH0', 'L'): ['bingel', 'bingle'],
#  ('B', 'IH1', 'N', 'IY0'): ['binney', 'binnie'],
#  ('B', 'ER1'): ['bir', 'birr', 'bur', 'burr'],
#  ('B', 'ER1', 'K', 'ER0', 'D'): ['birchard', 'burkard'],
#  ('B', 'ER1', 'CH', 'ER0'): ['bircher', 'birtcher', 'burcher'],
#  ('B', 'ER1', 'CH', 'IH0', 'T'): ['birchett', 'burchett'],
#  ('B', 'ER1', 'K', 'HH', 'EH0', 'D'): ['birckhead', 'birkhead', 'burkhead'],
#  ('B', 'ER1', 'D'): ['bird', 'burd', 'byrd'],
#  ('B', 'ER1', 'D', 'IY0'): ['birdie', 'birdy'],
#  ('B', 'ER1', 'D', 'S', 'AH0', 'L'): ['birdsell', 'burdsall'],
#  ('B', 'ER1', 'K', 'IH0', 'T'): ['birkett', 'burket', 'burkett', 'burkitt'],
#  ('B', 'ER1', 'L', 'IY0'): ['birley', 'burley', 'burly'],
#  ('B', 'AY1', 'R', 'AH0', 'N'): ['biron', 'byron'],
#  ('B', 'IH1', 'S'): ['bis', 'biss', 'buice'],
#  ('B', 'IH1', 'SH'): ['bisch', 'bish'],
#  ('B', 'IH1', 'S', 'IH0', 'K'): ['bisek', 'busick'],
#  ('B', 'IH1', 'S', 'AH0', 'L'): ['bisel', 'bissell'],
#  ('B', 'IH1', 'Z', 'M', 'AA2', 'R', 'K'): ['bismarck', 'bismark'],
#  ('B', 'IH1', 'S', 'AH0', 'N'): ['bissen', 'bisson'],
#  ('B', 'IH1', 'S', 'IH0', 'T'): ['bisset', 'bissett'],
#  ('B', 'IH1', 'T', 'ER0'): ['bitar', 'bitter'],
#  ('B', 'IH1', 'T', 'N', 'ER0'): ['bitner', 'bittner'],
#  ('B', 'IH1', 'T', 'S'): ['bits', 'bitz'],
#  ('B', 'IH1', 'T', 'AH0', 'L'): ['bittel', 'bittle'],
#  ('B', 'IH1', 'T', 'AH0', 'N'): ['bitten', 'bitton'],
#  ('B', 'IH1', 'T', 'ER0', 'M', 'AH0', 'N'): ['bitterman', 'bittermann'],
#  ('B', 'IH1', 'Z'): ['biz', 'buis'],
#  ('B', 'IH1', 'Z', 'IY0'): ['bizzy', 'busy'],
#  ('B', 'Y', 'AO1', 'R', 'N'): ['bjoern', 'bjorn'],
#  ('B', 'L', 'AE1', 'K', 'L', 'IY0'): ['blackley', 'blakley'],
#  ('B', 'L', 'AE1', 'K', 'M', 'AH0', 'N'): ['blackman', 'blackmon', 'blackmun'],
#  ('B', 'L', 'EY1', 'D', 'AH0', 'N'): ['bladen', 'blaydon'],
#  ('B', 'L', 'EY1', 'Z'): ['blaese',
#   'blaise',
#   'blaize',
#   'blase',
#   'blayze',
#   'blaze'],
#  ('B', 'L', 'EH1', 'S', 'IH0', 'NG'): ['blaesing', 'blessing'],
#  ('B', 'L', 'EY1', 'K', 'IY0'): ['blaikie', 'blakey'],
#  ('B', 'L', 'EY1', 'N'): ['blain', 'blaine', 'blane', 'blayne'],
#  ('B', 'L', 'EH1', 'R'): ['blair', 'blare'],
#  ('B', 'L', 'EY1', 'Z', 'ER0'): ['blaiser', 'blaser', 'blazer'],
#  ('B', 'L', 'EY1', 'K', 'L', 'IY0'): ['blakeley', 'blakely'],
#  ('B', 'L', 'EY1', 'K', 'S', 'L', 'IY0'): ['blakeslee', 'blakesley'],
#  ('B', 'L', 'AE1', 'N'): ['blan', 'blann'],
#  ('B', 'L', 'AE1', 'NG', 'K'): ['blanc', 'blanck', 'blank', 'blanke'],
#  ('B', 'L', 'AE1', 'N', 'S', 'IH0', 'T'): ['blancett', 'blansett'],
#  ('B', 'L', 'AE1', 'N', 'CH'): ['blanch', 'blanche'],
#  ('B', 'L', 'AE1', 'N', 'D', 'IH0', 'N'): ['blandin', 'blandon'],
#  ('B', 'L', 'EY1', 'N', 'IY0'): ['blaney', 'blayney'],
#  ('B', 'L', 'AE1', 'NG', 'K', 'IY2'): ['blankie', 'blanky'],
#  ('B', 'L', 'AE1', 'NG', 'K', 'L', 'IY0'): ['blankley', 'blankly'],
#  ('B', 'L', 'AA1', 'S', 'K', 'OW0'): ['blasco', 'blasko'],
#  ('B', 'L', 'AE1', 'S', 'D', 'AH0', 'L'): ['blasdel', 'blasdell'],
#  ('B', 'L', 'EY1', 'Z', 'IY0', 'ER0'): ['blasier', 'blazier'],
#  ('B', 'L', 'EY1', 'Z', 'IH0', 'NG'): ['blasing', 'blazing'],
#  ('B', 'L', 'AA0', 'S', 'IH0', 'NG', 'G', 'AA1', 'M', 'IY0'): ['blasingame',
#   'blassingame'],
#  ('B', 'L', 'AW1'): ['blau', 'blough'],
#  ('B', 'L', 'EY1'): ['blay', 'bley'],
#  ('B', 'L', 'IY1', 'K', 'ER0'): ['bleaker', 'bleecker', 'bleeker'],
#  ('B', 'L', 'OW1'): ['bleau', 'blow', 'blowe'],
#  ('B', 'L', 'EH1', 'K'): ['blech', 'bleck'],
#  ('B', 'L', 'EH1', 'K', 'ER0'): ['blecher', 'blecker'],
#  ('B', 'L', 'AY1', 'L', 'ER0'): ['bleiler', 'blyler'],
#  ('B', 'L', 'EH1', 'S', 'T'): ['blessed', 'blest'],
#  ('B', 'L', 'UW1'): ['bleu', 'blew', 'blue'],
#  ('B', 'L', 'UW1', 'IH0', 'T'): ['blewett', 'blewitt'],
#  ('B', 'L', 'AY1'): ['bligh', 'bly', 'blye'],
#  ('B', 'L', 'AY1', 'DH'): ['blithe', 'blythe'],
#  ('B', 'L', 'IH1', 'Z', 'ER0', 'D'): ['blizard', 'blizzard'],
#  ('B', 'L', 'AA1', 'K'): ['bloc', 'bloch', 'block', 'blok'],
#  ('B', 'L', 'AA1', 'K', 'ER0'): ['blocher', 'blocker'],
#  ('B', 'L', 'OW1', 'M'): ['bloem', 'blohm', 'blome'],
#  ('B', 'L', 'AA1', 'M', 'K', 'W', 'IH2', 'S', 'T'): ['blomkvist', 'blomquist'],
#  ('B', 'L', 'AA1', 'N', 'D'): ['blond', 'blonde'],
#  ('B', 'L', 'UW1', 'M'): ['bloom', 'blum', 'blume'],
#  ('B', 'L', 'UW1', 'M', 'ER0'): ['bloomer', 'blumer'],
#  ('B', 'L', 'OW1', 'Z'): ['blose', 'blows'],
#  ('B', 'L', 'AA1', 'K', 'S', 'AH0', 'M'): ['bloxham', 'bloxom', 'bloxsom'],
#  ('B', 'L', 'UW1', 'IH0', 'NG'): ['blueing', 'bluing'],
#  ('B', 'L', 'UW1', 'IH0', 'SH'): ['blueish', 'bluish'],
#  ('B', 'L', 'UW1', 'T'): ['bluett', 'bluitt'],
#  ('B', 'L', 'AH1', 'M', 'IH0', 'N', 'SH', 'AY0', 'N'): ['blumenschein',
#   'blumenshine'],
#  ('B', 'L', 'AH1', 'NG', 'K'): ['blunck', 'blunk'],
#  ('B', 'L', 'AH1', 'N', 'D', 'AH0', 'L'): ['blundall', 'blundell'],
#  ('B', 'UH1', 'L', 'AH0', 'V', 'AA2', 'R', 'D'): ['blvd', 'boulevard'],
#  ('B', 'OW1', 'K'): ['boak', 'boake', 'boeck', 'boeke', 'bouck'],
#  ('B', 'OW1', 'L'): ['boal', 'boehl', 'bohl', 'bole', 'boll', 'bowl', 'buol'],
#  ('B', 'OW1', 'L', 'Z'): ['boals',
#   'boles',
#   'bolles',
#   'bolls',
#   'bolz',
#   'bowles',
#   'bowls'],
#  ('B', 'OW1', 'N'): ['boan',
#   'boehne',
#   'boen',
#   'bohn',
#   'bohne',
#   'bone',
#   'bown',
#   'bowne'],
#  ('B', 'AO1', 'R', 'D'): ['board', 'bored'],
#  ('B', 'AO1', 'R', 'D', 'AH0'): ['boarda', 'borda'],
#  ('B', 'AO1', 'R', 'D', 'ER0'): ['boarder', 'border'],
#  ('B', 'AO1', 'R', 'D', 'M', 'AH0', 'N'): ['boardman', 'bordman'],
#  ('B', 'AO1', 'R', 'M', 'AH0', 'N'): ['boarman',
#   'boerman',
#   'borman',
#   'bormann'],
#  ('B', 'AO1', 'R', 'T'): ['boart', 'bort'],
#  ('B', 'OW1', 'Z'): ['boase', 'boes', 'bose', 'bowes', 'bows', 'boze'],
#  ('B', 'OW1', 'T', 'N', 'ER0'): ['boatner', 'boettner'],
#  ('B', 'OW1', 'T', 'R', 'AY2', 'T'): ['boatright', 'boatwright'],
#  ('B', 'AA1', 'B', 'ER0'): ['bobber', 'bober'],
#  ('B', 'AA1', 'B', 'IH0', 'T'): ['bobbett', 'bobbitt'],
#  ('B', 'AA1', 'B', 'IY0'): ['bobbi', 'bobbie', 'bobby'],
#  ('B', 'OW1', 'K', 'AH0'): ['boca', 'bocce'],
#  ('B', 'AA1', 'CH'): ['boche', 'botch'],
#  ('B', 'AA1', 'D', 'IY0'): ['boddie', 'boddy', 'body'],
#  ('B', 'OW1', 'D'): ['bode', 'bowed'],
#  ('B', 'OW1', 'D', 'AH0', 'N'): ['boden', 'bowden'],
#  ('B', 'OW1', 'D', 'IY0'): ['bodey', 'bodi', 'bodie'],
#  ('B', 'OW1', 'D', 'AH0', 'L'): ['bodle', 'bowdle'],
#  ('B', 'OW1', 'K', 'ER0'): ['boecker', 'boeker', 'boker', 'bokor', 'bowker'],
#  ('B', 'OW1', 'K', 'M', 'AH0', 'N'): ['boeckman', 'boeckmann'],
#  ('B', 'OW1', 'D', 'IH0', 'K', 'ER0'): ['boedecker', 'boedeker'],
#  ('B', 'OW1', 'JH'): ['boege', 'boge'],
#  ('B', 'OW1', 'G', 'ER0'): ['boeger', 'boger'],
#  ('B', 'OW1', 'HH', 'AH0', 'L'): ['boehle', 'bohle'],
#  ('B', 'OW1', 'L', 'ER0'): ['boehler', 'bohler', 'bolar', 'boler', 'bowler'],
#  ('B', 'OW1', 'L', 'K'): ['boehlke', 'bohlke'],
#  ('B', 'OW1', 'M'): ['boehm', 'boehme'],
#  ('B', 'OW1', 'M', 'ER0'): ['boehmer', 'bohmer', 'bomer', 'bowmer'],
#  ('B', 'OW1', 'N', 'ER0'): ['boehner', 'bohner', 'bonar', 'boner'],
#  ('B', 'OW1', 'N', 'IH0', 'NG'): ['boehning', 'boning'],
#  ('B', 'OW1', 'IH0', 'NG'): ['boeing', 'bowing'],
#  ('B', 'OW1', 'L', 'K', 'AW0'): ['boelkow', 'bolkow'],
#  ('B', 'OW1', 'L', 'M', 'AH0', 'N'): ['boelman', 'bohlman', 'bohlmann'],
#  ('B', 'OW1', 'L', 'T', 'ER0'): ['boelter', 'bolter', 'boulter'],
#  ('B', 'AO1', 'R', 'G', 'ER0'): ['boerger', 'borger'],
#  ('B', 'AO1', 'R', 'N', 'ER0'): ['boerner', 'borner'],
#  ('B', 'OW1', 'CH', 'ER0'): ['boetcher', 'boettcher'],
#  ('B', 'OW1', 'V'): ['boeve', 'bove'],
#  ('B', 'AA1', 'G', 'D', 'AH0', 'N'): ['bogdan', 'bogden', 'bogdon'],
#  ('B', 'AA1', 'G', 'AH0', 'N'): ['bogen', 'boggan'],
#  ('B', 'UH1', 'G', 'IY0'): ['bogie', 'boogie'],
#  ('B', 'OW1', 'HH', 'AH0', 'N'): ['bohan', 'bohon'],
#  ('B', 'AA1', 'HH', 'AH0', 'N', 'AA0', 'N'): ['bohannon', 'bohanon'],
#  ('B', 'OW1', 'AH0', 'N'): ['bohen', 'bowen'],
#  ('B', 'OW1', 'L', 'AH0', 'N', 'D'): ['bohland', 'boland', 'bowland'],
#  ('B', 'OW1', 'L', 'AH0', 'N'): ['bohlen',
#   'bolan',
#   'bolen',
#   'bolon',
#   'bowlen'],
#  ('B', 'OW1', 'L', 'IH0', 'N'): ['bohlin', 'bolin', 'bowlin'],
#  ('B', 'OW1', 'L', 'IH0', 'NG'): ['bohling', 'boling', 'bolling', 'bowling'],
#  ('B', 'OW1', 'L', 'IH0', 'NG', 'ER0'): ['bohlinger', 'bolinger'],
#  ('B', 'OW1', 'M', 'AH0', 'N'): ['bohman', 'boman', 'bowman', 'bowmen'],
#  ('B', 'AA1', 'N', 'IH0', 'T'): ['bohnet', 'bonnett'],
#  ('B', 'AO1', 'R', 'AH0', 'N'): ['bohren', 'boren'],
#  ('B', 'AO1', 'R', 'ER0'): ['bohrer', 'borer'],
#  ('B', 'OY1', 'S'): ['boice', 'boyce'],
#  ('B', 'OY1', 'Z'): ['boies', "boy's", 'boyes', 'boys', "boys'", 'boyz'],
#  ('B', 'OY1', 'K'): ['boik', 'boike'],
#  ('B', 'OY1', 'L'): ['boil', 'boyle'],
#  ('B', 'OY1', 'S', 'IY0'): ['boise', 'boisi'],
#  ('B', 'OY1', 'S', 'AH0', 'N'): ['boisen', 'boysen'],
#  ('B', 'OW1', 'L', 'D'): ['bold', 'bowled'],
#  ('B', 'OW1', 'L', 'D', 'AH0', 'N'): ['bolden', 'boldon'],
#  ('B', 'OW1', 'L', 'D', 'ER0'): ['bolder', 'boulder'],
#  ('B', 'OW1', 'L', 'T'): ['boldt', 'bolt', 'bolte'],
#  ('B', 'OW1', 'L', 'IY0'): ['boley', 'bowley'],
#  ('B', 'AA1', 'L', 'M', 'AH0', 'N'): ['bollman', 'bollmann'],
#  ('B', 'OW1', 'L', 'T', 'AH0', 'N'): ['bolten', 'bolton'],
#  ('B', 'OW1', 'L', 'T', 'S'): ['bolts', 'boltz'],
#  ('B', 'AA1', 'N'): ['bon', 'bonn', 'bonne'],
#  ('B', 'AA1', 'N', 'D'): ['bond', 'bonde'],
#  ('B', 'AA1', 'N', 'D', 'IY0'): ['bondi', 'bondy'],
#  ('B', 'AA1', 'N', 'T'): ['bondt', 'bonte'],
#  ('B', 'OW1', 'N', 'IY0'): ['boney', 'boni', 'bony'],
#  ('B', 'OW0', 'N', 'IY1', 'N', 'IY0'): ['bonine', 'bonini'],
#  ('B', 'AA1', 'N', 'IY0'): ['bonney', 'bonnie', 'bonny'],
#  ('B', 'AA1', 'N', 'IH0', 'B', 'EH0', 'L'): ['bonnibel', 'bonnibelle'],
#  ('B', 'UW1', 'IY0'): ['booee', 'buoy'],
#  ('B', 'UW1', 'ER0'): ['booher', 'buer'],
#  ('B', 'UH1', 'K', 'B', 'AY2', 'N', 'D', 'ER0'): ['bookbinder', 'buchbinder'],
#  ('B', 'UW1', 'L'): ['boole', 'boule'],
#  ('B', 'UW1', 'N'): ['boon', 'boone'],
#  ('B', 'UH1', 'R', 'D', 'AH0'): ['boorda', 'burda'],
#  ('B', 'UH1', 'R', 'M', 'AH0', 'N'): ['boorman', 'buhrman'],
#  ('B', 'AO1', 'R', 'T', 'S'): ['boortz', 'bortz'],
#  ('B', 'UW1', 'Z'): ['boos', 'booz', 'booze', 'buus'],
#  ('B', 'UW1', 'T'): ['boot', 'boote', 'boutte'],
#  ('B', 'UW1', 'T', 'AH0', 'N'): ['booten', 'booton'],
#  ('B', 'UW1', 'TH'): ['booth', 'buth'],
#  ('B', 'UW1', 'T', 'IY0'): ['bootie', 'booty'],
#  ('B', 'UW1', 'T', 'S'): ['boots', 'bootz'],
#  ('B', 'AA1', 'P'): ['bop', 'bopp'],
#  ('B', 'AO1', 'R', 'AH0'): ['bora', 'borah'],
#  ('B', 'AO1', 'R', 'AH0', 'K'): ['borak', 'boruch'],
#  ('B', 'AO1', 'R', 'AH0', 'L'): ['boral', 'borel', 'borell', 'burrill'],
#  ('B', 'ER0', 'SH', 'AA1', 'R', 'D'): ['borchard', 'burchard'],
#  ('B', 'AO1', 'R', 'K'): ['borck', 'bork'],
#  ('B', 'AO1', 'R', 'IH0', 'K'): ['borek', 'boric'],
#  ('B', 'AO0', 'R', 'EH1', 'L', 'IY0'): ['borelli', 'borrelli'],
#  ('B', 'AO1', 'R', 'G'): ['borg', 'bourg'],
#  ('B', 'AO1', 'R', 'G', 'M', 'AH0', 'N'): ['borgman', 'borgmann'],
#  ('B', 'AO1', 'R', 'N'): ['born', 'borne', 'bourn', 'bourne'],
#  ('B', 'AO1', 'R', 'N', 'M', 'AH0', 'N'): ['borneman', 'bornemann', 'bornman'],
#  ('B', 'ER1', 'OW0'): ['boro', 'burro', 'burrough', 'burrow'],
#  ('B', 'AO1', 'R', 'AO0', 'F'): ['boroff', 'borroff'],
#  ('B', 'ER0', 'AW1', 'S', 'K', 'IY0'): ['boroski', 'borowsky'],
#  ('B', 'AO1', 'R', 'S'): ['borse', 'bourse'],
#  ('B', 'AO1', 'R', 'T', 'AH0', 'N'): ['borten', 'borton'],
#  ('B', 'AA1', 'S'): ['bos', 'boss', 'bosse'],
#  ('B', 'OW1', 'Z', 'ER0'): ['boser', 'bowser'],
#  ('B', 'AA1', 'S', 'AH0', 'L', 'ER0'): ['bosler', 'bossler'],
#  ('B', 'OW1', 'S', 'OW0'): ['boso', 'bosso'],
#  ('B', 'AA1', 'S', 'T'): ['bossed', 'bost'],
#  ('B', 'AO1', 'S', 'HH', 'AA2', 'R', 'T'): ['bosshardt', 'bosshart'],
#  ('B', 'AO1', 'S', 'IY0'): ['bossie', 'bossy'],
#  ('B', 'AO1', 'T'): ['bot', 'bought'],
#  ('B', 'OW0', 'T', 'EH1', 'L', 'OW0'): ['botelho', 'botello'],
#  ('B', 'AA1', 'T', 'AH0', 'L'): ['bottel', 'bottle'],
#  ('B', 'AA1', 'T', 'ER0', 'F'): ['bottorf', 'bottorff'],
#  ('B', 'UW1', 'D', 'IH0', 'N'): ['boudin', 'budin'],
#  ('B', 'UW2', 'D', 'R', 'OW1'): ['boudreau', 'boudreaux'],
#  ('B', 'AW1', 'T', 'AH0', 'N'): ['boughton', 'bouton'],
#  ('B', 'UW0', 'IY1'): ['bouie', 'buie'],
#  ('B', 'UW0', 'L', 'EY1'): ['boulais', 'boulay'],
#  ('B', 'OY1', 'ER0'): ['bouyer', 'boyer'],
#  ('B', 'AA1', 'K', 'S'): ['box', 'boxx'],
#  ('B', 'OY1'): ['boy', 'boye'],
#  ('B', 'OY1', 'D'): ['boyd', 'boyde'],
#  ('B', 'OY1', 'D', 'S', 'T', 'AH0', 'N'): ['boydston', 'boydstun'],
#  ('B', 'OY1', 'L', 'AH0', 'N'): ['boylan', 'boylen'],
#  ('B', 'OY1', 'L', 'S', 'T', 'AH0', 'N'): ['boyleston', 'boylston'],
#  ('B', 'OY1', 'T'): ['boyt', 'boyte'],
#  ('B', 'R', 'AA1', 'SH'): ['braasch', 'brosh', 'brosz'],
#  ('B', 'R', 'AE1', 'K'): ['brac', 'brack', 'brakke', 'braque'],
#  ('B', 'R', 'EY1', 'S', 'IY0'): ['bracey', 'bracy'],
#  ('B', 'R', 'AE1', 'CH'): ['brach', 'bratsch'],
#  ('B', 'R', 'AE1', 'K', 'ER0'): ['bracher', 'bracker'],
#  ('B', 'R', 'AE1', 'K', 'IH0', 'T'): ['bracket', 'brackett'],
#  ('B', 'R', 'AE1', 'D', 'B', 'EH2', 'R', 'IY0'): ['bradberry', 'bradbury'],
#  ('B', 'R', 'EY1'): ['brae', 'bray', 'brey'],
#  ('B', 'R', 'AE1', 'G'): ['brag', 'bragg'],
#  ('B', 'R', 'AA1', 'M'): ['brahm', 'brom', 'bromm'],
#  ('B', 'R', 'EY1', 'N', 'ER0', 'D'): ['brainard', 'brainerd'],
#  ('B', 'R', 'EY1', 'N', 'ER0'): ['brainer', 'braner', 'breighner'],
#  ('B', 'R', 'EY1', 'Z'): ['braise', 'brase'],
#  ('B', 'R', 'EY1', 'K'): ['brake', 'break'],
#  ('B', 'R', 'EY1', 'K', 'F', 'IY2', 'L', 'D'): ['brakefield', 'breakfield'],
#  ('B', 'R', 'EY1', 'K', 'ER0'): ['braker', 'breaker'],
#  ('B', 'R', 'EY1', 'K', 'IH0', 'NG'): ['braking', 'breaking'],
#  ('B', 'R', 'AE1', 'L', 'IY0'): ['braley', 'bralley'],
#  ('B', 'R', 'AA1', 'L', 'IY0'): ['braly', 'brolly'],
#  ('B', 'R', 'EY1', 'M', 'AH0', 'N'): ['braman', 'brayman'],
#  ('B', 'R', 'AE1', 'M', 'L', 'IH0', 'T'): ['bramlet', 'bramlett'],
#  ('B', 'R', 'AE1', 'N'): ['bran', 'brann'],
#  ('B', 'R', 'AE1', 'N', 'AH0', 'M'): ['branam',
#   'brannam',
#   'brannum',
#   'branum'],
#  ('B', 'R', 'AE1', 'N', 'CH'): ['branch', 'branche'],
#  ('B', 'R', 'AE1', 'NG', 'K', 'OW0'): ['branco', 'branko'],
#  ('B', 'R', 'AE1', 'N', 'D'): ['brand', 'brande'],
#  ('B', 'R', 'AE1', 'N', 'D', 'N', 'UW2'): ['brand-new', 'brandnew'],
#  ('B', 'R', 'AE1', 'N', 'D', 'AH0', 'L'): ['brandel', 'brandl', 'brandle'],
#  ('B', 'R', 'AE1', 'N', 'D', 'AH0', 'N'): ['branden', 'brandon'],
#  ('B', 'R', 'AE1', 'N', 'D', 'AH0', 'N', 'B', 'ER0', 'G'): ['brandenberg',
#   'brandenburg'],
#  ('B',
#   'R',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'N',
#   'B',
#   'ER0',
#   'G',
#   'ER0'): ['brandenberger', 'brandenburger'],
#  ('B', 'R', 'AE1', 'N', 'D', 'IY0'): ['brandi', 'brandy'],
#  ('B', 'R', 'AE1', 'N', 'T'): ['brandt', 'brant'],
#  ('B', 'R', 'AE1', 'N', 'T', 'N', 'ER0'): ['brandtner', 'brantner'],
#  ('B', 'R', 'AE1', 'N', 'IH0', 'G', 'AH0', 'N'): ['branigan', 'brannigan'],
#  ('B', 'R', 'AE1', 'N', 'AH0', 'N'): ['brannan',
#   'brannen',
#   'brannon',
#   'branon'],
#  ('B', 'R', 'AE1', 'N', 'S', 'K', 'AH0', 'M'): ['branscom',
#   'branscomb',
#   'branscum'],
#  ('B', 'R', 'AE1', 'N', 'T', 'L', 'IY0'): ['brantley', 'brantly'],
#  ('B', 'R', 'AE1', 'SH'): ['brasch', 'brash'],
#  ('B', 'R', 'AE1', 'S', 'AH0', 'L'): ['brasel', 'brasil', 'brassell'],
#  ('B', 'R', 'AE1', 'S', 'OW0'): ['brasow', 'brasso'],
#  ('B', 'R', 'AH0', 'S', 'OW1'): ['brasseaux', 'brosseau', 'brusseau'],
#  ...}

# %%
len([i for i in spelling_to_pronunciation if not re.search(r"'?s'?$",i)])
# Out:
# 99556

# %%
pronunciation = tuple(pronunciation_to_spelling.keys())
have_overlaps = set()
for i in enumerate(pronunciation):
    for j in enumerate(pronunciation[i+1:]):
        if

# %%
pronunciation = tuple(pronunciation_to_spelling.keys())
df = pd.DataFrame(index=range(len(pronunciation)), columns=range(len(pronunciation)))

# %%
[not_plural_or_posessive_homophones[i] for i in _not_plural_or_posessive_homophones if i not in not_plural_or_posessive_homophones ]
# Out:
# [["'cuse", 'cues', 'kuse', 'kuze', "q's", "q.'s", 'q.s', 'ques', 'queues'],
#  ["'s", 'es', 'ess', 'esse', 's', 's.'],
#  ['aase', 'os'],
#  ['aches', 'aix'],
#  ['acts', 'ax', 'axe', 'x.'],
#  ["ad's", 'adds', 'ads', "ads'", 'adz'],
#  ['ahs', 'oz'],
#  ['ais', 'ayes', 'eis', "eye's", 'eyes', "eyes'", "i's", "i.'s", 'i.s', 'ise'],
#  ['aix', 'eckes', 'ex', 'x', 'x.'],
#  ['alex', 'alexs'],
#  ['alice', 'allis', 'alyce'],
#  ['allais', 'allay'],
#  ['americorp', 'americorps'],
#  ['anas', 'anise'],
#  ["angelo's", 'angelos', 'angeloz'],
#  ["apec's", 'apex'],
#  ['arcs', 'arx'],
#  ["art's", 'arts', 'artz'],
#  ["b's", "b.'s", 'b.s', "be's", 'beas', "bee's", 'bees', 'beese', 'bes'],
#  ['baars', "bar's", "barr's", 'barres', 'barrs', 'bars', 'barz'],
#  ['baatz', 'botts', 'botz'],
#  ["back's", 'backes', 'backs', 'bax'],
#  ['baetz', 'beats', 'beets', 'beitz', 'bietz'],
#  ['baise', 'baize', "bay's", 'bayes', 'bays', 'bayse', 'baze'],
#  ["ball's", 'balls', 'balz', 'bawls'],
#  ["ban's", 'bans', 'benz'],
#  ["bart's", 'barts', 'bartz'],
#  ['base', 'bass'],
#  ["basic's", 'basics', 'basix'],
#  ['bass', 'basse'],
#  ['bats', 'batts', 'batz'],
#  ['bautz', 'bots'],
#  ['bearce', 'bearse', 'bearss', 'burse'],
#  ['beens', 'binns', 'bins', 'binz'],
#  ["bell's", 'belles', 'bells', "bells'", 'bels', 'belz'],
#  ["belt's", 'belts', 'beltz'],
#  ["ben's", 'bens', 'benz'],
#  ['bertz', 'burts'],
#  ['bess', 'besse'],
#  ["bet's", 'bets', 'betts', 'betz'],
#  ['bies', 'bise', "buy's", 'buys'],
#  ["bildt's", 'biltz'],
#  ['bis', 'biss', 'buice'],
#  ['bits', 'bitz'],
#  ['biz', 'buis'],
#  ['blose', 'blows'],
#  ['boals', 'boles', 'bolles', 'bolls', 'bolz', 'bowles', 'bowls'],
#  ['boase', 'boes', 'bose', 'bowes', 'bows', 'boze'],
#  ['boies', "boy's", 'boyes', 'boys', "boys'", 'boyz'],
#  ['bolts', 'boltz'],
#  ['boos', 'booz', 'booze', 'buus'],
#  ['boots', 'bootz'],
#  ['bos', 'boss', 'bosse'],
#  ['boulais', 'boulay'],
#  ['brats', 'bratz'],
#  ['brees', 'breese', 'breeze', 'briese'],
#  ['bress', 'bresse'],
#  ['bretts', 'bretz'],
#  ['brews', 'bruise', 'bruse'],
#  ['bricks', 'brix'],
#  ['brits', 'britts', 'britz'],
#  ["bro's", 'brose'],
#  ["brock's", 'brox'],
#  ['brockhaus', 'brockhouse'],
#  ['brons', 'bronze'],
#  ['brows', 'browse'],
#  ["bud's", 'buds', 'budz'],
#  ["bunt's", 'buntz'],
#  ['bus', 'buss', 'busse'],
#  ["but's", 'buts', 'butts', 'butz'],
#  ["c's",
#   "c.'s",
#   'c.s',
#   'cees',
#   'saez',
#   "sea's",
#   'seas',
#   'sease',
#   'sees',
#   'seese',
#   'seize',
#   'sies'],
#  ['cabela', "cabela's"],
#  ['caen', 'cahn', 'can', 'cann', 'cannes', 'kan', 'kann', 'kanne'],
#  ["caen's", "can's", 'cannes', 'cans', 'kanz'],
#  ["caen's", 'cons', "kahn's", "khan's", 'konz'],
#  ["cain's", 'caines', 'canes', 'kainz', "kane's", 'keynes'],
#  ['callace', 'callous', 'callus', 'kallus', 'kalous'],
#  ['carats', 'carrots', 'karatz'],
#  ['cars', 'cause', 'coz'],
#  ["cat's", 'cats', 'kats', 'katz'],
#  ['cause', 'kaus'],
#  ['cayes', "k's", "k.'s", 'kase', "kay's", 'kayes', 'kays'],
#  ['cease', 'cece', 'seis', 'siess'],
#  ["cell's", 'cells', "cells'", 'cels', 'sells', 'selz'],
#  ['celts', 'seltz'],
#  ['celts', 'keltz'],
#  ['cents', 'scents', 'sentz'],
#  ['cents', 'sense'],
#  ['chaise', 'shays', "shea's"],
#  ['challis', 'shali'],
#  ['chants', 'tschantz'],
#  ['chas', 'chazz'],
#  ['chats', 'chatz', "chatz'"],
#  ['chaus', 'chausse'],
#  ['chews', 'choose', 'chuse', 'tewes', 'tews'],
#  ["chi's", 'kise', 'kyes'],
#  ['chippendale', 'chippendales'],
#  ['chutes', 'schuetz', 'schuetze', 'shoots', 'shutes'],
#  ['cites', 'seitz', 'sights', "site's", 'sites'],
#  ['citron', "citron's"],
#  ['claes', 'claeys', 'clays', 'klase'],
#  ['claus', "claus'", 'clause', 'claws'],
#  ['clemence', 'klemens'],
#  ['clonts', 'clontz', 'klontz'],
#  ['close', 'clothes', 'klose'],
#  ['clots', 'klotz'],
#  ['clouse', 'klaus'],
#  ['clucks', 'klux'],
#  ['clutts', 'klutts', 'kluttz', 'klutz'],
#  ['coar', 'cohr', 'cor', 'core', 'corps', 'corr', 'kohr'],
#  ['coax', "coke's", 'cokes', 'kokes'],
#  ['cocks', 'cox', 'coxe'],
#  ["colt's", 'colts', 'kolts', 'koltz'],
#  ['coo', 'cou', 'coup', 'coups', 'khoo', 'khuu', 'koo', 'ku', 'qu'],
#  ['coontz', 'koonts', 'koontz'],
#  ["corp's", "corp.'s", 'corpse'],
#  ['cots', 'kaatz', 'kotz'],
#  ['counts', 'kountz'],
#  ["court's", 'courts', "courts'", 'kortz'],
#  ['crans', 'krans', 'kranz'],
#  ['crase', "cray's", 'crays', 'craze'],
#  ['crees', 'kreis', 'kriese'],
#  ['cress', 'kress', 'kresse'],
#  ["crew's", 'crewes', 'crews', 'cruise', 'cruse', 'cruz', 'cruze', 'kruse'],
#  ['cries', 'crise', 'krise'],
#  ['cros', 'cross', 'krause', 'krausse', 'kross'],
#  ['crose', "crow's", 'crows', 'kroes', 'kroeze'],
#  ['crotts', 'kraatz', 'krotz'],
#  ['crouse', 'kraus', 'krauss', 'krouse'],
#  ["curt's", 'curts', 'kertz', 'kirts', 'kurtz'],
#  ['cuts', 'cutts', 'kutz'],
#  ["d's", "d.'s", 'd.s', 'deas', "dee's", 'dees', 'deese', 'deis'],
#  ['dacs', 'dax', "dax'"],
#  ['dais', 'daise', 'dase', "day's", 'days', "days'", 'daze'],
#  ["dan's", 'danz'],
#  ['darice', 'doris'],
#  ['dats', 'datz'],
#  ["daya's", 'dias', 'diez'],
#  ['deats', 'deets', 'deetz', 'deitz', 'dietz'],
#  ['debris', 'dubree'],
#  ["dec's", 'decks', 'dex'],
#  ['deiss', 'dice', 'dise', 'dyce'],
#  ['demarais', 'demaray'],
#  ['dens', 'denz'],
#  ['derks', 'dircks', 'dirkes', 'dirks', 'dirkse'],
#  ['deuce', 'deuss', 'doose', 'duce'],
#  ['dewees', 'deweese', "dewey's"],
#  ["di's", 'dies', 'dise', 'dyes'],
#  ["dick's", 'dickes', 'dicks', 'dix'],
#  ['dilts', 'diltz'],
#  ['diocese', 'dioceses'],
#  ['disabilities', 'disability'],
#  ['dlugos', 'dlugosz'],
#  ["doe's", 'doze'],
#  ['dohse', 'dos', 'dose'],
#  ["don's", 'dons', 'donze'],
#  ['dorice', 'doris', 'dorris'],
#  ['dougan', 'dougans'],
#  ['dougan', 'dougans'],
#  ['drees', 'dreese', 'dreis'],
#  ['drewes', 'drews', 'druse', 'druze'],
#  ['dubois', 'duboise'],
#  ['dubois', 'duboise'],
#  ["duck's", 'ducks', "ducks'", 'dux'],
#  ['dupuis', 'dupuy'],
#  ["e's", "e.'s", 'e.s', 'ease'],
#  ['eaux', "o's", "o.'s", 'o.s', "o.s'", "oh's", 'ohs', 'ooohs', 'ose', 'owes'],
#  ['eave', 'eve', 'yves'],
#  ['effertz', 'efforts'],
#  ['ellice', 'ellis'],
#  ['ennes', 'enns', 'enz', "n's", "n.'s", 'n.s'],
#  ['eunice', 'yunis'],
#  ['eustace', 'eustis'],
#  ['eustice', 'justis'],
#  ['ewes',
#   'hughes',
#   "hughes'",
#   'hughs',
#   "u's",
#   "u.'s",
#   'u.s',
#   'use',
#   "yew's",
#   'yoos',
#   'youse',
#   "yu's"],
#  ['facts', 'fax'],
#  ['faulks', 'faux', 'fawkes'],
#  ["fay's", "faye's", 'faze', "fe's", 'phase'],
#  ['fees', 'feese'],
#  ['feitz', 'fights', 'fites'],
#  ['feltes', 'felts', 'feltz'],
#  ['fettes', 'fetz'],
#  ['fickes', 'fix'],
#  ['fits', 'fitts', 'fitz'],
#  ['fitzmaurice', 'fitzmorris'],
#  ['flecks', 'flex'],
#  ['fleisch', 'fleiss', "fleiss'"],
#  ["foale's", 'folz'],
#  ['folts', 'foltz'],
#  ['fons', 'fonz'],
#  ['foose', 'fuoss'],
#  ['force', 'forse', 'fourths'],
#  ['foss', 'fosse'],
#  ['fouts', 'foutz'],
#  ['francaise', 'francaises'],
#  ['frans', 'franz', 'franze'],
#  ['frase', 'fraze', "frey's", 'phrase'],
#  ['freas',
#   'frease',
#   "freeh's",
#   'frees',
#   'freese',
#   'freeze',
#   'freis',
#   'frese',
#   'friese',
#   'frieze',
#   'friis'],
#  ['freise', 'friess'],
#  ['frenz', "friend's", 'friends', "friends'"],
#  ['frets', 'fretz'],
#  ['fricks', 'frix'],
#  ['frits', 'fritts', 'fritz'],
#  ['fuentes', 'fuentez'],
#  ['fults', 'fultz'],
#  ['furnace', 'furnas'],
#  ["g's", "g.'s", 'g.s', "gee's", 'geez', 'geeze', 'jees', 'jeez', 'jeeze'],
#  ['gans', 'ganz'],
#  ['gase', 'gays', 'gaze'],
#  ['gaus', 'gause', 'gauze'],
#  ['gees', 'giese'],
#  ['geis', 'guise', "guy's", 'guys', "guys'"],
#  ['geise', 'geiss', 'guice'],
#  ['gens', 'genz', "jenn's", 'jens'],
#  ["gent's", 'gents', 'gentz', 'jentz'],
#  ['gets', 'getts', 'getz', 'goetz'],
#  ['ghose', 'goes', 'goghs', 'gose'],
#  ['gneiss', 'nice', 'nyce'],
#  ['goals', 'goelz', 'golz'],
#  ['gotts', 'gotz'],
#  ['graetz', 'greets'],
#  ['granese', 'grannies'],
#  ["grant's", 'grants', 'grantz', 'granz'],
#  ['gras', 'grass', 'grasse'],
#  ["gray's", 'grays', 'graze', "grey's"],
#  ['grease', 'greece', 'griess'],
#  ['greis', 'griese'],
#  ['greitz', 'grites'],
#  ['gries', 'grise'],
#  ['grits', 'gritz'],
#  ['groce', 'grohs', 'gros', 'gross', 'grosz'],
#  ['grose', 'grows'],
#  ['gumbs', 'gums', 'gumz'],
#  ['gutierres', 'gutierrez'],
#  ['haas', 'haase', 'haass', 'hahs', 'hasse', 'hoss'],
#  ['hans', 'honse'],
#  ["hart's", 'harts', 'hartz', "heart's", 'hearts'],
#  ['hase', 'hayes', 'hays', 'hayse', 'haze', 'heys'],
#  ["hat's", 'hats', 'hatz'],
#  ['haus', 'hause', 'hauss', 'house'],
#  ["he's", 'hees', 'heese'],
#  ["heck's", 'hex'],
#  ['heights', 'heitz', 'hites'],
#  ['heines', 'heins', 'heinz', 'heinze', 'hines', 'hynes'],
#  ['heise', 'heiss', 'hice'],
#  ["hen's", 'hennes', 'hens', 'henze'],
#  ['hendricks', 'hendriks', 'hendrix', 'hendryx'],
#  ['henrique', 'henriques', 'henriquez'],
#  ['henriques', 'henriquez'],
#  ["her's", 'hers', 'herz'],
#  ['hernandes', 'hernandez'],
#  ['hertz', 'hirtz', 'hurts'],
#  ['hess', 'hesse'],
#  ['hewes', 'hews', 'hues', 'hughes', "hughes'", 'hughs', 'huse'],
#  ['hicks', 'hix'],
#  ['highs', 'hise'],
#  ['hilts', 'hiltz'],
#  ['hints', 'hintz'],
#  ['hits', 'hitz'],
#  ["ho's", 'hoes', 'hose'],
#  ['holes', 'holz', 'wholes'],
#  ["holt's", 'holts', 'holtz'],
#  ['hoos', "who's", 'whose'],
#  ['horace', 'horus'],
#  ['hots', 'hotz'],
#  ['houghs', 'houze', "how's", "howe's", 'howes', 'howse', 'howze'],
#  ['houts', 'houtz'],
#  ['hritz', "ritt's", 'ritts', 'ritz', 'writs'],
#  ['hucks', 'hux'],
#  ["hult's", 'hults', 'hultz'],
#  ['hysterectomies', 'hysterectomy'],
#  ['isomedix', "isomedix's"],
#  ['jac', 'jack', 'jacques'],
#  ["jan's", 'jans', 'janz'],
#  ['janice', 'janis'],
#  ['jew', 'joo', 'ju', 'jue', 'jus'],
#  ['jinks', 'jinx', 'jynx'],
#  ['justice', 'justus'],
#  ['keas', "kee's", 'kees', 'keese', "key's", 'keyes', "keyes'", 'keys'],
#  ['keats', 'keatts', 'keitz'],
#  ['kits', 'kitts', 'kitz'],
#  ['kneece',
#   'kniess',
#   'neace',
#   'neece',
#   'neice',
#   'neiss',
#   'nice',
#   'niece',
#   'niess'],
#  ['knees', 'neas', 'nease', 'nees', 'neese', 'neis', 'niese'],
#  ['knicks', "knicks'", "nick's", 'nicks', "nikk's", 'nix', 'nyx'],
#  ['knits', 'nitz'],
#  ['knocks', 'knox'],
#  ['knots', "knott's", 'knotts', 'nots', 'notz'],
#  ['knows', "no's", 'noes', 'nose'],
#  ['kuns', 'kunz', 'kunze'],
#  ['la-crosse', 'lacross', 'lacrosse'],
#  ["lac's", 'lacks', 'lax'],
#  ['lais', 'lase', "lay's", 'lays', 'leis', 'leys'],
#  ['lait', 'lay', 'laye', 'lei', 'les', 'ley', 'leyh'],
#  ['laos', 'louse'],
#  ['lapps', 'laps', 'lapse'],
#  ['lass', 'last'],
#  ['lats', "lot's", 'lots', 'lottes', 'lotts', 'lotz'],
#  ['lats', 'latz'],
#  ['laurice', 'loris'],
#  ['leas', "lee's", 'lees', "li's", 'liese'],
#  ['leiss', 'lice'],
#  ['lens', 'lenz'],
#  ['lents', 'lentz', 'lentzsch'],
#  ["let's", 'lets', 'letts', 'letz'],
#  ["leu's", 'loos', 'lose', "lou's", 'luiz', 'luse'],
#  ["levitt's", "levitte's", 'levitz'],
#  ['lewey', 'lewi', 'lewy', 'louis'],
#  ['lies', 'lise'],
#  ['lincks', "link's", 'links', 'lynx'],
#  ['lins', 'linz', "lynn's"],
#  ['lits', 'litts', 'litz'],
#  ['locks', 'lox'],
#  ['lohse', 'los'],
#  ['lox', 'lucks', 'luks', 'lux'],
#  ['lyonnais', 'lyonnaise'],
#  ['maahs', 'maas', 'mas', 'maz'],
#  ["mac's", "mack's", 'macks', 'macs', 'max', 'maxx'],
#  ['mace', 'mais'],
#  ['maddocks', 'maddox', 'maddux'],
#  ["mae's",
#   'maes',
#   'maize',
#   'mase',
#   "may's",
#   'mayes',
#   'mays',
#   "mays'",
#   'mayse',
#   'maze'],
#  ['maerz', 'mairs', "mare's", 'mares'],
#  ["maine's", 'maines', 'mains', 'mainz', 'manes', 'maynes'],
#  ['malice', 'mallis'],
#  ["man's", "mann's", 'mannes', 'manns', 'mans', 'manz'],
#  ['marcks', "mark's", 'marks', 'marques', 'marx', "merc's"],
#  ['maritz', 'merits', 'merritts'],
#  ['marrs', 'mars', "mars'", 'marz'],
#  ["mart's", 'marts', 'martz'],
#  ['mass', 'mass.', 'masse'],
#  ['mass.', 'massachusetts', "massachusetts'", 'massachussetts'],
#  ['matis', 'mattice'],
#  ['mats', 'mattes', 'matts', 'matz'],
#  ['mattocks', 'mattox'],
#  ["maverick's", 'mavericks', 'maverix'],
#  ['mcnease', 'mcnees'],
#  ['mease', 'mees', 'meis'],
#  ['meats', 'meets', 'meitz'],
#  ['meckes', 'mex'],
#  ['meiss', 'mice'],
#  ['melisse', 'mellis'],
#  ['melts', 'meltz'],
#  ["men's", 'mens', 'menz', 'menze'],
#  ['mers', 'merz'],
#  ['messrs', 'messrs.', 'mssrs', 'mssrs.'],
#  ["met's", 'mets', "mets'", 'metts', 'metz'],
#  ['meuse', 'mewes', 'muse'],
#  ['mies', 'mize'],
#  ['milhous', 'milhouse', 'millhouse'],
#  ["mill's", 'mills', "mills'", 'mils', 'milz'],
#  ["mint's", 'mints', 'mintz'],
#  ['misses', 'missis', 'missus', 'mrs', 'mrs.'],
#  ['moes', 'mose'],
#  ['moise', 'moyes'],
#  ['monts', 'montz'],
#  ["moore's", "mor's", 'morze'],
#  ['moos', 'muise'],
#  ['moots', 'mootz'],
#  ['morais', 'moray'],
#  ['morice', 'moris', 'morris', 'morriss'],
#  ['moros', 'moroz'],
#  ['morse', 'morss'],
#  ['mots', "mott's", 'motts', 'motz'],
#  ['mounts', 'mountz'],
#  ['ms', 'ms.'],
#  ['munns', 'muns', 'munz'],
#  ['mutts', 'mutz'],
#  ['myrtice', 'myrtis'],
#  ['nantes', 'nantz'],
#  ['nase', 'nays'],
#  ['navas', 'novice'],
#  ['necks', 'nex', 'next'],
#  ['nets', 'netz'],
#  ['neuhaus', 'newhouse'],
#  ['noise', 'noyes'],
#  ['noose', 'nous'],
#  ['notice', 'notis'],
#  ['ochs', 'ox'],
#  ['olympiad', 'olympiads'],
#  ['oohs', 'ooohs', 'ooze'],
#  ["p's", "p.'s", 'p.s', 'peas', 'pease', 'pees'],
#  ["pac's", 'packs', 'pacs', 'pacts', "pak's", 'pax'],
#  ['paetz', "peat's", "peet's", 'peets', 'peetz', 'peitz', "pete's", 'pietz'],
#  ['pais', 'paiz', 'pays', "pei's"],
#  ['palace', 'pallas'],
#  ['pas', 'paz'],
#  ["pat's", 'pats', 'patz'],
#  ['pause', 'paws'],
#  ['paychecks', 'paychex'],
#  ['pearse', 'perce', 'pers', 'perse', 'purse'],
#  ["pell's", 'pels', 'pelz'],
#  ['pelts', 'peltz'],
#  ['peres', "peres'", 'perez'],
#  ["peru's", 'peruse'],
#  ['perz', 'purrs'],
#  ["pet's", 'pets', 'petz'],
#  ['picks', 'pix'],
#  ["pill's", 'pills', 'pilz'],
#  ['pits', "pitt's", 'pitts', 'pitz'],
#  ["plack's", 'plaques', 'plax'],
#  ["plant's", 'plants', "plants'", 'plantz'],
#  ['plas', 'plass', 'plasse'],
#  ['platts', 'platz'],
#  ['pleas', 'please', 'plese'],
#  ['plots', 'plotts', 'plotz'],
#  ['pocks', 'pox'],
#  ["poe's", 'pose', 'pows'],
#  ["pollack's", 'pollux'],
#  ['populace', 'populous'],
#  ["port's", 'ports', 'portz'],
#  ['praise', 'prays', 'preys'],
#  ['preece', 'priess'],
#  ['preiss', 'price', 'pryce'],
#  ['prentice', 'prentiss'],
#  ['press', "press'", 'presse'],
#  ['pries', 'prize'],
#  ['prins', 'prinz'],
#  ['prints', 'printz'],
#  ['pritts', 'pritz'],
#  ["pro's", 'pros', "pros'", 'prose'],
#  ['prows', 'prowse'],
#  ["public's", 'publics', 'publix'],
#  ['putts', 'putz'],
#  ['quarts', 'quartz'],
#  ['quiros', 'quiroz'],
#  ['raatz', 'rots', 'rotz'],
#  ['race', 'rais'],
#  ['racks', 'rax'],
#  ['raise', 'rase', "ray's", 'rays', 'raze', "re's", "rea's", 'res'],
#  ['rans', 'ranz'],
#  ["rao's", 'rouse'],
#  ["rat's", 'rats', 'ratts', 'ratz'],
#  ['reas', 'rees', 'reis', 'riese'],
#  ['rease', 'reece', 'reese', 'reise', 'rhys', 'riess'],
#  ['reiss', 'rice', 'wrice'],
#  ['reits',
#   'reitz',
#   "right's",
#   'rights',
#   "rights'",
#   "rite's",
#   'rites',
#   "wright's",
#   'wrights',
#   'writes'],
#  ['rens', 'renz'],
#  ['rents', 'rentz'],
#  ['rex', 'wrecks'],
#  ["rick's", 'ricks', 'rix'],
#  ['ries', 'rise'],
#  ['riss', 'risse', 'rys'],
#  ["rock's", 'rocks', 'rox'],
#  ['roes', "roh's", 'rohs', 'rose', "row's", "rowe's", 'rowes', 'rows'],
#  ['roos', 'roose', 'rues', 'ruse'],
#  ['roots', 'routes', 'ruetz'],
#  ['ross', "ross'", 'rosse'],
#  ['rucks', 'rux'],
#  ['rus', 'russ', 'russe'],
#  ['ruts', 'rutts', 'rutz'],
#  ['sachs', "sachs'", 'sacks', 'sacs', 'saks', 'sax', 'saxe'],
#  ['sachs', 'socks', 'sox'],
#  ['saenz', 'scenes'],
#  ['sais', 'saiz'],
#  ['salas', 'salaz', 'sallas'],
#  ['salls', 'salz', 'sauls'],
#  ['sandos', 'sandose', 'sandoz'],
#  ['sannes', 'sans', 'sanz'],
#  ['sas', 'sass', 'sasse'],
#  ['sauce', 'soss'],
#  ['saus', 'sause', 'saws'],
#  ['scheets', 'scheetz', 'sheats', 'sheets', 'sheetz'],
#  ['schertz', 'shirts', 'shurtz'],
#  ['schiltz', 'shilts'],
#  ["schmidt's", 'schmitz'],
#  ['scholtes', 'scholtz', 'shoults', 'shoultz'],
#  ['scholz', 'scholze', 'shoals', 'sholes'],
#  ["schott's", 'shatz', 'shots', 'shotts'],
#  ['schutz', 'shuts', 'shutts'],
#  ['searfoss', 'surface'],
#  ['seeks', 'seix', 'sikhs'],
#  ['self-destruction', 'self-destructs'],
#  ['servais', 'survey'],
#  ['service', 'servis', 'serviss'],
#  ['shorts', "shorts'", 'shortz', "shortz'"],
#  ['sighs', 'size', "tsai's"],
#  ['sits', 'sitts', 'sitz'],
#  ['sleds', 'sledz'],
#  ['sluts', 'slutz'],
#  ['solace', 'solis'],
#  ['spats', 'spatz'],
#  ['speas', 'spease', 'spees', 'spiess'],
#  ['spence', 'spens'],
#  ['spits', 'spitz'],
#  ['staats', 'stotts', 'stotz'],
#  ['stats', 'statz'],
#  ['sticks', 'styx'],
#  ["store's", 'stores', "stores'", 'storrs', 'storz'],
#  ['storts', 'stortz', "stuart's"],
#  ['straus', 'strause', 'strauss', 'strouse'],
#  ['struts', 'strutz'],
#  ['stults', 'stultz'],
#  ['stunts', 'stuntz'],
#  ['stutts', 'stutz'],
#  ['suess', 'suisse', 'swiss'],
#  ['swarts', 'swartz'],
#  ['sways', 'swayze'],
#  ['sweats', 'swetz'],
#  ["t's", "t.'s", 't.s', 'teas', 'tease', 'tees'],
#  ['tacks', 'tax'],
#  ['teats', 'teets', 'tietz'],
#  ["tech's", 'techs', "teck's", 'tex'],
#  ['terese', "terry's"],
#  ['tern', 'ternes', 'terns', 'turns'],
#  ["thee's", 'these'],
#  ["track's", 'tracks', 'trax'],
#  ['trease', 'trees', 'treese'],
#  ['tucks', 'tuks', 'tux'],
#  ['u.s.', 'us'],
#  ['use', 'yous'],
#  ['valdes', 'valdez'],
#  ['vause', 'voss'],
#  ['verde', 'verdes'],
#  ['vers', 'verse'],
#  ['verses', 'versus', 'vs.'],
#  ['vertz', 'virts'],
#  ['vocs', 'vox'],
#  ['voeltz', 'volts', 'voltz'],
#  ['voelz', 'voles', 'volz'],
#  ['vous', 'vu'],
#  ['wacks', 'wax', 'whacks'],
#  ["wall's", 'walles', 'walls', 'walz'],
#  ['wallace', 'wallis'],
#  ['walts', 'waltz'],
#  ['wants', 'wantz'],
#  ['wares', 'warez', 'wears', "where's"],
#  ["watt's", 'watts', 'watz'],
#  ['weis', 'weiss', 'weisse', 'wice'],
#  ['weise', 'wiess'],
#  ['welles', "welles'", 'wells', 'welz'],
#  ['wenz', "when's"],
#  ['werts', 'wertz', 'wirtz', 'worts', 'wurtz'],
#  ["why's", 'whys', 'wies', 'wise', 'wyse', "y's", "y.'s"],
#  ['wickes', 'wicks', 'wix'],
#  ['wilts', 'wiltse', 'wiltz'],
#  ["wit's", 'wits', 'witts', 'witz'],
#  ['yonts', 'yontz'],
#  ["z's", "z.'s", 'zeese', 'zeis'],
#  ['zens', 'zenz']]

# %%
# attempt 1: get all puns separated by one edit
# restrict to swap-only edits
all_pronunciations = frozenset(i for i in pronunciation_to_spelling)
puns = {} # {pronounced_word: [puns of distance 1, puns of distance 2, ...]}

for word in all_pronunciations:
    for index in range(len(word)):
        for target_symbol in SYMBOLS:
            if target_symbol != word[index]:
                pun_attempt = tuple([*word[:index], target_symbol, *word[index + 1:]])
                if pun_attempt in all_pronunciations:
                    if word in puns:
                        puns[word][0].append(pun_attempt)
                    else:
                        puns[word] = [[pun_attempt]]
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.58 µs

# %%
puns
# Out:
# {('Y', 'UW1', 'AO0', 'NG'): [[('Y', 'UW1', 'IH0', 'NG')]],
#  ('T',
#   'AY1',
#   'ER0',
#   'Z'): [[('B', 'AY1', 'ER0', 'Z'),
#    ('F', 'AY1', 'ER0', 'Z'),
#    ('HH', 'AY1', 'ER0', 'Z'),
#    ('L', 'AY1', 'ER0', 'Z'),
#    ('M', 'AY1', 'ER0', 'Z'),
#    ('P', 'AY1', 'ER0', 'Z'),
#    ('S', 'AY1', 'ER0', 'Z'),
#    ('V', 'AY1', 'ER0', 'Z'),
#    ('W', 'AY1', 'ER0', 'Z'),
#    ('T', 'AW1', 'ER0', 'Z'),
#    ('T', 'AY1', 'D', 'Z'),
#    ('T', 'AY1', 'L', 'Z'),
#    ('T', 'AY1', 'M', 'Z'),
#    ('T', 'AY1', 'N', 'Z'),
#    ('T', 'AY1', 'ER0', 'D')]],
#  ('F',
#   'AE1',
#   'N',
#   'CH',
#   'ER0'): [[('HH', 'AE1', 'N', 'CH', 'ER0'),
#    ('R', 'AE1', 'N', 'CH', 'ER0'),
#    ('F', 'IH1', 'N', 'CH', 'ER0')]],
#  ('R',
#   'AA1',
#   'S',
#   'T'): [[('B', 'AA1', 'S', 'T'),
#    ('D', 'AA1', 'S', 'T'),
#    ('F', 'AA1', 'S', 'T'),
#    ('JH', 'AA1', 'S', 'T'),
#    ('K', 'AA1', 'S', 'T'),
#    ('N', 'AA1', 'S', 'T'),
#    ('R', 'AE1', 'S', 'T'),
#    ('R', 'AH1', 'S', 'T'),
#    ('R', 'EH1', 'S', 'T'),
#    ('R', 'EY1', 'S', 'T'),
#    ('R', 'IH1', 'S', 'T'),
#    ('R', 'OW1', 'S', 'T'),
#    ('R', 'UW1', 'S', 'T'),
#    ('R', 'AA1', 'K', 'T'),
#    ('R', 'AA1', 'S', 'OW0')]],
#  ('Z',
#   'IH1',
#   'R',
#   'OW0'): [[('B', 'IH1', 'R', 'OW0'),
#    ('F', 'IH1', 'R', 'OW0'),
#    ('HH', 'IH1', 'R', 'OW0'),
#    ('L', 'IH1', 'R', 'OW0'),
#    ('M', 'IH1', 'R', 'OW0'),
#    ('N', 'IH1', 'R', 'OW0'),
#    ('P', 'IH1', 'R', 'OW0'),
#    ('Z', 'AA1', 'R', 'OW0'),
#    ('Z', 'AE1', 'R', 'OW0'),
#    ('Z', 'EH1', 'R', 'OW0'),
#    ('Z', 'IY1', 'R', 'OW0'),
#    ('Z', 'IH1', 'N', 'OW0'),
#    ('Z', 'IH1', 'P', 'OW0'),
#    ('Z', 'IH1', 'Z', 'OW0'),
#    ('Z', 'IH1', 'R', 'B'),
#    ('Z', 'IH1', 'R', 'N')]],
#  ('G',
#   'R',
#   'AY1',
#   'P',
#   'S'): [[('G', 'R', 'EY1', 'P', 'S'),
#    ('G', 'R', 'IH1', 'P', 'S'),
#    ('G', 'R', 'OW1', 'P', 'S'),
#    ('G', 'R', 'UW1', 'P', 'S'),
#    ('G', 'R', 'AY1', 'T', 'S'),
#    ('G', 'R', 'AY1', 'P', 'T')]],
#  ('K', 'AH0', 'N', 'F', 'EH1', 'S'): [[('K', 'AH0', 'N', 'T', 'EH1', 'S')]],
#  ('B',
#   'AW1',
#   'M',
#   'S',
#   'T',
#   'AA2',
#   'R',
#   'K'): [[('B', 'AA1', 'M', 'S', 'T', 'AA2', 'R', 'K')]],
#  ('JH',
#   'EH1',
#   'N',
#   'ER0',
#   'EY2',
#   'T',
#   'IH0',
#   'D'): [[('V', 'EH1', 'N', 'ER0', 'EY2', 'T', 'IH0', 'D'),
#    ('JH', 'EH1', 'N', 'ER0', 'EY2', 'T', 'AH0', 'D'),
#    ('JH', 'EH1', 'N', 'ER0', 'EY2', 'T', 'IH0', 'NG')]],
#  ('Y',
#   'OW0',
#   'B',
#   'IY1',
#   'N',
#   'AH0'): [[('Y', 'AH0', 'B', 'IY1', 'N', 'AH0')]],
#  ('K',
#   'ER1',
#   'W',
#   'IH0',
#   'N'): [[('B', 'ER1', 'W', 'IH0', 'N'),
#    ('D', 'ER1', 'W', 'IH0', 'N'),
#    ('G', 'ER1', 'W', 'IH0', 'N'),
#    ('M', 'ER1', 'W', 'IH0', 'N'),
#    ('SH', 'ER1', 'W', 'IH0', 'N'),
#    ('K', 'ER1', 'L', 'IH0', 'N'),
#    ('K', 'ER1', 'T', 'IH0', 'N'),
#    ('K', 'ER1', 'V', 'IH0', 'N'),
#    ('K', 'ER1', 'W', 'AH0', 'N'),
#    ('K', 'ER1', 'W', 'AO0', 'N')]],
#  ('L', 'EH1', 'V', 'L', 'ER0', 'Z'): [[('L', 'AH1', 'V', 'L', 'ER0', 'Z')]],
#  ('P',
#   'L',
#   'AY1',
#   'T'): [[('AH0', 'L', 'AY1', 'T'),
#    ('B', 'L', 'AY1', 'T'),
#    ('F', 'L', 'AY1', 'T'),
#    ('K', 'L', 'AY1', 'T'),
#    ('S', 'L', 'AY1', 'T'),
#    ('P', 'L', 'AA1', 'T'),
#    ('P', 'L', 'AE1', 'T'),
#    ('P', 'L', 'AO1', 'T'),
#    ('P', 'L', 'EH1', 'T'),
#    ('P', 'L', 'EY1', 'T'),
#    ('P', 'L', 'IH1', 'T'),
#    ('P', 'L', 'IY1', 'T'),
#    ('P', 'L', 'AY1', 'AH0'),
#    ('P', 'L', 'AY1', 'D'),
#    ('P', 'L', 'AY1', 'ER0'),
#    ('P', 'L', 'AY1', 'Z')]],
#  ('P',
#   'AE1',
#   'JH',
#   'AH0',
#   'N',
#   'T',
#   'S'): [[('P', 'AE1', 'T', 'AH0', 'N', 'T', 'S')]],
#  ('CH',
#   'IH1',
#   'S',
#   'AH0',
#   'M'): [[('B', 'IH1', 'S', 'AH0', 'M'),
#    ('K', 'IH1', 'S', 'AH0', 'M'),
#    ('S', 'IH1', 'S', 'AH0', 'M'),
#    ('CH', 'IH1', 'T', 'AH0', 'M'),
#    ('CH', 'IH1', 'Z', 'AH0', 'M'),
#    ('CH', 'IH1', 'S', 'OW0', 'M')]],
#  ('G',
#   'AA1',
#   'V',
#   'ER0',
#   'N',
#   'ER0',
#   'Z'): [[('G', 'AH1', 'V', 'ER0', 'N', 'ER0', 'Z')]],
#  ('S',
#   'UW0',
#   'P',
#   'IY1',
#   'R',
#   'IY0',
#   'ER0',
#   'Z'): [[('S', 'UW0', 'P', 'IH1', 'R', 'IY0', 'ER0', 'Z')]],
#  ('HH',
#   'EH1',
#   'L',
#   'Z'): [[('B', 'EH1', 'L', 'Z'),
#    ('D', 'EH1', 'L', 'Z'),
#    ('F', 'EH1', 'L', 'Z'),
#    ('JH', 'EH1', 'L', 'Z'),
#    ('K', 'EH1', 'L', 'Z'),
#    ('M', 'EH1', 'L', 'Z'),
#    ('N', 'EH1', 'L', 'Z'),
#    ('P', 'EH1', 'L', 'Z'),
#    ('S', 'EH1', 'L', 'Z'),
#    ('SH', 'EH1', 'L', 'Z'),
#    ('T', 'EH1', 'L', 'Z'),
#    ('W', 'EH1', 'L', 'Z'),
#    ('Y', 'EH1', 'L', 'Z'),
#    ('HH', 'AE1', 'L', 'Z'),
#    ('HH', 'AH1', 'L', 'Z'),
#    ('HH', 'AO1', 'L', 'Z'),
#    ('HH', 'AW1', 'L', 'Z'),
#    ('HH', 'AY1', 'L', 'Z'),
#    ('HH', 'EY1', 'L', 'Z'),
#    ('HH', 'IH1', 'L', 'Z'),
#    ('HH', 'IY1', 'L', 'Z'),
#    ('HH', 'OW1', 'L', 'Z'),
#    ('HH', 'EH1', 'D', 'Z'),
#    ('HH', 'EH1', 'M', 'Z'),
#    ('HH', 'EH1', 'N', 'Z'),
#    ('HH', 'EH1', 'R', 'Z'),
#    ('HH', 'EH1', 'L', 'D'),
#    ('HH', 'EH1', 'L', 'ER0'),
#    ('HH', 'EH1', 'L', 'F'),
#    ('HH', 'EH1', 'L', 'IY0'),
#    ('HH', 'EH1', 'L', 'K'),
#    ('HH', 'EH1', 'L', 'M'),
#    ('HH', 'EH1', 'L', 'P'),
#    ('HH', 'EH1', 'L', 'T'),
#    ('HH', 'EH1', 'L', 'TH')]],
#  ('P',
#   'Y',
#   'UH1',
#   'R',
#   'IH0',
#   'NG',
#   'T',
#   'AH0',
#   'N'): [[('K', 'Y', 'UH1', 'R', 'IH0', 'NG', 'T', 'AH0', 'N')]],
#  ('K',
#   'AA1',
#   'R',
#   'P',
#   'IY0',
#   'OW0'): [[('K', 'AA1', 'R', 'D', 'IY0', 'OW0')]],
#  ('D',
#   'IH2',
#   'S',
#   'AH0',
#   'P',
#   'IY1',
#   'R',
#   'AH0',
#   'N',
#   'S',
#   'IH0',
#   'Z'): [[('D',
#     'IH2',
#     'S',
#     'AH0',
#     'P',
#     'IH1',
#     'R',
#     'AH0',
#     'N',
#     'S',
#     'IH0',
#     'Z')]],
#  ('D', 'OW1', 'L', 'Z', 'IH0', 'Z'): [[('R', 'OW1', 'L', 'Z', 'IH0', 'Z')]],
#  ('K', 'L', 'AH0', 'V', 'EH1', 'T'): [[('K', 'L', 'AH0', 'V', 'AY1', 'T')]],
#  ('R', 'IY1', 'T', 'EY2', 'L'): [[('R', 'IY1', 'S', 'EY2', 'L')]],
#  ('JH',
#   'EH2',
#   'N',
#   'ER0',
#   'EY1',
#   'SH',
#   'AH0',
#   'N'): [[('V', 'EH2', 'N', 'ER0', 'EY1', 'SH', 'AH0', 'N')]],
#  ('K',
#   'AH0',
#   'N',
#   'S',
#   'IH1',
#   'S',
#   'T',
#   'AH0',
#   'N',
#   'S'): [[('K', 'AH0', 'N', 'S', 'IH1', 'S', 'T', 'AH0', 'N', 'T')]],
#  ('B',
#   'OY1',
#   'Z'): [[('JH', 'OY1', 'Z'),
#    ('M', 'OY1', 'Z'),
#    ('N', 'OY1', 'Z'),
#    ('P', 'OY1', 'Z'),
#    ('R', 'OY1', 'Z'),
#    ('T', 'OY1', 'Z'),
#    ('B', 'AA1', 'Z'),
#    ('B', 'AE1', 'Z'),
#    ('B', 'AH1', 'Z'),
#    ('B', 'AO1', 'Z'),
#    ('B', 'AW1', 'Z'),
#    ('B', 'AY1', 'Z'),
#    ('B', 'ER1', 'Z'),
#    ('B', 'EY1', 'Z'),
#    ('B', 'IH1', 'Z'),
#    ('B', 'IY1', 'Z'),
#    ('B', 'OW1', 'Z'),
#    ('B', 'UW1', 'Z'),
#    ('B', 'OY1', 'D'),
#    ('B', 'OY1', 'ER0'),
#    ('B', 'OY1', 'K'),
#    ('B', 'OY1', 'L'),
#    ('B', 'OY1', 'N'),
#    ('B', 'OY1', 'S'),
#    ('B', 'OY1', 'T')]],
#  ('W',
#   'EY1',
#   'K',
#   'L',
#   'IY0'): [[('W', 'AE1', 'K', 'L', 'IY0'),
#    ('W', 'AO1', 'K', 'L', 'IY0'),
#    ('W', 'IH1', 'K', 'L', 'IY0'),
#    ('W', 'IY1', 'K', 'L', 'IY0')]],
#  ('V',
#   'EH1',
#   'T',
#   'S'): [[('B', 'EH1', 'T', 'S'),
#    ('D', 'EH1', 'T', 'S'),
#    ('F', 'EH1', 'T', 'S'),
#    ('G', 'EH1', 'T', 'S'),
#    ('HH', 'EH1', 'T', 'S'),
#    ('JH', 'EH1', 'T', 'S'),
#    ('K', 'EH1', 'T', 'S'),
#    ('L', 'EH1', 'T', 'S'),
#    ('M', 'EH1', 'T', 'S'),
#    ('N', 'EH1', 'T', 'S'),
#    ('P', 'EH1', 'T', 'S'),
#    ('R', 'EH1', 'T', 'S'),
#    ('S', 'EH1', 'T', 'S'),
#    ('W', 'EH1', 'T', 'S'),
#    ('V', 'AE1', 'T', 'S'),
#    ('V', 'ER1', 'T', 'S'),
#    ('V', 'IY1', 'T', 'S'),
#    ('V', 'OW1', 'T', 'S'),
#    ('V', 'OY1', 'T', 'S'),
#    ('V', 'EH1', 'K', 'S'),
#    ('V', 'EH1', 'T', 'AH0'),
#    ('V', 'EH1', 'T', 'ER0')]],
#  ('B',
#   'AO1',
#   'R',
#   'S',
#   'K',
#   'IY0'): [[('G', 'AO1', 'R', 'S', 'K', 'IY0'),
#    ('N', 'AO1', 'R', 'S', 'K', 'IY0'),
#    ('B', 'AA1', 'R', 'S', 'K', 'IY0')]],
#  ('K',
#   'R',
#   'IH1',
#   'SH'): [[('F', 'R', 'IH1', 'SH'),
#    ('T', 'R', 'IH1', 'SH'),
#    ('K', 'L', 'IH1', 'SH'),
#    ('K', 'R', 'AE1', 'SH'),
#    ('K', 'R', 'AH1', 'SH'),
#    ('K', 'R', 'AW1', 'SH'),
#    ('K', 'R', 'EH1', 'SH'),
#    ('K', 'R', 'IH1', 'B'),
#    ('K', 'R', 'IH1', 'CH'),
#    ('K', 'R', 'IH1', 'K'),
#    ('K', 'R', 'IH1', 'L'),
#    ('K', 'R', 'IH1', 'M'),
#    ('K', 'R', 'IH1', 'NG'),
#    ('K', 'R', 'IH1', 'P'),
#    ('K', 'R', 'IH1', 'R'),
#    ('K', 'R', 'IH1', 'S'),
#    ('K', 'R', 'IH1', 'Z')]],
#  ('HH',
#   'AH1',
#   'F',
#   'S',
#   'T',
#   'IH0',
#   'D',
#   'AH0',
#   'L',
#   'ER0'): [[('HH', 'AH1', 'F', 'S', 'T', 'IH0', 'T', 'AH0', 'L', 'ER0')]],
#  ('L',
#   'IY1',
#   'D',
#   'AH0',
#   'L'): [[('B', 'IY1', 'D', 'AH0', 'L'),
#    ('CH', 'IY1', 'D', 'AH0', 'L'),
#    ('K', 'IY1', 'D', 'AH0', 'L'),
#    ('M', 'IY1', 'D', 'AH0', 'L'),
#    ('N', 'IY1', 'D', 'AH0', 'L'),
#    ('R', 'IY1', 'D', 'AH0', 'L'),
#    ('W', 'IY1', 'D', 'AH0', 'L'),
#    ('L', 'AY1', 'D', 'AH0', 'L'),
#    ('L', 'EY1', 'D', 'AH0', 'L'),
#    ('L', 'IH1', 'D', 'AH0', 'L'),
#    ('L', 'IY1', 'B', 'AH0', 'L'),
#    ('L', 'IY1', 'G', 'AH0', 'L'),
#    ('L', 'IY1', 'TH', 'AH0', 'L'),
#    ('L', 'IY1', 'V', 'AH0', 'L'),
#    ('L', 'IY1', 'D', 'AH0', 'M')]],
#  ('L',
#   'OW1',
#   'JH'): [[('B', 'OW1', 'JH'),
#    ('D', 'OW1', 'JH'),
#    ('HH', 'OW1', 'JH'),
#    ('V', 'OW1', 'JH'),
#    ('L', 'AA1', 'JH'),
#    ('L', 'EH1', 'JH'),
#    ('L', 'EY1', 'JH'),
#    ('L', 'IY1', 'JH'),
#    ('L', 'UW1', 'JH'),
#    ('L', 'OW1', 'B'),
#    ('L', 'OW1', 'D'),
#    ('L', 'OW1', 'DH'),
#    ('L', 'OW1', 'ER0'),
#    ('L', 'OW1', 'F'),
#    ('L', 'OW1', 'G'),
#    ('L', 'OW1', 'IY0'),
#    ('L', 'OW1', 'M'),
#    ('L', 'OW1', 'N'),
#    ('L', 'OW1', 'P'),
#    ('L', 'OW1', 'S'),
#    ('L', 'OW1', 'SH'),
#    ('L', 'OW1', 'TH'),
#    ('L', 'OW1', 'Z')]],
#  ('L',
#   'UW0',
#   'AO1',
#   'NG'): [[('F', 'UW0', 'AO1', 'NG'), ('V', 'UW0', 'AO1', 'NG')]],
#  ('IY0',
#   'V',
#   'EH1',
#   'N',
#   'T',
#   'F',
#   'AH0',
#   'L'): [[('IH0', 'V', 'EH1', 'N', 'T', 'F', 'AH0', 'L')]],
#  ('IH0',
#   'N',
#   'K',
#   'W',
#   'AY1',
#   'R',
#   'ER0'): [[('IH2', 'N', 'K', 'W', 'AY1', 'R', 'ER0'),
#    ('IH0', 'N', 'K', 'W', 'AY1', 'R', 'IY2')]],
#  ('K',
#   'R',
#   'IH1',
#   'K',
#   'IH0',
#   'T'): [[('P', 'R', 'IH1', 'K', 'IH0', 'T'),
#    ('T', 'R', 'IH1', 'K', 'IH0', 'T'),
#    ('K', 'R', 'AA1', 'K', 'IH0', 'T'),
#    ('K', 'R', 'IH1', 'K', 'AH0', 'T')]],
#  ('B',
#   'IH1',
#   'L',
#   'G',
#   'ER0'): [[('D', 'IH1', 'L', 'G', 'ER0'),
#    ('G', 'IH1', 'L', 'G', 'ER0'),
#    ('HH', 'IH1', 'L', 'G', 'ER0'),
#    ('K', 'IH1', 'L', 'G', 'ER0'),
#    ('P', 'IH1', 'L', 'G', 'ER0'),
#    ('B', 'AH1', 'L', 'G', 'ER0'),
#    ('B', 'EH1', 'L', 'G', 'ER0'),
#    ('B', 'IH1', 'L', 'D', 'ER0')]],
#  ('K',
#   'L',
#   'AE1',
#   'S',
#   'AH0',
#   'N'): [[('G', 'L', 'AE1', 'S', 'AH0', 'N'),
#    ('K', 'L', 'AA1', 'S', 'AH0', 'N'),
#    ('K', 'L', 'AO1', 'S', 'AH0', 'N'),
#    ('K', 'L', 'AW1', 'S', 'AH0', 'N'),
#    ('K', 'L', 'EY1', 'S', 'AH0', 'N'),
#    ('K', 'L', 'AE1', 'R', 'AH0', 'N'),
#    ('K', 'L', 'AE1', 'S', 'AH0', 'Z')]],
#  ('K',
#   'AE1',
#   'SH',
#   'M',
#   'IH0',
#   'R'): [[('K', 'AE1', 'ZH', 'M', 'IH0', 'R'),
#    ('K', 'AE1', 'SH', 'M', 'AO0', 'R'),
#    ('K', 'AE1', 'SH', 'M', 'IY0', 'R')]],
#  ('HH',
#   'AE1',
#   'N',
#   'D',
#   'AH0',
#   'D'): [[('K', 'AE1', 'N', 'D', 'AH0', 'D'),
#    ('L', 'AE1', 'N', 'D', 'AH0', 'D'),
#    ('HH', 'AE1', 'N', 'D', 'IH0', 'D'),
#    ('HH', 'AE1', 'N', 'D', 'AH0', 'L')]],
#  ('B',
#   'R',
#   'EY1',
#   'D',
#   'IH0',
#   'NG'): [[('G', 'R', 'EY1', 'D', 'IH0', 'NG'),
#    ('T', 'R', 'EY1', 'D', 'IH0', 'NG'),
#    ('B', 'L', 'EY1', 'D', 'IH0', 'NG'),
#    ('B', 'R', 'EH1', 'D', 'IH0', 'NG'),
#    ('B', 'R', 'IY1', 'D', 'IH0', 'NG'),
#    ('B', 'R', 'UW1', 'D', 'IH0', 'NG'),
#    ('B', 'R', 'EY1', 'K', 'IH0', 'NG'),
#    ('B', 'R', 'EY1', 'S', 'IH0', 'NG'),
#    ('B', 'R', 'EY1', 'V', 'IH0', 'NG'),
#    ('B', 'R', 'EY1', 'D', 'IH0', 'D')]],
#  ('HH',
#   'AH0',
#   'L',
#   'EY1',
#   'V',
#   'IY0'): [[('HH', 'AH0', 'L', 'IY1', 'V', 'IY0')]],
#  ('D',
#   'IH0',
#   'L',
#   'UW1',
#   'K',
#   'AH0'): [[('D', 'EH0', 'L', 'UW1', 'K', 'AH0')]],
#  ('S',
#   'EH1',
#   'L',
#   'D',
#   'AH0'): [[('F', 'EH1', 'L', 'D', 'AH0'),
#    ('K', 'EH1', 'L', 'D', 'AH0'),
#    ('N', 'EH1', 'L', 'D', 'AH0'),
#    ('V', 'EH1', 'L', 'D', 'AH0'),
#    ('Z', 'EH1', 'L', 'D', 'AH0'),
#    ('S', 'EH1', 'R', 'D', 'AH0'),
#    ('S', 'EH1', 'L', 'IY0', 'AH0'),
#    ('S', 'EH1', 'L', 'M', 'AH0'),
#    ('S', 'EH1', 'L', 'V', 'AH0')]],
#  ('S',
#   'T',
#   'AO1',
#   'R',
#   'ER0'): [[('S', 'K', 'AO1', 'R', 'ER0'),
#    ('S', 'N', 'AO1', 'R', 'ER0'),
#    ('S', 'P', 'AO1', 'R', 'ER0'),
#    ('S', 'T', 'EH1', 'R', 'ER0'),
#    ('S', 'T', 'AO1', 'F', 'ER0'),
#    ('S', 'T', 'AO1', 'K', 'ER0'),
#    ('S', 'T', 'AO1', 'L', 'ER0'),
#    ('S', 'T', 'AO1', 'R', 'AH0'),
#    ('S', 'T', 'AO1', 'R', 'D'),
#    ('S', 'T', 'AO1', 'R', 'IY0'),
#    ('S', 'T', 'AO1', 'R', 'K'),
#    ('S', 'T', 'AO1', 'R', 'M'),
#    ('S', 'T', 'AO1', 'R', 'T'),
#    ('S', 'T', 'AO1', 'R', 'Z')]],
#  ('K',
#   'AA1',
#   'P',
#   'S'): [[('CH', 'AA1', 'P', 'S'),
#    ('HH', 'AA1', 'P', 'S'),
#    ('M', 'AA1', 'P', 'S'),
#    ('P', 'AA1', 'P', 'S'),
#    ('R', 'AA1', 'P', 'S'),
#    ('S', 'AA1', 'P', 'S'),
#    ('SH', 'AA1', 'P', 'S'),
#    ('T', 'AA1', 'P', 'S'),
#    ('W', 'AA1', 'P', 'S'),
#    ('K', 'AE1', 'P', 'S'),
#    ('K', 'AH1', 'P', 'S'),
#    ('K', 'EY1', 'P', 'S'),
#    ('K', 'IH1', 'P', 'S'),
#    ('K', 'IY1', 'P', 'S'),
#    ('K', 'OW1', 'P', 'S'),
#    ('K', 'UW1', 'P', 'S'),
#    ('K', 'AA1', 'K', 'S'),
#    ('K', 'AA1', 'R', 'S'),
#    ('K', 'AA1', 'T', 'S'),
#    ('K', 'AA1', 'P', 'ER0'),
#    ('K', 'AA1', 'P', 'IY0'),
#    ('K', 'AA1', 'P', 'IY1'),
#    ('K', 'AA1', 'P', 'OW0'),
#    ('K', 'AA1', 'P', 'T')]],
#  ('K',
#   'AH0',
#   'N',
#   'T',
#   'R',
#   'OW1',
#   'L',
#   'ER0',
#   'Z'): [[('K', 'AH0', 'M', 'T', 'R', 'OW1', 'L', 'ER0', 'Z'),
#    ('K', 'AH0', 'N', 'T', 'R', 'AA1', 'L', 'ER0', 'Z')]],
#  ('M',
#   'AA1',
#   'R',
#   'S',
#   'T',
#   'AH0',
#   'N'): [[('G', 'AA1', 'R', 'S', 'T', 'AH0', 'N'),
#    ('HH', 'AA1', 'R', 'S', 'T', 'AH0', 'N'),
#    ('K', 'AA1', 'R', 'S', 'T', 'AH0', 'N'),
#    ('M', 'AA1', 'R', 'L', 'T', 'AH0', 'N'),
#    ('M', 'AA1', 'R', 'S', 'D', 'AH0', 'N')]],
#  ('S',
#   'AH0',
#   'F',
#   'Y',
#   'UW1',
#   'Z',
#   'IH0',
#   'NG'): [[('R', 'AH0', 'F', 'Y', 'UW1', 'Z', 'IH0', 'NG'),
#    ('S', 'AH0', 'F', 'Y', 'UW1', 'Z', 'IH0', 'Z')]],
#  ('F',
#   'IH1',
#   'L',
#   'CH'): [[('M', 'IH1', 'L', 'CH'),
#    ('P', 'IH1', 'L', 'CH'),
#    ('Z', 'IH1', 'L', 'CH'),
#    ('F', 'EH1', 'L', 'CH'),
#    ('F', 'IH1', 'N', 'CH'),
#    ('F', 'IH1', 'L', 'AH0'),
#    ('F', 'IH1', 'L', 'D'),
#    ('F', 'IH1', 'L', 'ER0'),
#    ('F', 'IH1', 'L', 'IY0'),
#    ('F', 'IH1', 'L', 'M'),
#    ('F', 'IH1', 'L', 'P'),
#    ('F', 'IH1', 'L', 'TH'),
#    ('F', 'IH1', 'L', 'Z')]],
#  ('R',
#   'IH1',
#   'D',
#   'IH0',
#   'K'): [[('L', 'IH1', 'D', 'IH0', 'K'),
#    ('W', 'IH1', 'D', 'IH0', 'K'),
#    ('Z', 'IH1', 'D', 'IH0', 'K'),
#    ('R', 'AA1', 'D', 'IH0', 'K'),
#    ('R', 'AE1', 'D', 'IH0', 'K'),
#    ('R', 'AH1', 'D', 'IH0', 'K'),
#    ('R', 'EH1', 'D', 'IH0', 'K'),
#    ('R', 'UW1', 'D', 'IH0', 'K'),
#    ('R', 'IH1', 'R', 'IH0', 'K'),
#    ('R', 'IH1', 'D', 'AH0', 'K'),
#    ('R', 'IH1', 'D', 'IH0', 'NG')]],
#  ('B',
#   'UW1',
#   'S',
#   'T',
#   'S'): [[('B', 'AH1', 'S', 'T', 'S'),
#    ('B', 'EH1', 'S', 'T', 'S'),
#    ('B', 'ER1', 'S', 'T', 'S'),
#    ('B', 'IY1', 'S', 'T', 'S'),
#    ('B', 'OW1', 'S', 'T', 'S'),
#    ('B', 'UW1', 'S', 'T', 'ER0')]],
#  ('L',
#   'AE1',
#   'M',
#   'B',
#   'R',
#   'OW0'): [[('F', 'AE1', 'M', 'B', 'R', 'OW0'),
#    ('G', 'AE1', 'M', 'B', 'R', 'OW0'),
#    ('HH', 'AE1', 'M', 'B', 'R', 'OW0'),
#    ('L', 'AE1', 'M', 'UH0', 'R', 'OW0')]],
#  ('G',
#   'R',
#   'OW1',
#   'S',
#   'L',
#   'IY0'): [[('G', 'R', 'AE1', 'S', 'L', 'IY0'),
#    ('G', 'R', 'EH1', 'S', 'L', 'IY0'),
#    ('G', 'R', 'OW1', 'S', 'ER0', 'IY0'),
#    ('G', 'R', 'OW1', 'S', 'R', 'IY0')]],
#  ('HH',
#   'EH1',
#   'L',
#   'D',
#   'IH0',
#   'N',
#   'B',
#   'R',
#   'AH0',
#   'N',
#   'D'): [[('HH', 'IH1', 'L', 'D', 'IH0', 'N', 'B', 'R', 'AH0', 'N', 'D'),
#    ('HH', 'EH1', 'L', 'D', 'IH0', 'N', 'B', 'R', 'AE0', 'N', 'D')]],
#  ('T',
#   'AE1',
#   'K',
#   'ER0'): [[('B', 'AE1', 'K', 'ER0'),
#    ('HH', 'AE1', 'K', 'ER0'),
#    ('L', 'AE1', 'K', 'ER0'),
#    ('M', 'AE1', 'K', 'ER0'),
#    ('P', 'AE1', 'K', 'ER0'),
#    ('R', 'AE1', 'K', 'ER0'),
#    ('S', 'AE1', 'K', 'ER0'),
#    ('SH', 'AE1', 'K', 'ER0'),
#    ('TH', 'AE1', 'K', 'ER0'),
#    ('W', 'AE1', 'K', 'ER0'),
#    ('Z', 'AE1', 'K', 'ER0'),
#    ('T', 'AH1', 'K', 'ER0'),
#    ('T', 'AO1', 'K', 'ER0'),
#    ('T', 'AW1', 'K', 'ER0'),
#    ('T', 'AY1', 'K', 'ER0'),
#    ('T', 'EY1', 'K', 'ER0'),
#    ('T', 'IH1', 'K', 'ER0'),
#    ('T', 'UH1', 'K', 'ER0'),
#    ('T', 'AE1', 'N', 'ER0'),
#    ('T', 'AE1', 'NG', 'ER0'),
#    ('T', 'AE1', 'P', 'ER0'),
#    ('T', 'AE1', 'T', 'ER0'),
#    ('T', 'AE1', 'K', 'IY0'),
#    ('T', 'AE1', 'K', 'IY2'),
#    ('T', 'AE1', 'K', 'S'),
#    ('T', 'AE1', 'K', 'T')]],
#  ('B',
#   'IY1',
#   'P'): [[('CH', 'IY1', 'P'),
#    ('D', 'IY1', 'P'),
#    ('HH', 'IY1', 'P'),
#    ('JH', 'IY1', 'P'),
#    ('K', 'IY1', 'P'),
#    ('L', 'IY1', 'P'),
#    ('N', 'IY1', 'P'),
#    ('P', 'IY1', 'P'),
#    ('R', 'IY1', 'P'),
#    ('S', 'IY1', 'P'),
#    ('SH', 'IY1', 'P'),
#    ('T', 'IY1', 'P'),
#    ('V', 'IY1', 'P'),
#    ('W', 'IY1', 'P'),
#    ('B', 'AA1', 'P'),
#    ('B', 'AH1', 'P'),
#    ('B', 'ER1', 'P'),
#    ('B', 'IH1', 'P'),
#    ('B', 'UW1', 'P'),
#    ('B', 'IY1', 'CH'),
#    ('B', 'IY1', 'D'),
#    ('B', 'IY1', 'F'),
#    ('B', 'IY1', 'K'),
#    ('B', 'IY1', 'L'),
#    ('B', 'IY1', 'M'),
#    ('B', 'IY1', 'N'),
#    ('B', 'IY1', 'R'),
#    ('B', 'IY1', 'T'),
#    ('B', 'IY1', 'V'),
#    ('B', 'IY1', 'Z')]],
#  ('S',
#   'OW1',
#   'L',
#   'AH0',
#   'N'): [[('B', 'OW1', 'L', 'AH0', 'N'),
#    ('D', 'OW1', 'L', 'AH0', 'N'),
#    ('F', 'OW1', 'L', 'AH0', 'N'),
#    ('G', 'OW1', 'L', 'AH0', 'N'),
#    ('HH', 'OW1', 'L', 'AH0', 'N'),
#    ('K', 'OW1', 'L', 'AH0', 'N'),
#    ('M', 'OW1', 'L', 'AH0', 'N'),
#    ('N', 'OW1', 'L', 'AH0', 'N'),
#    ('P', 'OW1', 'L', 'AH0', 'N'),
#    ('R', 'OW1', 'L', 'AH0', 'N'),
#    ('T', 'OW1', 'L', 'AH0', 'N'),
#    ('S', 'AA1', 'L', 'AH0', 'N'),
#    ('S', 'AH1', 'L', 'AH0', 'N'),
#    ('S', 'EH1', 'L', 'AH0', 'N'),
#    ('S', 'OW1', 'D', 'AH0', 'N'),
#    ('S', 'OW1', 'L', 'IH0', 'N'),
#    ('S', 'OW1', 'L', 'AH0', 'K'),
#    ('S', 'OW1', 'L', 'AH0', 'M')]],
#  ('D',
#   'OW1',
#   'D',
#   'OW0',
#   'Z'): [[('D', 'OW1', 'B', 'OW0', 'Z'), ('D', 'OW1', 'D', 'IY0', 'Z')]],
#  ('S',
#   'L',
#   'AE1',
#   'DH',
#   'ER0'): [[('B', 'L', 'AE1', 'DH', 'ER0'),
#    ('S', 'M', 'AE1', 'DH', 'ER0'),
#    ('S', 'L', 'IH1', 'DH', 'ER0'),
#    ('S', 'L', 'AE1', 'K', 'ER0'),
#    ('S', 'L', 'AE1', 'M', 'ER0'),
#    ('S', 'L', 'AE1', 'SH', 'ER0'),
#    ('S', 'L', 'AE1', 'T', 'ER0')]],
#  ('S', 'UW1', 'HH', 'UW2'): [[('S', 'UW1', 'ZH', 'UW2')]],
#  ('HH',
#   'AH0',
#   'L',
#   'UW1',
#   'S',
#   'IH0',
#   'N',
#   'EY0',
#   'T',
#   'IH0',
#   'NG'): [[('HH',
#     'AH0',
#     'L',
#     'UW1',
#     'S',
#     'AH0',
#     'N',
#     'EY0',
#     'T',
#     'IH0',
#     'NG')]],
#  ('HH',
#   'AY1',
#   'K',
#   'AH0',
#   'N'): [[('G', 'AY1', 'K', 'AH0', 'N'),
#    ('L', 'AY1', 'K', 'AH0', 'N'),
#    ('HH', 'AA1', 'K', 'AH0', 'N'),
#    ('HH', 'AE1', 'K', 'AH0', 'N'),
#    ('HH', 'AO1', 'K', 'AH0', 'N'),
#    ('HH', 'AW1', 'K', 'AH0', 'N'),
#    ('HH', 'EY1', 'K', 'AH0', 'N'),
#    ('HH', 'IH1', 'K', 'AH0', 'N'),
#    ('HH', 'AY1', 'D', 'AH0', 'N'),
#    ('HH', 'AY1', 'F', 'AH0', 'N'),
#    ('HH', 'AY1', 'M', 'AH0', 'N'),
#    ('HH', 'AY1', 'N', 'AH0', 'N'),
#    ('HH', 'AY1', 'S', 'AH0', 'N'),
#    ('HH', 'AY1', 'T', 'AH0', 'N'),
#    ('HH', 'AY1', 'K', 'AH0', 'L'),
#    ('HH', 'AY1', 'K', 'AH0', 'Z')]],
#  ('M',
#   'IH1',
#   'K',
#   'S',
#   'T',
#   'ER0'): [[('M', 'AE1', 'K', 'S', 'T', 'ER0'),
#    ('M', 'IH1', 'N', 'S', 'T', 'ER0'),
#    ('M', 'IH1', 'K', 'S', 'CH', 'ER0'),
#    ('M', 'IH1', 'K', 'S', 'N', 'ER0')]],
#  ('T',
#   'EH1',
#   'R',
#   'AH0',
#   'S'): [[('D', 'EH1', 'R', 'AH0', 'S'),
#    ('F', 'EH1', 'R', 'AH0', 'S'),
#    ('M', 'EH1', 'R', 'AH0', 'S'),
#    ('P', 'EH1', 'R', 'AH0', 'S'),
#    ('S', 'EH1', 'R', 'AH0', 'S'),
#    ('T', 'AO1', 'R', 'AH0', 'S'),
#    ('T', 'EH1', 'N', 'AH0', 'S'),
#    ('T', 'EH1', 'R', 'IH0', 'S'),
#    ('T', 'EH1', 'R', 'AH0', 'F'),
#    ('T', 'EH1', 'R', 'AH0', 'L'),
#    ('T', 'EH1', 'R', 'AH0', 'M'),
#    ('T', 'EH1', 'R', 'AH0', 'N'),
#    ('T', 'EH1', 'R', 'AH0', 'Z')]],
#  ('T',
#   'EH1',
#   'M',
#   'P',
#   'T',
#   'IH0',
#   'D'): [[('T', 'EH1', 'M', 'P', 'T', 'IH0', 'NG')]],
#  ('SH',
#   'AE1',
#   'N',
#   'D',
#   'Z'): [[('B', 'AE1', 'N', 'D', 'Z'),
#    ('HH', 'AE1', 'N', 'D', 'Z'),
#    ('L', 'AE1', 'N', 'D', 'Z'),
#    ('R', 'AE1', 'N', 'D', 'Z'),
#    ('S', 'AE1', 'N', 'D', 'Z'),
#    ('SH', 'AE1', 'N', 'D', 'IY0')]],
#  ('D', 'AH1', 'F', 'AO0', 'R'): [[('D', 'IY1', 'F', 'AO0', 'R')]],
#  ('SH',
#   'AA1',
#   'K',
#   'IH0',
#   'NG'): [[('D', 'AA1', 'K', 'IH0', 'NG'),
#    ('HH', 'AA1', 'K', 'IH0', 'NG'),
#    ('K', 'AA1', 'K', 'IH0', 'NG'),
#    ('L', 'AA1', 'K', 'IH0', 'NG'),
#    ('M', 'AA1', 'K', 'IH0', 'NG'),
#    ('N', 'AA1', 'K', 'IH0', 'NG'),
#    ('R', 'AA1', 'K', 'IH0', 'NG'),
#    ('S', 'AA1', 'K', 'IH0', 'NG'),
#    ('SH', 'AH1', 'K', 'IH0', 'NG'),
#    ('SH', 'ER1', 'K', 'IH0', 'NG'),
#    ('SH', 'EY1', 'K', 'IH0', 'NG'),
#    ('SH', 'AA1', 'P', 'IH0', 'NG')]],
#  ('B',
#   'AE1',
#   'N',
#   'IH0',
#   'SH'): [[('HH', 'AE1', 'N', 'IH0', 'SH'),
#    ('JH', 'AE1', 'N', 'IH0', 'SH'),
#    ('M', 'AE1', 'N', 'IH0', 'SH'),
#    ('V', 'AE1', 'N', 'IH0', 'SH'),
#    ('Y', 'AE1', 'N', 'IH0', 'SH'),
#    ('B', 'EH1', 'N', 'IH0', 'SH'),
#    ('B', 'ER1', 'N', 'IH0', 'SH'),
#    ('B', 'AE1', 'B', 'IH0', 'SH'),
#    ('B', 'AE1', 'NG', 'IH0', 'SH'),
#    ('B', 'AE1', 'R', 'IH0', 'SH'),
#    ('B', 'AE1', 'N', 'IH0', 'K'),
#    ('B', 'AE1', 'N', 'IH0', 'NG'),
#    ('B', 'AE1', 'N', 'IH0', 'S'),
#    ('B', 'AE1', 'N', 'IH0', 'T')]],
#  ('L',
#   'IH1',
#   'F',
#   'T'): [[('G', 'IH1', 'F', 'T'),
#    ('M', 'IH1', 'F', 'T'),
#    ('R', 'IH1', 'F', 'T'),
#    ('S', 'IH1', 'F', 'T'),
#    ('SH', 'IH1', 'F', 'T'),
#    ('T', 'IH1', 'F', 'T'),
#    ('L', 'AE1', 'F', 'T'),
#    ('L', 'AH1', 'F', 'T'),
#    ('L', 'AO1', 'F', 'T'),
#    ('L', 'EH1', 'F', 'T'),
#    ('L', 'IY1', 'F', 'T'),
#    ('L', 'IH1', 'CH', 'T'),
#    ('L', 'IH1', 'K', 'T'),
#    ('L', 'IH1', 'L', 'T'),
#    ('L', 'IH1', 'N', 'T'),
#    ('L', 'IH1', 'P', 'T'),
#    ('L', 'IH1', 'S', 'T'),
#    ('L', 'IH1', 'F', 'S')]],
#  ('N', 'UW1', 'L', 'AE2', 'N', 'D'): [[('N', 'UW1', 'L', 'AH0', 'N', 'D')]],
#  ('B',
#   'EH1',
#   'TH',
#   'ER0',
#   'D'): [[('B', 'EH1', 'K', 'ER0', 'D'), ('B', 'EH1', 'T', 'ER0', 'D')]],
#  ('M',
#   'IH1',
#   'L',
#   'IY0',
#   'AH0',
#   'N'): [[('CH', 'IH1', 'L', 'IY0', 'AH0', 'N'),
#    ('JH', 'IH1', 'L', 'IY0', 'AH0', 'N'),
#    ('K', 'IH1', 'L', 'IY0', 'AH0', 'N'),
#    ('L', 'IH1', 'L', 'IY0', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'ER0', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'K', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'M', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'S', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'T', 'AH0', 'N'),
#    ('M', 'IH1', 'L', 'Y', 'AH0', 'N')]],
#  ('CH',
#   'EH1',
#   'R',
#   'IH0',
#   'T',
#   'IY0',
#   'Z'): [[('R', 'EH1', 'R', 'IH0', 'T', 'IY0', 'Z'),
#    ('V', 'EH1', 'R', 'IH0', 'T', 'IY0', 'Z'),
#    ('CH', 'EH1', 'R', 'AH0', 'T', 'IY0', 'Z')]],
#  ('V',
#   'IH1',
#   'R',
#   'D'): [[('B', 'IH1', 'R', 'D'),
#    ('CH', 'IH1', 'R', 'D'),
#    ('F', 'IH1', 'R', 'D'),
#    ('G', 'IH1', 'R', 'D'),
#    ('JH', 'IH1', 'R', 'D'),
#    ('N', 'IH1', 'R', 'D'),
#    ('P', 'IH1', 'R', 'D'),
#    ('R', 'IH1', 'R', 'D'),
#    ('S', 'IH1', 'R', 'D'),
#    ('SH', 'IH1', 'R', 'D'),
#    ('W', 'IH1', 'R', 'D'),
#    ('V', 'IH1', 'R', 'AA0'),
#    ('V', 'IH1', 'R', 'Z')]],
#  ('M',
#   'OW1',
#   'SH',
#   'AH0',
#   'N'): [[('B', 'OW1', 'SH', 'AH0', 'N'),
#    ('HH', 'OW1', 'SH', 'AH0', 'N'),
#    ('K', 'OW1', 'SH', 'AH0', 'N'),
#    ('L', 'OW1', 'SH', 'AH0', 'N'),
#    ('N', 'OW1', 'SH', 'AH0', 'N'),
#    ('P', 'OW1', 'SH', 'AH0', 'N'),
#    ('M', 'AY1', 'SH', 'AH0', 'N'),
#    ('M', 'ER1', 'SH', 'AH0', 'N'),
#    ('M', 'EY1', 'SH', 'AH0', 'N'),
#    ('M', 'IH1', 'SH', 'AH0', 'N'),
#    ('M', 'OW1', 'D', 'AH0', 'N'),
#    ('M', 'OW1', 'G', 'AH0', 'N'),
#    ('M', 'OW1', 'HH', 'AH0', 'N'),
#    ('M', 'OW1', 'L', 'AH0', 'N'),
#    ('M', 'OW1', 'M', 'AH0', 'N'),
#    ('M', 'OW1', 'T', 'AH0', 'N'),
#    ('M', 'OW1', 'SH', 'AH0', 'S'),
#    ('M', 'OW1', 'SH', 'AH0', 'Z')]],
#  ('JH',
#   'AA1',
#   'B',
#   'Z'): [[('B', 'AA1', 'B', 'Z'),
#    ('D', 'AA1', 'B', 'Z'),
#    ('F', 'AA1', 'B', 'Z'),
#    ('G', 'AA1', 'B', 'Z'),
#    ('HH', 'AA1', 'B', 'Z'),
#    ('K', 'AA1', 'B', 'Z'),
#    ('L', 'AA1', 'B', 'Z'),
#    ('M', 'AA1', 'B', 'Z'),
#    ('N', 'AA1', 'B', 'Z'),
#    ('R', 'AA1', 'B', 'Z'),
#    ('S', 'AA1', 'B', 'Z'),
#    ('JH', 'AE1', 'B', 'Z'),
#    ('JH', 'AY1', 'B', 'Z'),
#    ('JH', 'OW1', 'B', 'Z'),
#    ('JH', 'AA1', 'G', 'Z'),
#    ('JH', 'AA1', 'N', 'Z'),
#    ('JH', 'AA1', 'R', 'Z'),
#    ('JH', 'AA1', 'B', 'ER0')]],
#  ('EH1',
#   'JH',
#   'Y',
#   'UW0',
#   'K',
#   'EY2',
#   'T',
#   'IH0',
#   'NG'): [[('EH1', 'JH', 'Y', 'UW0', 'K', 'EY2', 'T', 'IH0', 'D')]],
#  ('S',
#   'EH1',
#   'L',
#   'AH0',
#   'B',
#   'R',
#   'EY2',
#   'T',
#   'IH0',
#   'NG'): [[('S', 'EH1', 'L', 'AH0', 'B', 'R', 'EY2', 'T', 'IH0', 'D')]],
#  ('CH',
#   'IH1',
#   'P',
#   'T'): [[('D', 'IH1', 'P', 'T'),
#    ('JH', 'IH1', 'P', 'T'),
#    ('L', 'IH1', 'P', 'T'),
#    ('N', 'IH1', 'P', 'T'),
#    ('R', 'IH1', 'P', 'T'),
#    ('S', 'IH1', 'P', 'T'),
#    ('SH', 'IH1', 'P', 'T'),
#    ('T', 'IH1', 'P', 'T'),
#    ('W', 'IH1', 'P', 'T'),
#    ('Z', 'IH1', 'P', 'T'),
#    ('CH', 'AA1', 'P', 'T'),
#    ('CH', 'IH1', 'P', 'ER0'),
#    ('CH', 'IH1', 'P', 'IY0'),
#    ('CH', 'IH1', 'P', 'S')]],
#  ('G',
#   'AE1',
#   'L',
#   'B',
#   'R',
#   'EH2',
#   'TH'): [[('G', 'IH1', 'L', 'B', 'R', 'EH2', 'TH'),
#    ('G', 'AE1', 'L', 'B', 'R', 'EY2', 'TH')]],
#  ('P',
#   'R',
#   'IH0',
#   'K',
#   'L',
#   'UW1',
#   'D',
#   'IH0',
#   'D'): [[('P', 'R', 'IY0', 'K', 'L', 'UW1', 'D', 'IH0', 'D'),
#    ('P', 'R', 'IH0', 'K', 'L', 'UW1', 'D', 'IH0', 'NG')]],
#  ('K',
#   'AA2',
#   'D',
#   'AH0',
#   'F',
#   'AH0',
#   'K',
#   'EY1',
#   'SH',
#   'AH0',
#   'N'): [[('M', 'AA2', 'D', 'AH0', 'F', 'AH0', 'K', 'EY1', 'SH', 'AH0', 'N')]],
#  ('K',
#   'AA2',
#   'R',
#   'IY1',
#   'N',
#   'OW0'): [[('P', 'AA2', 'R', 'IY1', 'N', 'OW0'),
#    ('K', 'AA0', 'R', 'IY1', 'N', 'OW0'),
#    ('K', 'EH2', 'R', 'IY1', 'N', 'OW0'),
#    ('K', 'AA2', 'R', 'AA1', 'N', 'OW0')]],
#  ('OW1',
#   'N',
#   'ER0'): [[('AA1', 'N', 'ER0'),
#    ('AY1', 'N', 'ER0'),
#    ('EH1', 'N', 'ER0'),
#    ('ER1', 'N', 'ER0'),
#    ('EY1', 'N', 'ER0'),
#    ('IH1', 'N', 'ER0'),
#    ('OW1', 'B', 'ER0'),
#    ('OW1', 'D', 'ER0'),
#    ('OW1', 'F', 'ER0'),
#    ('OW1', 'G', 'ER0'),
#    ('OW1', 'K', 'ER0'),
#    ('OW1', 'L', 'ER0'),
#    ('OW1', 'M', 'ER0'),
#    ('OW1', 'S', 'ER0'),
#    ('OW1', 'V', 'ER0'),
#    ('OW1', 'Z', 'ER0'),
#    ('OW1', 'N', 'AH0'),
#    ('OW1', 'N', 'D'),
#    ('OW1', 'N', 'IY0'),
#    ('OW1', 'N', 'OW0'),
#    ('OW1', 'N', 'Z')]],
#  ('P',
#   'AA1',
#   'R',
#   'S',
#   'AH0',
#   'L'): [[('M', 'AA1', 'R', 'S', 'AH0', 'L'),
#    ('P', 'IH1', 'R', 'S', 'AH0', 'L'),
#    ('P', 'AA1', 'R', 'N', 'AH0', 'L'),
#    ('P', 'AA1', 'R', 'SH', 'AH0', 'L'),
#    ('P', 'AA1', 'R', 'S', 'AH0', 'N')]],
#  ('S',
#   'T',
#   'AE1',
#   'N',
#   'L',
#   'IY0'): [[('S', 'T', 'ER1', 'N', 'L', 'IY0'),
#    ('S', 'T', 'AE1', 'B', 'L', 'IY0'),
#    ('S', 'T', 'AE1', 'P', 'L', 'IY0'),
#    ('S', 'T', 'AE1', 'N', 'L', 'AH0')]],
#  ('Y',
#   'AH1',
#   'N',
#   'Z'): [[('B', 'AH1', 'N', 'Z'),
#    ('CH', 'AH1', 'N', 'Z'),
#    ('D', 'AH1', 'N', 'Z'),
#    ('F', 'AH1', 'N', 'Z'),
#    ('G', 'AH1', 'N', 'Z'),
#    ('K', 'AH1', 'N', 'Z'),
#    ('L', 'AH1', 'N', 'Z'),
#    ('M', 'AH1', 'N', 'Z'),
#    ('N', 'AH1', 'N', 'Z'),
#    ('P', 'AH1', 'N', 'Z'),
#    ('R', 'AH1', 'N', 'Z'),
#    ('S', 'AH1', 'N', 'Z'),
#    ('SH', 'AH1', 'N', 'Z'),
#    ('T', 'AH1', 'N', 'Z'),
#    ('W', 'AH1', 'N', 'Z'),
#    ('Y', 'AO1', 'N', 'Z'),
#    ('Y', 'EH1', 'N', 'Z'),
#    ('Y', 'ER1', 'N', 'Z'),
#    ('Y', 'EY1', 'N', 'Z'),
#    ('Y', 'AH1', 'NG', 'Z'),
#    ('Y', 'AH1', 'N', 'JH')]],
#  ('B',
#   'UW1',
#   'Z',
#   'ER0'): [[('HH', 'UW1', 'Z', 'ER0'),
#    ('K', 'UW1', 'Z', 'ER0'),
#    ('L', 'UW1', 'Z', 'ER0'),
#    ('P', 'UW1', 'Z', 'ER0'),
#    ('Y', 'UW1', 'Z', 'ER0'),
#    ('B', 'AH1', 'Z', 'ER0'),
#    ('B', 'AY1', 'Z', 'ER0'),
#    ('B', 'IY1', 'Z', 'ER0'),
#    ('B', 'OW1', 'Z', 'ER0'),
#    ('B', 'UW1', 'B', 'ER0'),
#    ('B', 'UW1', 'L', 'ER0'),
#    ('B', 'UW1', 'M', 'ER0'),
#    ('B', 'UW1', 'SH', 'ER0'),
#    ('B', 'UW1', 'Z', 'AH0'),
#    ('B', 'UW1', 'Z', 'IY0')]],
#  ('AE1',
#   'D',
#   'AH0',
#   'T',
#   'IH0',
#   'V'): [[('AE1', 'D', 'IH0', 'T', 'IH0', 'V')]],
#  ('JH',
#   'ER0',
#   'EY1'): [[('D', 'ER0', 'EY1'), ('M', 'ER0', 'EY1'), ('JH', 'IY1', 'EY1')]],
#  ('D',
#   'IH0',
#   'S',
#   'IH1',
#   'ZH',
#   'AH0',
#   'N',
#   'Z'): [[('R', 'IH0', 'S', 'IH1', 'ZH', 'AH0', 'N', 'Z'),
#    ('D', 'IH0', 'V', 'IH1', 'ZH', 'AH0', 'N', 'Z')]],
#  ('S',
#   'IH1',
#   'N',
#   'T',
#   'EH2',
#   'K'): [[('M', 'IH1', 'N', 'T', 'EH2', 'K'),
#    ('S', 'IH1', 'L', 'T', 'EH2', 'K')]],
#  ('K',
#   'AE1',
#   'T',
#   'AH0',
#   'L',
#   'AO0',
#   'G',
#   'Z'): [[('K', 'AE1', 'T', 'AH0', 'L', 'AA0', 'G', 'Z'),
#    ('K', 'AE1', 'T', 'AH0', 'L', 'AO2', 'G', 'Z'),
#    ('K', 'AE1', 'T', 'AH0', 'L', 'AO0', 'G', 'D')]],
#  ('R',
#   'IH1',
#   'F',
#   'S'): [[('F', 'IH1', 'F', 'S'),
#    ('G', 'IH1', 'F', 'S'),
#    ('L', 'IH1', 'F', 'S'),
#    ('Z', 'IH1', 'F', 'S'),
#    ('R', 'AH1', 'F', 'S'),
#    ('R', 'IY1', 'F', 'S'),
#    ('R', 'UW1', 'F', 'S'),
#    ('R', 'IH1', 'K', 'S'),
#    ('R', 'IH1', 'N', 'S'),
#    ('R', 'IH1', 'P', 'S'),
#    ('R', 'IH1', 'T', 'S'),
#    ('R', 'IH1', 'F', 'IY0'),
#    ('R', 'IH1', 'F', 'T')]],
#  ('P',
#   'Y',
#   'UW1',
#   'D',
#   'ER0'): [[('B', 'Y', 'UW1', 'D', 'ER0'),
#    ('K', 'Y', 'UW1', 'D', 'ER0'),
#    ('T', 'Y', 'UW1', 'D', 'ER0'),
#    ('P', 'Y', 'UW1', 'T', 'ER0')]],
#  ('K',
#   'EY1',
#   'N',
#   'ER0'): [[('D', 'EY1', 'N', 'ER0'),
#    ('F', 'EY1', 'N', 'ER0'),
#    ('G', 'EY1', 'N', 'ER0'),
#    ('HH', 'EY1', 'N', 'ER0'),
#    ('M', 'EY1', 'N', 'ER0'),
#    ('R', 'EY1', 'N', 'ER0'),
#    ('S', 'EY1', 'N', 'ER0'),
#    ('SH', 'EY1', 'N', 'ER0'),
#    ('T', 'EY1', 'N', 'ER0'),
#    ('W', 'EY1', 'N', 'ER0'),
#    ('K', 'AA1', 'N', 'ER0'),
#    ('K', 'AE1', 'N', 'ER0'),
#    ('K', 'AY1', 'N', 'ER0'),
#    ('K', 'EH1', 'N', 'ER0'),
#    ('K', 'ER1', 'N', 'ER0'),
#    ('K', 'IH1', 'N', 'ER0'),
#    ('K', 'IY1', 'N', 'ER0'),
#    ('K', 'OW1', 'N', 'ER0'),
#    ('K', 'OY1', 'N', 'ER0'),
#    ('K', 'UH1', 'N', 'ER0'),
#    ('K', 'UW1', 'N', 'ER0'),
#    ('K', 'EY1', 'D', 'ER0'),
#    ('K', 'EY1', 'F', 'ER0'),
#    ('K', 'EY1', 'L', 'ER0'),
#    ('K', 'EY1', 'M', 'ER0'),
#    ('K', 'EY1', 'P', 'ER0'),
#    ('K', 'EY1', 'S', 'ER0'),
#    ('K', 'EY1', 'T', 'ER0'),
#    ('K', 'EY1', 'V', 'ER0'),
#    ('K', 'EY1', 'Z', 'ER0'),
#    ('K', 'EY1', 'N', 'D'),
#    ('K', 'EY1', 'N', 'IY0'),
#    ('K', 'EY1', 'N', 'Z')]],
#  ('S',
#   'IH1',
#   'M',
#   'P',
#   'AH0',
#   'L'): [[('D', 'IH1', 'M', 'P', 'AH0', 'L'),
#    ('G', 'IH1', 'M', 'P', 'AH0', 'L'),
#    ('K', 'IH1', 'M', 'P', 'AH0', 'L'),
#    ('P', 'IH1', 'M', 'P', 'AH0', 'L'),
#    ('S', 'AE1', 'M', 'P', 'AH0', 'L'),
#    ('S', 'EH1', 'M', 'P', 'AH0', 'L'),
#    ('S', 'IH1', 'M', 'B', 'AH0', 'L')]],
#  ('G',
#   'ER1',
#   'D',
#   'AH0'): [[('G', 'AA1', 'D', 'AH0'),
#    ('G', 'AY1', 'D', 'AH0'),
#    ('G', 'EY1', 'D', 'AH0'),
#    ('G', 'IY1', 'D', 'AH0'),
#    ('G', 'OW1', 'D', 'AH0'),
#    ('G', 'UH1', 'D', 'AH0'),
#    ('G', 'UW1', 'D', 'AH0'),
#    ('G', 'ER1', 'IY0', 'AH0'),
#    ('G', 'ER1', 'K', 'AH0'),
#    ('G', 'ER1', 'D', 'ER0'),
#    ('G', 'ER1', 'D', 'Z')]],
#  ('S', 'AW1', 'N', 'D', 'L', 'IY0'): [[('R', 'AW1', 'N', 'D', 'L', 'IY0')]],
#  ('N',
#   'AY1',
#   'R',
#   'Z'): [[('B', 'AY1', 'R', 'Z'),
#    ('F', 'AY1', 'R', 'Z'),
#    ('HH', 'AY1', 'R', 'Z'),
#    ('M', 'AY1', 'R', 'Z'),
#    ('P', 'AY1', 'R', 'Z'),
#    ('S', 'AY1', 'R', 'Z'),
#    ('SH', 'AY1', 'R', 'Z'),
#    ('V', 'AY1', 'R', 'Z'),
#    ('W', 'AY1', 'R', 'Z'),
#    ('N', 'AA1', 'R', 'Z'),
#    ('N', 'AE1', 'R', 'Z'),
#    ('N', 'IH1', 'R', 'Z'),
#    ('N', 'OY1', 'R', 'Z'),
#    ('N', 'AY1', 'L', 'Z'),
#    ('N', 'AY1', 'N', 'Z'),
#    ('N', 'AY1', 'V', 'Z')]],
#  ('W',
#   'ER1',
#   'Z',
#   'AH0',
#   'L'): [[('HH', 'ER1', 'Z', 'AH0', 'L'),
#    ('W', 'AY1', 'Z', 'AH0', 'L'),
#    ('W', 'IY1', 'Z', 'AH0', 'L'),
#    ('W', 'ER1', 'D', 'AH0', 'L'),
#    ('W', 'ER1', 'R', 'AH0', 'L')]],
#  ('JH',
#   'UH1',
#   'R',
#   'IH0',
#   'S',
#   'T'): [[('SH', 'UH1', 'R', 'IH0', 'S', 'T'),
#    ('T', 'UH1', 'R', 'IH0', 'S', 'T'),
#    ('JH', 'UH1', 'R', 'AH0', 'S', 'T')]],
#  ('R', 'AY1', 'IH0', 'TH'): [[('V', 'AY1', 'IH0', 'TH')]],
#  ('S',
#   'W',
#   'AA1',
#   'P',
#   'IH0',
#   'NG'): [[('HH', 'W', 'AA1', 'P', 'IH0', 'NG'),
#    ('S', 'T', 'AA1', 'P', 'IH0', 'NG'),
#    ('S', 'W', 'AY1', 'P', 'IH0', 'NG'),
#    ('S', 'W', 'IY1', 'P', 'IH0', 'NG'),
#    ('S', 'W', 'UW1', 'P', 'IH0', 'NG'),
#    ('S', 'W', 'AA1', 'CH', 'IH0', 'NG')]],
#  ('P',
#   'R',
#   'EH1',
#   'S',
#   'ER0',
#   'Z'): [[('B', 'R', 'EH1', 'S', 'ER0', 'Z'),
#    ('D', 'R', 'EH1', 'S', 'ER0', 'Z'),
#    ('P', 'R', 'EH1', 'SH', 'ER0', 'Z'),
#    ('P', 'R', 'EH1', 'S', 'AH0', 'Z'),
#    ('P', 'R', 'EH1', 'S', 'IH0', 'Z')]],
#  ('S',
#   'K',
#   'AE1',
#   'N',
#   'D'): [[('S', 'P', 'AE1', 'N', 'D'),
#    ('S', 'T', 'AE1', 'N', 'D'),
#    ('S', 'K', 'IH1', 'N', 'D'),
#    ('S', 'K', 'AE1', 'M', 'D'),
#    ('S', 'K', 'AE1', 'N', 'ER0'),
#    ('S', 'K', 'AE1', 'N', 'T'),
#    ('S', 'K', 'AE1', 'N', 'Z')]],
#  ('CH',
#   'EH0',
#   'L',
#   'AA1',
#   'N',
#   'OW0'): [[('CH', 'EH0', 'L', 'AA1', 'N', 'IY0')]],
#  ('N',
#   'EY0',
#   'V',
#   'EH1',
#   'L'): [[('N', 'OW0', 'V', 'EH1', 'L'),
#    ('N', 'UW2', 'V', 'EH1', 'L'),
#    ('N', 'EY0', 'V', 'AY1', 'L'),
#    ('N', 'EY0', 'V', 'IY1', 'L')]],
#  ('F', 'IH1', 'T', 'ER0', 'ER0'): [[('F', 'IH1', 'T', 'S', 'ER0')]],
#  ('F',
#   'R',
#   'AY1',
#   'T',
#   'N',
#   'IH0',
#   'NG'): [[('B', 'R', 'AY1', 'T', 'N', 'IH0', 'NG')]],
#  ('F',
#   'EH1',
#   'N',
#   'IH0',
#   'G'): [[('HH', 'EH1', 'N', 'IH0', 'G'),
#    ('L', 'EH1', 'N', 'IH0', 'G'),
#    ('W', 'EH1', 'N', 'IH0', 'G'),
#    ('F', 'EH1', 'T', 'IH0', 'G'),
#    ('F', 'EH1', 'N', 'IH0', 'K'),
#    ('F', 'EH1', 'N', 'IH0', 'NG')]],
#  ('T',
#   'R',
#   'AE0',
#   'N',
#   'Z',
#   'L',
#   'EY1',
#   'T',
#   'IH0',
#   'D'): [[('T', 'R', 'AE0', 'N', 'S', 'L', 'EY1', 'T', 'IH0', 'D'),
#    ('T', 'R', 'AE0', 'N', 'Z', 'L', 'EY1', 'T', 'IH0', 'NG')]],
#  ('B',
#   'AY1',
#   'R',
#   'AH0',
#   'L'): [[('T', 'AY1', 'R', 'AH0', 'L'),
#    ('V', 'AY1', 'R', 'AH0', 'L'),
#    ('B', 'AA1', 'R', 'AH0', 'L'),
#    ('B', 'AE1', 'R', 'AH0', 'L'),
#    ('B', 'AO1', 'R', 'AH0', 'L'),
#    ('B', 'EH1', 'R', 'AH0', 'L'),
#    ('B', 'AY1', 'B', 'AH0', 'L'),
#    ('B', 'AY1', 'ER0', 'AH0', 'L'),
#    ('B', 'AY1', 'G', 'AH0', 'L'),
#    ('B', 'AY1', 'S', 'AH0', 'L'),
#    ('B', 'AY1', 'T', 'AH0', 'L'),
#    ('B', 'AY1', 'R', 'AH0', 'M'),
#    ('B', 'AY1', 'R', 'AH0', 'N')]],
#  ('F',
#   'AY1',
#   'ER0',
#   'W',
#   'IY2',
#   'D'): [[('F', 'AY1', 'ER0', 'W', 'UH2', 'D')]],
#  ('F', 'AE1', 'N', 'Z', 'L', 'ER0'): [[('K', 'AE1', 'N', 'Z', 'L', 'ER0')]],
#  ('S',
#   'IH1',
#   'S',
#   'ER0',
#   'OW2',
#   'N'): [[('S', 'IH1', 'K', 'ER0', 'OW2', 'N')]],
#  ('R',
#   'IH0',
#   'G',
#   'EY1',
#   'L',
#   'IH0',
#   'NG'): [[('R', 'IH0', 'G', 'EY1', 'N', 'IH0', 'NG')]],
#  ('EH1',
#   'NG',
#   'G',
#   'ER0'): [[('AE1', 'NG', 'G', 'ER0'),
#    ('AH1', 'NG', 'G', 'ER0'),
#    ('IH1', 'NG', 'G', 'ER0'),
#    ('EH1', 'D', 'G', 'ER0'),
#    ('EH1', 'L', 'G', 'ER0')]],
#  ('HH',
#   'AE1',
#   'N',
#   'D',
#   'IY0',
#   'K',
#   'AE2',
#   'P',
#   'S'): [[('HH', 'AE1', 'N', 'D', 'IY0', 'K', 'AE2', 'P', 'ER0'),
#    ('HH', 'AE1', 'N', 'D', 'IY0', 'K', 'AE2', 'P', 'T')]],
#  ('M',
#   'AA1',
#   'R',
#   'T',
#   'S'): [[('B', 'AA1', 'R', 'T', 'S'),
#    ('CH', 'AA1', 'R', 'T', 'S'),
#    ('D', 'AA1', 'R', 'T', 'S'),
#    ('HH', 'AA1', 'R', 'T', 'S'),
#    ('K', 'AA1', 'R', 'T', 'S'),
#    ('P', 'AA1', 'R', 'T', 'S'),
#    ('SH', 'AA1', 'R', 'T', 'S'),
#    ('T', 'AA1', 'R', 'T', 'S'),
#    ('M', 'EH1', 'R', 'T', 'S'),
#    ('M', 'AA1', 'N', 'T', 'S'),
#    ('M', 'AA1', 'R', 'IH0', 'S'),
#    ('M', 'AA1', 'R', 'K', 'S'),
#    ('M', 'AA1', 'R', 'T', 'AH0'),
#    ('M', 'AA1', 'R', 'T', 'ER0'),
#    ('M', 'AA1', 'R', 'T', 'IY0')]],
#  ('R',
#   'IH0',
#   'S',
#   'P',
#   'AA1',
#   'N',
#   'D'): [[('R', 'IY0', 'S', 'P', 'AA1', 'N', 'D'),
#    ('R', 'IH0', 'S', 'P', 'AA1', 'N', 'S')]],
#  ('IH0',
#   'F',
#   'EH1',
#   'K',
#   'T',
#   'IH0',
#   'NG'): [[('AH0', 'F', 'EH1', 'K', 'T', 'IH0', 'NG'),
#    ('IH0', 'JH', 'EH1', 'K', 'T', 'IH0', 'NG'),
#    ('IH0', 'L', 'EH1', 'K', 'T', 'IH0', 'NG'),
#    ('IH0', 'R', 'EH1', 'K', 'T', 'IH0', 'NG'),
#    ('IH0', 'F', 'EH1', 'K', 'T', 'IH0', 'D'),
#    ('IH0', 'F', 'EH1', 'K', 'T', 'IH0', 'V')]],
#  ('R',
#   'AE1',
#   'NG',
#   'K',
#   'ER0'): [[('B', 'AE1', 'NG', 'K', 'ER0'),
#    ('D', 'AE1', 'NG', 'K', 'ER0'),
#    ('HH', 'AE1', 'NG', 'K', 'ER0'),
#    ('K', 'AE1', 'NG', 'K', 'ER0'),
#    ('M', 'AE1', 'NG', 'K', 'ER0'),
#    ('S', 'AE1', 'NG', 'K', 'ER0'),
#    ('SH', 'AE1', 'NG', 'K', 'ER0'),
#    ('T', 'AE1', 'NG', 'K', 'ER0'),
#    ('R', 'IH1', 'NG', 'K', 'ER0'),
#    ('R', 'AE1', 'NG', 'K', 'OW0'),
#    ('R', 'AE1', 'NG', 'K', 'S'),
#    ('R', 'AE1', 'NG', 'K', 'T')]],
#  ('F',
#   'Y',
#   'UW1',
#   'S',
#   'AH0',
#   'L',
#   'IH0',
#   'JH',
#   'IH0',
#   'Z'): [[('F', 'Y', 'UW1', 'S', 'AH0', 'L', 'AA0', 'JH', 'IH0', 'Z')]],
#  ('K', 'OW1', 'L', 'B', 'EH2', 'K'): [[('K', 'OW1', 'L', 'T', 'EH2', 'K')]],
#  ('N', 'UW1', 'JH', 'AH0', 'N', 'T'): [[('N', 'EH1', 'JH', 'AH0', 'N', 'T')]],
#  ('D', 'EH1', 'V', 'L', 'IH0', 'SH'): [[('D', 'EH1', 'V', 'L', 'IH0', 'N')]],
#  ('B',
#   'EY1',
#   'N',
#   'T',
#   'ER0'): [[('F', 'EY1', 'N', 'T', 'ER0'),
#    ('P', 'EY1', 'N', 'T', 'ER0'),
#    ('T', 'EY1', 'N', 'T', 'ER0'),
#    ('B', 'AE1', 'N', 'T', 'ER0'),
#    ('B', 'EH1', 'N', 'T', 'ER0')]],
#  ('G',
#   'IH1',
#   'L',
#   'IH0',
#   'T'): [[('B', 'IH1', 'L', 'IH0', 'T'),
#    ('M', 'IH1', 'L', 'IH0', 'T'),
#    ('T', 'IH1', 'L', 'IH0', 'T'),
#    ('W', 'IH1', 'L', 'IH0', 'T'),
#    ('G', 'AE1', 'L', 'IH0', 'T'),
#    ('G', 'UW1', 'L', 'IH0', 'T'),
#    ('G', 'IH1', 'L', 'AH0', 'T'),
#    ('G', 'IH1', 'L', 'IH0', 'G'),
#    ('G', 'IH1', 'L', 'IH0', 'K'),
#    ('G', 'IH1', 'L', 'IH0', 'M'),
#    ('G', 'IH1', 'L', 'IH0', 'N'),
#    ('G', 'IH1', 'L', 'IH0', 'S')]],
#  ('AH0',
#   'F',
#   'EH1',
#   'K',
#   'SH',
#   'AH0',
#   'N',
#   'AH0',
#   'T'): [[('AH0', 'F', 'EH1', 'K', 'SH', 'AH0', 'N', 'IH0', 'T')]],
#  ('R',
#   'IY0',
#   'F',
#   'IH1',
#   'T',
#   'IH0',
#   'NG'): [[('R', 'IY0', 'F', 'IH1', 'T', 'IH0', 'D')]],
#  ('G',
#   'EH1',
#   'S',
#   'T',
#   'IH0',
#   'D'): [[('B', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('CH', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('ER0', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('N', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('R', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('T', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('V', 'EH1', 'S', 'T', 'IH0', 'D'),
#    ('G', 'AH1', 'S', 'T', 'IH0', 'D')]],
#  ('N', 'EH1', 'R', 'EY0', 'T', 'S'): [[('N', 'EH1', 'R', 'EY0', 'T', 'ER0')]],
#  ('CH',
#   'EH1',
#   'T'): [[('B', 'EH1', 'T'),
#    ('D', 'EH1', 'T'),
#    ('F', 'EH1', 'T'),
#    ('G', 'EH1', 'T'),
#    ('HH', 'EH1', 'T'),
#    ('JH', 'EH1', 'T'),
#    ('K', 'EH1', 'T'),
#    ('L', 'EH1', 'T'),
#    ('M', 'EH1', 'T'),
#    ('N', 'EH1', 'T'),
#    ('P', 'EH1', 'T'),
#    ('R', 'EH1', 'T'),
#    ('S', 'EH1', 'T'),
#    ('T', 'EH1', 'T'),
#    ('V', 'EH1', 'T'),
#    ('W', 'EH1', 'T'),
#    ('Y', 'EH1', 'T'),
#    ('CH', 'AE1', 'T'),
#    ('CH', 'ER1', 'T'),
#    ('CH', 'EY1', 'T'),
#    ('CH', 'IH1', 'T'),
#    ('CH', 'IY1', 'T'),
#    ('CH', 'OW1', 'T'),
#    ('CH', 'EH1', 'K'),
#    ('CH', 'EH1', 'L'),
#    ('CH', 'EH1', 'N'),
#    ('CH', 'EH1', 'NG'),
#    ('CH', 'EH1', 'R'),
#    ('CH', 'EH1', 'S'),
#    ('CH', 'EH1', 'Z')]],
#  ('P',
#   'IY1',
#   'S'): [[('D', 'IY1', 'S'),
#    ('ER0', 'IY1', 'S'),
#    ('G', 'IY1', 'S'),
#    ('HH', 'IY1', 'S'),
#    ('JH', 'IY1', 'S'),
#    ('K', 'IY1', 'S'),
#    ('L', 'IY1', 'S'),
#    ('M', 'IY1', 'S'),
#    ('N', 'IY1', 'S'),
#    ('R', 'IY1', 'S'),
#    ('S', 'IY1', 'S'),
#    ('SH', 'IY1', 'S'),
#    ('T', 'IY1', 'S'),
#    ('W', 'IY1', 'S'),
#    ('Y', 'IY1', 'S'),
#    ('Z', 'IY1', 'S'),
#    ('P', 'AA1', 'S'),
#    ('P', 'AE1', 'S'),
#    ('P', 'AH1', 'S'),
#    ('P', 'AO1', 'S'),
#    ('P', 'EH1', 'S'),
#    ('P', 'ER1', 'S'),
#    ('P', 'EY1', 'S'),
#    ('P', 'IH1', 'S'),
#    ('P', 'UH1', 'S'),
#    ('P', 'IY1', 'AH0'),
#    ('P', 'IY1', 'CH'),
#    ('P', 'IY1', 'D'),
#    ('P', 'IY1', 'G'),
#    ('P', 'IY1', 'K'),
#    ('P', 'IY1', 'L'),
#    ('P', 'IY1', 'N'),
#    ('P', 'IY1', 'P'),
#    ('P', 'IY1', 'T'),
#    ('P', 'IY1', 'TH'),
#    ('P', 'IY1', 'V'),
#    ('P', 'IY1', 'Z')]],
#  ('W',
#   'AO1',
#   'K',
#   'T',
#   'ER0'): [[('D', 'AO1', 'K', 'T', 'ER0'),
#    ('W', 'EH1', 'K', 'T', 'ER0'),
#    ('W', 'AO1', 'L', 'T', 'ER0'),
#    ('W', 'AO1', 'K', 'N', 'ER0'),
#    ('W', 'AO1', 'K', 'Y', 'ER0')]],
#  ('N',
#   'IH1',
#   'K',
#   'S',
#   'T'): [[('F', 'IH1', 'K', 'S', 'T'),
#    ('M', 'IH1', 'K', 'S', 'T'),
#    ('S', 'IH1', 'K', 'S', 'T'),
#    ('N', 'EH1', 'K', 'S', 'T'),
#    ('N', 'IH1', 'K', 'S', 'IY0')]],
#  ('S',
#   'AE1',
#   'CH',
#   'ER0'): [[('HH', 'AE1', 'CH', 'ER0'),
#    ('K', 'AE1', 'CH', 'ER0'),
#    ('M', 'AE1', 'CH', 'ER0'),
#    ('N', 'AE1', 'CH', 'ER0'),
#    ('TH', 'AE1', 'CH', 'ER0'),
#    ('S', 'AH1', 'CH', 'ER0'),
#    ('S', 'ER1', 'CH', 'ER0'),
#    ('S', 'UW1', 'CH', 'ER0'),
#    ('S', 'AE1', 'D', 'ER0'),
#    ('S', 'AE1', 'DH', 'ER0'),
#    ('S', 'AE1', 'F', 'ER0'),
#    ('S', 'AE1', 'K', 'ER0'),
#    ('S', 'AE1', 'N', 'ER0'),
#    ('S', 'AE1', 'NG', 'ER0'),
#    ('S', 'AE1', 'P', 'ER0'),
#    ('S', 'AE1', 'S', 'ER0'),
#    ('S', 'AE1', 'T', 'ER0'),
#    ('S', 'AE1', 'TH', 'ER0'),
#    ('S', 'AE1', 'CH', 'AH0'),
#    ('S', 'AE1', 'CH', 'IY0'),
#    ('S', 'AE1', 'CH', 'S')]],
#  ('S',
#   'AA1',
#   'L',
#   'V',
#   'D'): [[('S', 'AA1', 'L', 'AH0', 'D'),
#    ('S', 'AA1', 'L', 'V', 'AH0'),
#    ('S', 'AA1', 'L', 'V', 'ER0'),
#    ('S', 'AA1', 'L', 'V', 'IY0'),
#    ('S', 'AA1', 'L', 'V', 'Z')]],
#  ('G',
#   'ER1',
#   'S',
#   'T',
#   'IY0',
#   'N'): [[('B', 'ER1', 'S', 'T', 'IY0', 'N'),
#    ('D', 'ER1', 'S', 'T', 'IY0', 'N'),
#    ('K', 'ER1', 'S', 'T', 'IY0', 'N'),
#    ('G', 'ER1', 'S', 'T', 'AH0', 'N'),
#    ('G', 'ER1', 'S', 'T', 'AY0', 'N')]],
#  ('M',
#   'IH1',
#   'N',
#   'IH0',
#   'S',
#   'T',
#   'ER0',
#   'Z'): [[('M', 'IH1', 'N', 'AH0', 'S', 'T', 'ER0', 'Z')]],
#  ('L',
#   'AH1',
#   'F',
#   'M',
#   'AH0',
#   'N'): [[('HH', 'AH1', 'F', 'M', 'AH0', 'N'),
#    ('L', 'AE1', 'F', 'M', 'AH0', 'N'),
#    ('L', 'AH1', 'K', 'M', 'AH0', 'N'),
#    ('L', 'AH1', 'T', 'M', 'AH0', 'N')]],
#  ('F',
#   'ER1',
#   'S',
#   'AH0',
#   'N'): [[('B', 'ER1', 'S', 'AH0', 'N'),
#    ('G', 'ER1', 'S', 'AH0', 'N'),
#    ('HH', 'ER1', 'S', 'AH0', 'N'),
#    ('JH', 'ER1', 'S', 'AH0', 'N'),
#    ('M', 'ER1', 'S', 'AH0', 'N'),
#    ('P', 'ER1', 'S', 'AH0', 'N'),
#    ('S', 'ER1', 'S', 'AH0', 'N'),
#    ('W', 'ER1', 'S', 'AH0', 'N'),
#    ('F', 'AA1', 'S', 'AH0', 'N'),
#    ('F', 'AE1', 'S', 'AH0', 'N'),
#    ('F', 'UW1', 'S', 'AH0', 'N'),
#    ('F', 'ER1', 'L', 'AH0', 'N'),
#    ('F', 'ER1', 'M', 'AH0', 'N')]],
#  ('T',
#   'AE1',
#   'T',
#   'ER0',
#   'Z'): [[('B', 'AE1', 'T', 'ER0', 'Z'),
#    ('L', 'AE1', 'T', 'ER0', 'Z'),
#    ('M', 'AE1', 'T', 'ER0', 'Z'),
#    ('SH', 'AE1', 'T', 'ER0', 'Z'),
#    ('T', 'EY1', 'T', 'ER0', 'Z'),
#    ('T', 'IY1', 'T', 'ER0', 'Z'),
#    ('T', 'UW1', 'T', 'ER0', 'Z'),
#    ('T', 'AE1', 'T', 'ER0', 'D')]],
#  ('R', 'IY1', 'S', 'EY2', 'L'): [[('R', 'IY1', 'T', 'EY2', 'L')]],
#  ('B',
#   'EH1',
#   'L',
#   'AH0',
#   'M'): [[('F', 'EH1', 'L', 'AH0', 'M'),
#    ('K', 'EH1', 'L', 'AH0', 'M'),
#    ('M', 'EH1', 'L', 'AH0', 'M'),
#    ('P', 'EH1', 'L', 'AH0', 'M'),
#    ('Z', 'EH1', 'L', 'AH0', 'M'),
#    ('B', 'OW1', 'L', 'AH0', 'M'),
#    ('B', 'EH1', 'K', 'AH0', 'M'),
#    ('B', 'EH1', 'L', 'AH0', 'K'),
#    ('B', 'EH1', 'L', 'AH0', 'N'),
#    ('B', 'EH1', 'L', 'AH0', 'S'),
#    ('B', 'EH1', 'L', 'AH0', 'T'),
#    ('B', 'EH1', 'L', 'AH0', 'Z')]],
#  ('R',
#   'EH1',
#   'Z',
#   'AH0',
#   'N',
#   'Z'): [[('R', 'EY1', 'Z', 'AH0', 'N', 'Z'),
#    ('R', 'IY1', 'Z', 'AH0', 'N', 'Z'),
#    ('R', 'OW1', 'Z', 'AH0', 'N', 'Z'),
#    ('R', 'EH1', 'K', 'AH0', 'N', 'Z'),
#    ('R', 'EH1', 'Z', 'IH0', 'N', 'Z')]],
#  ('B', 'UH1', 'R', 'D', 'AH0', 'Z'): [[('B', 'AO1', 'R', 'D', 'AH0', 'Z')]],
#  ('S',
#   'IY1',
#   'T'): [[('B', 'IY1', 'T'),
#    ('CH', 'IY1', 'T'),
#    ('D', 'IY1', 'T'),
#    ('F', 'IY1', 'T'),
#    ('HH', 'IY1', 'T'),
#    ('K', 'IY1', 'T'),
#    ('L', 'IY1', 'T'),
#    ('M', 'IY1', 'T'),
#    ('N', 'IY1', 'T'),
#    ('P', 'IY1', 'T'),
#    ('SH', 'IY1', 'T'),
#    ('T', 'IY1', 'T'),
#    ('V', 'IY1', 'T'),
#    ('W', 'IY1', 'T'),
#    ('S', 'AE1', 'T'),
#    ('S', 'AO1', 'T'),
#    ('S', 'AY1', 'T'),
#    ('S', 'EH1', 'T'),
#    ('S', 'ER1', 'T'),
#    ('S', 'EY1', 'T'),
#    ('S', 'IH1', 'T'),
#    ('S', 'UH1', 'T'),
#    ('S', 'UW1', 'T'),
#    ('S', 'IY1', 'AH0'),
#    ('S', 'IY1', 'AW0'),
#    ('S', 'IY1', 'B'),
#    ('S', 'IY1', 'D'),
#    ('S', 'IY1', 'DH'),
#    ('S', 'IY1', 'EY1'),
#    ('S', 'IY1', 'F'),
#    ('S', 'IY1', 'G'),
#    ('S', 'IY1', 'JH'),
#    ('S', 'IY1', 'K'),
#    ('S', 'IY1', 'L'),
#    ('S', 'IY1', 'M'),
#    ('S', 'IY1', 'N'),
#    ('S', 'IY1', 'OW0'),
#    ('S', 'IY1', 'P'),
#    ('S', 'IY1', 'R'),
#    ('S', 'IY1', 'S'),
#    ('S', 'IY1', 'TH'),
#    ('S', 'IY1', 'UW0'),
#    ('S', 'IY1', 'Z')]],
#  ('F',
#   'AY1',
#   'B',
#   'ER0'): [[('B', 'AY1', 'B', 'ER0'),
#    ('HH', 'AY1', 'B', 'ER0'),
#    ('R', 'AY1', 'B', 'ER0'),
#    ('S', 'AY1', 'B', 'ER0'),
#    ('SH', 'AY1', 'B', 'ER0'),
#    ('T', 'AY1', 'B', 'ER0'),
#    ('V', 'AY1', 'B', 'ER0'),
#    ('F', 'AW1', 'B', 'ER0'),
#    ('F', 'ER1', 'B', 'ER0'),
#    ('F', 'EY1', 'B', 'ER0'),
#    ('F', 'IY1', 'B', 'ER0'),
#    ('F', 'AY1', 'F', 'ER0'),
#    ('F', 'AY1', 'G', 'ER0'),
#    ('F', 'AY1', 'L', 'ER0'),
#    ('F', 'AY1', 'N', 'ER0'),
#    ('F', 'AY1', 'T', 'ER0'),
#    ('F', 'AY1', 'Z', 'ER0')]],
#  ('HH',
#   'EH1',
#   'G'): [[('B', 'EH1', 'G'),
#    ('JH', 'EH1', 'G'),
#    ('K', 'EH1', 'G'),
#    ('L', 'EH1', 'G'),
#    ('M', 'EH1', 'G'),
#    ('N', 'EH1', 'G'),
#    ('P', 'EH1', 'G'),
#    ('R', 'EH1', 'G'),
#    ('S', 'EH1', 'G'),
#    ('T', 'EH1', 'G'),
#    ('V', 'EH1', 'G'),
#    ('HH', 'AA1', 'G'),
#    ('HH', 'AE1', 'G'),
#    ('HH', 'AH1', 'G'),
#    ('HH', 'AO1', 'G'),
#    ('HH', 'AW1', 'G'),
#    ('HH', 'EY1', 'G'),
#    ('HH', 'IY1', 'G'),
#    ('HH', 'OW1', 'G'),
#    ('HH', 'UW1', 'G'),
#    ('HH', 'EH1', 'B'),
#    ('HH', 'EH1', 'D'),
#    ('HH', 'EH1', 'JH'),
#    ('HH', 'EH1', 'K'),
#    ('HH', 'EH1', 'L'),
#    ('HH', 'EH1', 'M'),
#    ('HH', 'EH1', 'N'),
#    ('HH', 'EH1', 'NG'),
#    ('HH', 'EH1', 'P'),
#    ('HH', 'EH1', 'R'),
#    ('HH', 'EH1', 'S'),
#    ('HH', 'EH1', 'SH'),
#    ('HH', 'EH1', 'T'),
#    ('HH', 'EH1', 'TH')]],
#  ('S',
#   'IH1',
#   'T',
#   'K',
#   'AH0'): [[('D', 'IH1', 'T', 'K', 'AH0'),
#    ('N', 'IH1', 'T', 'K', 'AH0'),
#    ('S', 'IH1', 'T', 'K', 'OW0')]],
#  ('W', 'IH1', 'N', 'IH0', 'NG', 'Z'): [[('W', 'AY1', 'N', 'IH0', 'NG', 'Z')]],
#  ('K',
#   'R',
#   'AE1',
#   'P'): [[('F', 'R', 'AE1', 'P'),
#    ('T', 'R', 'AE1', 'P'),
#    ('K', 'L', 'AE1', 'P'),
#    ('K', 'R', 'AA1', 'P'),
#    ('K', 'R', 'AH1', 'P'),
#    ('K', 'R', 'AY1', 'P'),
#    ('K', 'R', 'EY1', 'P'),
#    ('K', 'R', 'IH1', 'P'),
#    ('K', 'R', 'IY1', 'P'),
#    ('K', 'R', 'UW1', 'P'),
#    ('K', 'R', 'AE1', 'B'),
#    ('K', 'R', 'AE1', 'CH'),
#    ('K', 'R', 'AE1', 'G'),
#    ('K', 'R', 'AE1', 'K'),
#    ('K', 'R', 'AE1', 'L'),
#    ('K', 'R', 'AE1', 'M'),
#    ('K', 'R', 'AE1', 'N'),
#    ('K', 'R', 'AE1', 'S'),
#    ('K', 'R', 'AE1', 'SH'),
#    ('K', 'R', 'AE1', 'T')]],
#  ('W',
#   'AY1',
#   'S',
#   'ER0'): [[('B', 'AY1', 'S', 'ER0'),
#    ('G', 'AY1', 'S', 'ER0'),
#    ('HH', 'AY1', 'S', 'ER0'),
#    ('K', 'AY1', 'S', 'ER0'),
#    ('L', 'AY1', 'S', 'ER0'),
#    ('M', 'AY1', 'S', 'ER0'),
#    ('N', 'AY1', 'S', 'ER0'),
#    ('P', 'AY1', 'S', 'ER0'),
#    ('R', 'AY1', 'S', 'ER0'),
#    ('S', 'AY1', 'S', 'ER0'),
#    ('T', 'AY1', 'S', 'ER0'),
#    ('Z', 'AY1', 'S', 'ER0'),
#    ('W', 'AO1', 'S', 'ER0'),
#    ('W', 'IH1', 'S', 'ER0'),
#    ('W', 'IY1', 'S', 'ER0'),
#    ('W', 'AY1', 'D', 'ER0'),
#    ('W', 'AY1', 'HH', 'ER0'),
#    ('W', 'AY1', 'K', 'ER0'),
#    ('W', 'AY1', 'L', 'ER0'),
#    ('W', 'AY1', 'M', 'ER0'),
#    ('W', 'AY1', 'N', 'ER0'),
#    ('W', 'AY1', 'P', 'ER0'),
#    ('W', 'AY1', 'T', 'ER0'),
#    ('W', 'AY1', 'Z', 'ER0'),
#    ('W', 'AY1', 'S', 'T')]],
#  ('T',
#   'R',
#   'AE0',
#   'N',
#   'Z',
#   'L',
#   'EY1',
#   'SH',
#   'AH0',
#   'N'): [[('T', 'R', 'AE0', 'N', 'S', 'L', 'EY1', 'SH', 'AH0', 'N')]],
#  ('AA0',
#   'V',
#   'IY1',
#   'L',
#   'EH0',
#   'S'): [[('AA0', 'V', 'IY1', 'L', 'EH0', 'Z')]],
#  ('JH',
#   'EH0',
#   'M',
#   'IY1',
#   'M',
#   'AH0'): [[('JH', 'EH0', 'M', 'AY1', 'M', 'AH0')]],
#  ('M',
#   'AA0',
#   'T',
#   'S',
#   'OW1',
#   'N',
#   'IY0'): [[('M', 'AA0', 'T', 'S', 'OW1', 'K', 'IY0')]],
#  ('AH0',
#   'L',
#   'EH1',
#   'S',
#   'IY0'): [[('AA0', 'L', 'EH1', 'S', 'IY0'),
#    ('P', 'L', 'EH1', 'S', 'IY0'),
#    ('AH0', 'L', 'EY1', 'S', 'IY0'),
#    ('AH0', 'L', 'EH1', 'L', 'IY0'),
#    ('AH0', 'L', 'EH1', 'R', 'IY0'),
#    ('AH0', 'L', 'EH1', 'T', 'IY0')]],
#  ('P',
#   'IY0',
#   'EH1',
#   'R',
#   'Z'): [[('P', 'R', 'EH1', 'R', 'Z'), ('P', 'IY0', 'EH1', 'R', 'IY0')]],
#  ('S',
#   'AH1',
#   'F',
#   'ER0',
#   'IH0',
#   'NG',
#   'Z'): [[('S', 'AH1', 'F', 'R', 'IH0', 'NG', 'Z')]],
#  ('K',
#   'AA1',
#   'R',
#   'S'): [[('F', 'AA1', 'R', 'S'),
#    ('M', 'AA1', 'R', 'S'),
#    ('P', 'AA1', 'R', 'S'),
#    ('K', 'AO1', 'R', 'S'),
#    ('K', 'AA1', 'K', 'S'),
#    ('K', 'AA1', 'P', 'S'),
#    ('K', 'AA1', 'T', 'S'),
#    ('K', 'AA1', 'R', 'AH0'),
#    ('K', 'AA1', 'R', 'B'),
#    ('K', 'AA1', 'R', 'CH'),
#    ('K', 'AA1', 'R', 'D'),
#    ('K', 'AA1', 'R', 'ER0'),
#    ('K', 'AA1', 'R', 'G'),
#    ('K', 'AA1', 'R', 'K'),
#    ('K', 'AA1', 'R', 'L'),
#    ('K', 'AA1', 'R', 'N'),
#    ('K', 'AA1', 'R', 'OW0'),
#    ('K', 'AA1', 'R', 'P'),
#    ('K', 'AA1', 'R', 'SH'),
#    ('K', 'AA1', 'R', 'T'),
#    ('K', 'AA1', 'R', 'V'),
#    ('K', 'AA1', 'R', 'Z')]],
#  ('Y',
#   'UW1',
#   'L',
#   'AH0',
#   'N',
#   'B',
#   'ER0',
#   'G'): [[('M', 'UW1', 'L', 'AH0', 'N', 'B', 'ER0', 'G'),
#    ('SH', 'UW1', 'L', 'AH0', 'N', 'B', 'ER0', 'G')]],
#  ('S',
#   'AH0',
#   'S',
#   'UW1',
#   'L',
#   'OW0'): [[('F', 'AH0', 'S', 'UW1', 'L', 'OW0')]],
#  ('W',
#   'OW1',
#   'L',
#   'T',
#   'S'): [[('B', 'OW1', 'L', 'T', 'S'),
#    ('F', 'OW1', 'L', 'T', 'S'),
#    ('G', 'OW1', 'L', 'T', 'S'),
#    ('HH', 'OW1', 'L', 'T', 'S'),
#    ('JH', 'OW1', 'L', 'T', 'S'),
#    ('K', 'OW1', 'L', 'T', 'S'),
#    ('M', 'OW1', 'L', 'T', 'S'),
#    ('S', 'OW1', 'L', 'T', 'S'),
# ...
#    ('L', 'AY1', 'T', 'IY0'),
#    ('L', 'EH1', 'T', 'IY0'),
#    ('L', 'EY1', 'T', 'IY0'),
#    ('L', 'UW1', 'T', 'IY0'),
#    ('L', 'IH1', 'B', 'IY0'),
#    ('L', 'IH1', 'D', 'IY0'),
#    ('L', 'IH1', 'L', 'IY0'),
#    ('L', 'IH1', 'N', 'IY0'),
#    ('L', 'IH1', 'P', 'IY0'),
#    ('L', 'IH1', 'R', 'IY0'),
#    ('L', 'IH1', 'S', 'IY0'),
#    ('L', 'IH1', 'V', 'IY0'),
#    ('L', 'IH1', 'Z', 'IY0'),
#    ('L', 'IH1', 'T', 'ER0'),
#    ('L', 'IH1', 'T', 'S')]],
#  ('D',
#   'UW1',
#   'S',
#   'AH0',
#   'L',
#   'ER0'): [[('D', 'UW1', 'P', 'AH0', 'L', 'ER0')]],
#  ('AA0',
#   'M',
#   'EH1',
#   'N'): [[('EY0', 'M', 'EH1', 'N'),
#    ('AA0', 'M', 'AO1', 'N'),
#    ('AA0', 'M', 'IY1', 'N')]],
#  ('OW1',
#   'P',
#   'AH0',
#   'L',
#   'Z'): [[('AE1', 'P', 'AH0', 'L', 'Z'),
#    ('OW1', 'F', 'AH0', 'L', 'Z'),
#    ('OW1', 'G', 'AH0', 'L', 'Z'),
#    ('OW1', 'P', 'AH0', 'N', 'Z')]],
#  ('K',
#   'AE1',
#   'R',
#   'IY0',
#   'ER0',
#   'Z'): [[('B', 'AE1', 'R', 'IY0', 'ER0', 'Z'),
#    ('K', 'EH1', 'R', 'IY0', 'ER0', 'Z')]],
#  ('R',
#   'UW1',
#   'K',
#   'ER0',
#   'T'): [[('R', 'AH1', 'K', 'ER0', 'T'),
#    ('R', 'AY1', 'K', 'ER0', 'T'),
#    ('R', 'IH1', 'K', 'ER0', 'T'),
#    ('R', 'UW1', 'B', 'ER0', 'T'),
#    ('R', 'UW1', 'P', 'ER0', 'T')]],
#  ('S', 'IY1', 'B', 'AO0', 'L', 'D'): [[('S', 'IY1', 'B', 'OW2', 'L', 'D')]],
#  ('HH',
#   'Y',
#   'UW1',
#   'M',
#   'IH0',
#   'D'): [[('HH', 'Y', 'UW1', 'M', 'AH0', 'D'),
#    ('HH', 'Y', 'UW1', 'M', 'ER0', 'D')]],
#  ('B',
#   'OW1',
#   'L',
#   'IH0',
#   'K'): [[('G', 'OW1', 'L', 'IH0', 'K'),
#    ('HH', 'OW1', 'L', 'IH0', 'K'),
#    ('Z', 'OW1', 'L', 'IH0', 'K'),
#    ('B', 'AA1', 'L', 'IH0', 'K'),
#    ('B', 'EH1', 'L', 'IH0', 'K'),
#    ('B', 'IH1', 'L', 'IH0', 'K'),
#    ('B', 'OW1', 'B', 'IH0', 'K'),
#    ('B', 'OW1', 'V', 'IH0', 'K'),
#    ('B', 'OW1', 'L', 'IH0', 'N'),
#    ('B', 'OW1', 'L', 'IH0', 'NG')]],
#  ('M', 'EH1', 'T', 'AO1', 'L'): [[('M', 'EH1', 'T', 'AH0', 'L')]],
#  ('W',
#   'IH1',
#   'N',
#   'B',
#   'ER2',
#   'N'): [[('K', 'IH1', 'N', 'B', 'ER2', 'N'),
#    ('W', 'IH1', 'N', 'B', 'ER0', 'N')]],
#  ('G',
#   'AA1',
#   'R',
#   'S',
#   'AH0',
#   'N'): [[('B', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('F', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('K', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('L', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('M', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('P', 'AA1', 'R', 'S', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'D', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'G', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'L', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'M', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'T', 'AH0', 'N'),
#    ('G', 'AA1', 'R', 'Z', 'AH0', 'N')]],
#  ('S',
#   'P',
#   'AE1',
#   'M'): [[('S', 'AY0', 'AE1', 'M'),
#    ('S', 'K', 'AE1', 'M'),
#    ('S', 'L', 'AE1', 'M'),
#    ('S', 'T', 'AE1', 'M'),
#    ('S', 'W', 'AE1', 'M'),
#    ('S', 'P', 'ER1', 'M'),
#    ('S', 'P', 'AE1', 'K'),
#    ('S', 'P', 'AE1', 'N'),
#    ('S', 'P', 'AE1', 'NG'),
#    ('S', 'P', 'AE1', 'R'),
#    ('S', 'P', 'AE1', 'T'),
#    ('S', 'P', 'AE1', 'TH'),
#    ('S', 'P', 'AE1', 'Z')]],
#  ('P',
#   'OW1',
#   'L',
#   'IY0'): [[('B', 'OW1', 'L', 'IY0'),
#    ('D', 'OW1', 'L', 'IY0'),
#    ('F', 'OW1', 'L', 'IY0'),
#    ('G', 'OW1', 'L', 'IY0'),
#    ('HH', 'OW1', 'L', 'IY0'),
#    ('IY0', 'OW1', 'L', 'IY0'),
#    ('JH', 'OW1', 'L', 'IY0'),
#    ('K', 'OW1', 'L', 'IY0'),
#    ('L', 'OW1', 'L', 'IY0'),
#    ('M', 'OW1', 'L', 'IY0'),
#    ('N', 'OW1', 'L', 'IY0'),
#    ('R', 'OW1', 'L', 'IY0'),
#    ('S', 'OW1', 'L', 'IY0'),
#    ('SH', 'OW1', 'L', 'IY0'),
#    ('T', 'OW1', 'L', 'IY0'),
#    ('P', 'AA1', 'L', 'IY0'),
#    ('P', 'AO1', 'L', 'IY0'),
#    ('P', 'AW1', 'L', 'IY0'),
#    ('P', 'EH1', 'L', 'IY0'),
#    ('P', 'ER1', 'L', 'IY0'),
#    ('P', 'EY1', 'L', 'IY0'),
#    ('P', 'IH1', 'L', 'IY0'),
#    ('P', 'UH1', 'L', 'IY0'),
#    ('P', 'UW1', 'L', 'IY0'),
#    ('P', 'OW1', 'D', 'IY0'),
#    ('P', 'OW1', 'K', 'IY0'),
#    ('P', 'OW1', 'Z', 'IY0'),
#    ('P', 'OW1', 'L', 'AY0'),
#    ('P', 'OW1', 'L', 'D'),
#    ('P', 'OW1', 'L', 'ER0'),
#    ('P', 'OW1', 'L', 'K'),
#    ('P', 'OW1', 'L', 'OW0'),
#    ('P', 'OW1', 'L', 'S'),
#    ('P', 'OW1', 'L', 'Z')]],
#  ('AY1',
#   'S',
#   'AH0',
#   'N',
#   'OW2',
#   'G',
#   'AH0',
#   'L'): [[('IH1', 'S', 'AH0', 'N', 'OW2', 'G', 'AH0', 'L')]],
#  ('F',
#   'R',
#   'OW1',
#   'D',
#   'ER0'): [[('B', 'R', 'OW1', 'D', 'ER0'),
#    ('SH', 'R', 'OW1', 'D', 'ER0'),
#    ('F', 'Y', 'OW1', 'D', 'ER0'),
#    ('F', 'R', 'AY1', 'D', 'ER0'),
#    ('F', 'R', 'OW1', 'M', 'ER0'),
#    ('F', 'R', 'OW1', 'D', 'OW2')]],
#  ('F',
#   'EH1',
#   'CH'): [[('B', 'EH1', 'CH'),
#    ('K', 'EH1', 'CH'),
#    ('L', 'EH1', 'CH'),
#    ('M', 'EH1', 'CH'),
#    ('P', 'EH1', 'CH'),
#    ('R', 'EH1', 'CH'),
#    ('V', 'EH1', 'CH'),
#    ('F', 'AH1', 'CH'),
#    ('F', 'AW1', 'CH'),
#    ('F', 'IH1', 'CH'),
#    ('F', 'EH1', 'D'),
#    ('F', 'EH1', 'K'),
#    ('F', 'EH1', 'L'),
#    ('F', 'EH1', 'M'),
#    ('F', 'EH1', 'N'),
#    ('F', 'EH1', 'NG'),
#    ('F', 'EH1', 'R'),
#    ('F', 'EH1', 'S'),
#    ('F', 'EH1', 'T'),
#    ('F', 'EH1', 'Z')]],
#  ('N',
#   'OW1',
#   'T',
#   'OW0'): [[('D', 'OW1', 'T', 'OW0'),
#    ('G', 'OW1', 'T', 'OW0'),
#    ('K', 'OW1', 'T', 'OW0'),
#    ('M', 'OW1', 'T', 'OW0'),
#    ('R', 'OW1', 'T', 'OW0'),
#    ('S', 'OW1', 'T', 'OW0'),
#    ('T', 'OW1', 'T', 'OW0'),
#    ('N', 'EH1', 'T', 'OW0'),
#    ('N', 'EY1', 'T', 'OW0'),
#    ('N', 'IH1', 'T', 'OW0'),
#    ('N', 'IY1', 'T', 'OW0'),
#    ('N', 'OW1', 'G', 'OW0'),
#    ('N', 'OW1', 'L', 'OW0'),
#    ('N', 'OW1', 'M', 'OW0'),
#    ('N', 'OW1', 'V', 'OW0'),
#    ('N', 'OW1', 'T', 'ER0'),
#    ('N', 'OW1', 'T', 'S')]],
#  ('S',
#   'AA1',
#   'K',
#   'ER0',
#   'Z'): [[('D', 'AA1', 'K', 'ER0', 'Z'),
#    ('F', 'AA1', 'K', 'ER0', 'Z'),
#    ('G', 'AA1', 'K', 'ER0', 'Z'),
#    ('L', 'AA1', 'K', 'ER0', 'Z'),
#    ('R', 'AA1', 'K', 'ER0', 'Z'),
#    ('S', 'AH1', 'K', 'ER0', 'Z'),
#    ('S', 'IY1', 'K', 'ER0', 'Z'),
#    ('S', 'AA1', 'D', 'ER0', 'Z'),
#    ('S', 'AA1', 'L', 'ER0', 'Z'),
#    ('S', 'AA1', 'K', 'OW0', 'Z')]],
#  ('S',
#   'T',
#   'AE1',
#   'L',
#   'Y',
#   'AH0',
#   'N',
#   'Z'): [[('IH2', 'T', 'AE1', 'L', 'Y', 'AH0', 'N', 'Z'),
#    ('S', 'K', 'AE1', 'L', 'Y', 'AH0', 'N', 'Z')]],
#  ('N',
#   'AO1',
#   'D'): [[('B', 'AO1', 'D'),
#    ('JH', 'AO1', 'D'),
#    ('L', 'AO1', 'D'),
#    ('M', 'AO1', 'D'),
#    ('P', 'AO1', 'D'),
#    ('S', 'AO1', 'D'),
#    ('TH', 'AO1', 'D'),
#    ('N', 'AA1', 'D'),
#    ('N', 'AE1', 'D'),
#    ('N', 'AH1', 'D'),
#    ('N', 'EH1', 'D'),
#    ('N', 'ER1', 'D'),
#    ('N', 'IY1', 'D'),
#    ('N', 'OW1', 'D'),
#    ('N', 'OY1', 'D'),
#    ('N', 'UW1', 'D'),
#    ('N', 'AO1', 'B'),
#    ('N', 'AO1', 'F'),
#    ('N', 'AO1', 'L'),
#    ('N', 'AO1', 'P'),
#    ('N', 'AO1', 'R'),
#    ('N', 'AO1', 'S'),
#    ('N', 'AO1', 'T'),
#    ('N', 'AO1', 'Z')]],
#  ('T',
#   'EH1',
#   'R',
#   'AH0',
#   'F'): [[('SH', 'EH1', 'R', 'AH0', 'F'),
#    ('T', 'EH1', 'R', 'AH0', 'L'),
#    ('T', 'EH1', 'R', 'AH0', 'M'),
#    ('T', 'EH1', 'R', 'AH0', 'N'),
#    ('T', 'EH1', 'R', 'AH0', 'S'),
#    ('T', 'EH1', 'R', 'AH0', 'Z')]],
#  ('B',
#   'UW0',
#   'L',
#   'EH1',
#   'T'): [[('G', 'UW0', 'L', 'EH1', 'T'),
#    ('R', 'UW0', 'L', 'EH1', 'T'),
#    ('B', 'ER2', 'L', 'EH1', 'T'),
#    ('B', 'UW2', 'L', 'EH1', 'T')]],
#  ('F',
#   'EH1',
#   'L',
#   'AH0',
#   'S'): [[('B', 'EH1', 'L', 'AH0', 'S'),
#    ('JH', 'EH1', 'L', 'AH0', 'S'),
#    ('S', 'EH1', 'L', 'AH0', 'S'),
#    ('Z', 'EH1', 'L', 'AH0', 'S'),
#    ('F', 'AY1', 'L', 'AH0', 'S'),
#    ('F', 'EH1', 'R', 'AH0', 'S'),
#    ('F', 'EH1', 'L', 'IH0', 'S'),
#    ('F', 'EH1', 'L', 'P', 'S'),
#    ('F', 'EH1', 'L', 'T', 'S'),
#    ('F', 'EH1', 'L', 'AH0', 'M'),
#    ('F', 'EH1', 'L', 'AH0', 'N')]],
#  ('EH1',
#   'S',
#   'ER0',
#   'IY0'): [[('AH1', 'S', 'ER0', 'IY0'),
#    ('ER1', 'S', 'ER0', 'IY0'),
#    ('EH1', 'L', 'ER0', 'IY0'),
#    ('EH1', 'M', 'ER0', 'IY0'),
#    ('EH1', 'V', 'ER0', 'IY0'),
#    ('EH1', 'S', 'K', 'IY0'),
#    ('EH1', 'S', 'P', 'IY0'),
#    ('EH1', 'S', 'R', 'IY0'),
#    ('EH1', 'S', 'T', 'IY0')]],
#  ('AE1',
#   'N',
#   'D',
#   'ER0',
#   'Z'): [[('EH1', 'N', 'D', 'ER0', 'Z'),
#    ('AE1', 'N', 'S', 'ER0', 'Z'),
#    ('AE1', 'N', 'T', 'ER0', 'Z'),
#    ('AE1', 'N', 'D', 'IY0', 'Z'),
#    ('AE1', 'N', 'D', 'ER0', 'AH0'),
#    ('AE1', 'N', 'D', 'ER0', 'T')]],
#  ('M',
#   'IH2',
#   'S',
#   'B',
#   'AH0',
#   'HH',
#   'EY1',
#   'V'): [[('M', 'IH2', 'S', 'B', 'IY0', 'HH', 'EY1', 'V')]],
#  ('W',
#   'AH2',
#   'N',
#   'AH1',
#   'P',
#   'M',
#   'AH0',
#   'N',
#   'SH',
#   'IH2',
#   'P'): [[('W', 'AH2', 'N', 'AH1', 'P', 'M', 'AE0', 'N', 'SH', 'IH2', 'P')]],
#  ('K',
#   'EH1',
#   'M',
#   'IH0',
#   'S',
#   'T',
#   'S'): [[('K', 'EH1', 'R', 'IH0', 'S', 'T', 'S'),
#    ('K', 'EH1', 'M', 'AH0', 'S', 'T', 'S')]],
#  ('S',
#   'EH0',
#   'N',
#   'T',
#   'AA1',
#   'R',
#   'IY0'): [[('S', 'EH0', 'N', 'T', 'UH1', 'R', 'IY0'),
#    ('S', 'EH0', 'N', 'T', 'AA1', 'N', 'IY0')]],
#  ('S',
#   'T',
#   'UW1',
#   'JH'): [[('S', 'T', 'EY1', 'JH'),
#    ('S', 'T', 'IY1', 'JH'),
#    ('S', 'T', 'UW1', 'B'),
#    ('S', 'T', 'UW1', 'D'),
#    ('S', 'T', 'UW1', 'K'),
#    ('S', 'T', 'UW1', 'L'),
#    ('S', 'T', 'UW1', 'P'),
#    ('S', 'T', 'UW1', 'V'),
#    ('S', 'T', 'UW1', 'Z')]],
#  ('P',
#   'Y',
#   'UW1',
#   'N',
#   'IH0',
#   'K'): [[('M', 'Y', 'UW1', 'N', 'IH0', 'K'),
#    ('P', 'Y', 'UW1', 'B', 'IH0', 'K')]],
#  ('S',
#   'T',
#   'R',
#   'AO1',
#   'NG'): [[('S', 'P', 'R', 'AO1', 'NG'),
#    ('S', 'T', 'R', 'AE1', 'NG'),
#    ('S', 'T', 'R', 'AH1', 'NG'),
#    ('S', 'T', 'R', 'EH1', 'NG'),
#    ('S', 'T', 'R', 'IH1', 'NG'),
#    ('S', 'T', 'R', 'AO1', 'N'),
#    ('S', 'T', 'R', 'AO1', 'Z')]],
#  ('EH1',
#   'K',
#   'AH0',
#   'L',
#   'S',
#   'T',
#   'AA0',
#   'N'): [[('EH1', 'G', 'AH0', 'L', 'S', 'T', 'AA0', 'N')]],
#  ('K',
#   'EH1',
#   'N',
#   'T',
#   'N',
#   'ER0'): [[('JH', 'EH1', 'N', 'T', 'N', 'ER0'),
#    ('L', 'EH1', 'N', 'T', 'N', 'ER0'),
#    ('S', 'EH1', 'N', 'T', 'N', 'ER0'),
#    ('V', 'EH1', 'N', 'T', 'N', 'ER0'),
#    ('Z', 'EH1', 'N', 'T', 'N', 'ER0'),
#    ('K', 'AE1', 'N', 'T', 'N', 'ER0'),
#    ('K', 'IH1', 'N', 'T', 'N', 'ER0'),
#    ('K', 'EH1', 'L', 'T', 'N', 'ER0'),
#    ('K', 'EH1', 'S', 'T', 'N', 'ER0')]],
#  ('Z',
#   'OW1',
#   'B',
#   'AH0',
#   'L'): [[('D', 'OW1', 'B', 'AH0', 'L'),
#    ('F', 'OW1', 'B', 'AH0', 'L'),
#    ('G', 'OW1', 'B', 'AH0', 'L'),
#    ('K', 'OW1', 'B', 'AH0', 'L'),
#    ('L', 'OW1', 'B', 'AH0', 'L'),
#    ('M', 'OW1', 'B', 'AH0', 'L'),
#    ('N', 'OW1', 'B', 'AH0', 'L'),
#    ('R', 'OW1', 'B', 'AH0', 'L'),
#    ('S', 'OW1', 'B', 'AH0', 'L'),
#    ('SH', 'OW1', 'B', 'AH0', 'L'),
#    ('Z', 'AY1', 'B', 'AH0', 'L'),
#    ('Z', 'ER1', 'B', 'AH0', 'L'),
#    ('Z', 'EY1', 'B', 'AH0', 'L'),
#    ('Z', 'IY1', 'B', 'AH0', 'L')]],
#  ('F',
#   'L',
#   'AO1'): [[('G', 'L', 'AO1'),
#    ('K', 'L', 'AO1'),
#    ('S', 'L', 'AO1'),
#    ('F', 'L', 'AY1'),
#    ('F', 'L', 'ER1'),
#    ('F', 'L', 'EY1'),
#    ('F', 'L', 'IY1'),
#    ('F', 'L', 'OW1'),
#    ('F', 'L', 'OY1'),
#    ('F', 'L', 'UW1')]],
#  ('K',
#   'EH1',
#   'L',
#   'IH0',
#   'M',
#   'Z'): [[('K', 'EH1', 'L', 'AH0', 'M', 'Z'),
#    ('K', 'EH1', 'L', 'IH0', 'N', 'Z')]],
#  ('L',
#   'IH1',
#   'N',
#   'D',
#   'AA2',
#   'L'): [[('R', 'IH1', 'N', 'D', 'AA2', 'L'),
#    ('L', 'AH1', 'N', 'D', 'AA2', 'L'),
#    ('L', 'IH1', 'N', 'D', 'AH0', 'L')]],
#  ('B',
#   'AA0',
#   'R',
#   'T',
#   'OW1',
#   'L',
#   'IY0'): [[('B', 'AA0', 'R', 'T', 'OW1', 'N', 'IY0'),
#    ('B', 'AA0', 'R', 'T', 'OW1', 'L', 'OW0')]],
#  ('JH',
#   'AY1',
#   'B',
#   'AH0',
#   'Z'): [[('D', 'AY1', 'B', 'AH0', 'Z'),
#    ('R', 'AY1', 'B', 'AH0', 'Z'),
#    ('S', 'AY1', 'B', 'AH0', 'Z')]],
#  ('L',
#   'AO1',
#   'R',
#   'IH0',
#   'NG'): [[('B', 'AO1', 'R', 'IH0', 'NG'),
#    ('D', 'AO1', 'R', 'IH0', 'NG'),
#    ('G', 'AO1', 'R', 'IH0', 'NG'),
#    ('K', 'AO1', 'R', 'IH0', 'NG'),
#    ('M', 'AO1', 'R', 'IH0', 'NG'),
#    ('P', 'AO1', 'R', 'IH0', 'NG'),
#    ('R', 'AO1', 'R', 'IH0', 'NG'),
#    ('S', 'AO1', 'R', 'IH0', 'NG'),
#    ('SH', 'AO1', 'R', 'IH0', 'NG'),
#    ('W', 'AO1', 'R', 'IH0', 'NG'),
#    ('L', 'UH1', 'R', 'IH0', 'NG'),
#    ('L', 'AO1', 'D', 'IH0', 'NG'),
#    ('L', 'AO1', 'G', 'IH0', 'NG'),
#    ('L', 'AO1', 'NG', 'IH0', 'NG'),
#    ('L', 'AO1', 'S', 'IH0', 'NG'),
#    ('L', 'AO1', 'R', 'AH0', 'NG'),
#    ('L', 'AO1', 'R', 'IH0', 'K'),
#    ('L', 'AO1', 'R', 'IH0', 'N'),
#    ('L', 'AO1', 'R', 'IH0', 'S')]],
#  ('D',
#   'AE1',
#   'G',
#   'AH0',
#   'N',
#   'HH',
#   'AA2',
#   'R',
#   'T'): [[('D', 'EH1', 'G', 'AH0', 'N', 'HH', 'AA2', 'R', 'T')]],
#  ('SH',
#   'AY1',
#   'N',
#   'IY0'): [[('B', 'AY1', 'N', 'IY0'),
#    ('HH', 'AY1', 'N', 'IY0'),
#    ('P', 'AY1', 'N', 'IY0'),
#    ('R', 'AY1', 'N', 'IY0'),
#    ('T', 'AY1', 'N', 'IY0'),
#    ('V', 'AY1', 'N', 'IY0'),
#    ('W', 'AY1', 'N', 'IY0'),
#    ('SH', 'AO1', 'N', 'IY0'),
#    ('SH', 'OW1', 'N', 'IY0'),
#    ('SH', 'AY1', 'L', 'IY0'),
#    ('SH', 'AY1', 'R', 'IY0'),
#    ('SH', 'AY1', 'N', 'D'),
#    ('SH', 'AY1', 'N', 'ER0'),
#    ('SH', 'AY1', 'N', 'Z')]],
#  ('K',
#   'AE1',
#   'F'): [[('CH', 'AE1', 'F'),
#    ('F', 'AE1', 'F'),
#    ('G', 'AE1', 'F'),
#    ('HH', 'AE1', 'F'),
#    ('L', 'AE1', 'F'),
#    ('N', 'AE1', 'F'),
#    ('P', 'AE1', 'F'),
#    ('R', 'AE1', 'F'),
#    ('SH', 'AE1', 'F'),
#    ('T', 'AE1', 'F'),
#    ('Y', 'AE1', 'F'),
#    ('K', 'AA1', 'F'),
#    ('K', 'AH1', 'F'),
#    ('K', 'AO1', 'F'),
#    ('K', 'IH1', 'F'),
#    ('K', 'IY1', 'F'),
#    ('K', 'OY1', 'F'),
#    ('K', 'AE1', 'B'),
#    ('K', 'AE1', 'CH'),
#    ('K', 'AE1', 'D'),
#    ('K', 'AE1', 'JH'),
#    ('K', 'AE1', 'K'),
#    ('K', 'AE1', 'L'),
#    ('K', 'AE1', 'M'),
#    ('K', 'AE1', 'N'),
#    ('K', 'AE1', 'NG'),
#    ('K', 'AE1', 'P'),
#    ('K', 'AE1', 'S'),
#    ('K', 'AE1', 'SH'),
#    ('K', 'AE1', 'T'),
#    ('K', 'AE1', 'TH')]],
#  ('S',
#   'IH1',
#   'S',
#   'AH0',
#   'L',
#   'ER0'): [[('CH', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('F', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('G', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('K', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('SH', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('W', 'IH1', 'S', 'AH0', 'L', 'ER0'),
#    ('S', 'AE1', 'S', 'AH0', 'L', 'ER0'),
#    ('S', 'EH1', 'S', 'AH0', 'L', 'ER0'),
#    ('S', 'IH1', 'K', 'AH0', 'L', 'ER0'),
#    ('S', 'IH1', 'M', 'AH0', 'L', 'ER0'),
#    ('S', 'IH1', 'S', 'AH0', 'L', 'IY0')]],
#  ('F',
#   'EH1',
#   'T',
#   'ER0',
#   'D'): [[('B', 'EH1', 'T', 'ER0', 'D'),
#    ('L', 'EH1', 'T', 'ER0', 'D'),
#    ('P', 'EH1', 'T', 'ER0', 'D'),
#    ('F', 'EH1', 'DH', 'ER0', 'D'),
#    ('F', 'EH1', 'T', 'AH0', 'D'),
#    ('F', 'EH1', 'T', 'ER0', 'Z')]],
#  ('F',
#   'AE1',
#   'S',
#   'L',
#   'ER0'): [[('B', 'AE1', 'S', 'L', 'ER0'),
#    ('D', 'AE1', 'S', 'L', 'ER0'),
#    ('HH', 'AE1', 'S', 'L', 'ER0'),
#    ('K', 'AE1', 'S', 'L', 'ER0'),
#    ('F', 'AA1', 'S', 'L', 'ER0'),
#    ('F', 'EH1', 'S', 'L', 'ER0'),
#    ('F', 'IH1', 'S', 'L', 'ER0'),
#    ('F', 'AE1', 'K', 'L', 'ER0'),
#    ('F', 'AE1', 'S', 'N', 'ER0'),
#    ('F', 'AE1', 'S', 'T', 'ER0')]],
#  ('IH2',
#   'N',
#   'V',
#   'EH1',
#   'R',
#   'IY0',
#   'AH0',
#   'N',
#   'S'): [[('IH2', 'N', 'V', 'EH1', 'R', 'IY0', 'AH0', 'N', 'T')]],
#  ('HH',
#   'AO1',
#   'NG',
#   'K',
#   'IH0',
#   'NG'): [[('HH', 'AO1', 'NG', 'K', 'AO0', 'NG'),
#    ('HH', 'AO1', 'NG', 'K', 'AO1', 'NG')]],
#  ('R',
#   'EH1',
#   'G',
#   'OW0'): [[('L', 'EH1', 'G', 'OW0'),
#    ('R', 'AA1', 'G', 'OW0'),
#    ('R', 'IY1', 'G', 'OW0'),
#    ('R', 'EH1', 'K', 'OW0'),
#    ('R', 'EH1', 'M', 'OW0'),
#    ('R', 'EH1', 'N', 'OW0'),
#    ('R', 'EH1', 'G', 'EY2'),
#    ('R', 'EH1', 'G', 'IY0'),
#    ('R', 'EH1', 'G', 'Z')]],
#  ('CH',
#   'AW1',
#   'S'): [[('B', 'AW1', 'S'),
#    ('D', 'AW1', 'S'),
#    ('F', 'AW1', 'S'),
#    ('G', 'AW1', 'S'),
#    ('HH', 'AW1', 'S'),
#    ('K', 'AW1', 'S'),
#    ('L', 'AW1', 'S'),
#    ('M', 'AW1', 'S'),
#    ('N', 'AW1', 'S'),
#    ('R', 'AW1', 'S'),
#    ('Y', 'AW1', 'S'),
#    ('CH', 'AE1', 'S'),
#    ('CH', 'EH1', 'S'),
#    ('CH', 'EY1', 'S'),
#    ('CH', 'OY1', 'S'),
#    ('CH', 'UW1', 'S'),
#    ('CH', 'AW1', 'Z')]],
#  ('P',
#   'EY1',
#   'L',
#   'IY0',
#   'OW0'): [[('D', 'EY1', 'L', 'IY0', 'OW0'),
#    ('P', 'AA1', 'L', 'IY0', 'OW0'),
#    ('P', 'UW1', 'L', 'IY0', 'OW0')]],
#  ('S',
#   'EH1',
#   'K'): [[('B', 'EH1', 'K'),
#    ('CH', 'EH1', 'K'),
#    ('D', 'EH1', 'K'),
#    ('F', 'EH1', 'K'),
#    ('HH', 'EH1', 'K'),
#    ('JH', 'EH1', 'K'),
#    ('K', 'EH1', 'K'),
#    ('L', 'EH1', 'K'),
#    ('M', 'EH1', 'K'),
#    ('N', 'EH1', 'K'),
#    ('P', 'EH1', 'K'),
#    ('R', 'EH1', 'K'),
#    ('SH', 'EH1', 'K'),
#    ('T', 'EH1', 'K'),
#    ('W', 'EH1', 'K'),
#    ('Y', 'EH1', 'K'),
#    ('Z', 'EH1', 'K'),
#    ('S', 'AA1', 'K'),
#    ('S', 'AE1', 'K'),
#    ('S', 'AH1', 'K'),
#    ('S', 'AO1', 'K'),
#    ('S', 'AY1', 'K'),
#    ('S', 'ER1', 'K'),
#    ('S', 'EY1', 'K'),
#    ('S', 'IH1', 'K'),
#    ('S', 'IY1', 'K'),
#    ('S', 'OW1', 'K'),
#    ('S', 'UW1', 'K'),
#    ('S', 'EH1', 'D'),
#    ('S', 'EH1', 'F'),
#    ('S', 'EH1', 'G'),
#    ('S', 'EH1', 'JH'),
#    ('S', 'EH1', 'L'),
#    ('S', 'EH1', 'N'),
#    ('S', 'EH1', 'NG'),
#    ('S', 'EH1', 'P'),
#    ('S', 'EH1', 'R'),
#    ('S', 'EH1', 'T'),
#    ('S', 'EH1', 'TH'),
#    ('S', 'EH1', 'Z')]],
#  ...}

# %%
# exhaustive swap-only 3-edit puns
# for word in all_pronunciations:
#     for i in range(len(word)):
#         for j in range(i + 1,len(word)):
#             if i != j:
#                 for symbol_i in SYMBOLS:
#                     for symbol_j in SYMBOLS:
#                         if symbol_i != word[i] and symbol_j != word[j]:
#                             pun_attempt = tuple([
#                                 *word[:i], symbol_i, *word[i + 1:j]])
#                             if pun_attempt in all_pronunciations:
#                                 if word in puns:
#                                     puns[word][0].append(pun_attempt)
#                                 else:
#                                     puns[word] = [[pun_attempt]]
# Out:
# 11.443697499232712
